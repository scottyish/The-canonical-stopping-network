# %% [markdown]
# # FSL FEAT nipype

# %%
import os
import glob

import nipype
import nipype.interfaces.io as nio
import nipype.interfaces.fsl as fsl
import nipype.interfaces.ants as ants
import nipype.pipeline.engine as pe
import nipype.interfaces.utility as util
import nipype.algorithms.modelgen as model

# %% [markdown]
# ## pipeline setup

# %%
# Which dataset are we looking at?
# this_dataset = 'Leipzig_7T_SM'
this_dataset = 'Leipzig_7T_GdH'
# this_dataset = 'NTNU_7T_SJSI'

# %%
# general set-up
base_dir = '/home/scotti/projects/3t_7t_sst_comparison'
work_dir = os.path.join(base_dir, 'processing', 'nipype_workflow_folders')
smooth_hp_dir = os.path.join(base_dir, 'derivatives', 'susan_smoothed_hp_func', this_dataset)

hpcutoff = 10000.   # in seconds
model_n = [0]
spaces = ['T1w']   # shouldn't touch this but just in case we _do_ want to go back to MNI....

if this_dataset == 'Leipzig_7T_SM':
    smoothing_fwhm = ['1p6']
    t_r = 3.0
    numsubs = 18
    subject_ids = [x.split('/')[-2].split('-')[-1] for x in glob.glob(os.path.join(smooth_hp_dir, 'sub-*/'))]
    task = 'stop'
elif this_dataset == 'Leipzig_7T_GdH':
    smoothing_fwhm = ['5p0']#['3p125']#['1p5']
    t_r = 2.0
#     numsubs = 20
    subject_ids = [x.split('/')[-1].split('-')[-1] for x in glob.glob(os.path.join(smooth_hp_dir, 'sub-*T'))]
    numsubs = len(subject_ids)
    task = 'stop'

template_brain = os.path.join(base_dir,'sourcedata/templates/mni_icbm152_t1_tal_nlin_asym_09c_brain.nii')

# %%
print(f"""
this dataset : {this_dataset}
smoothing_fwhm : {smoothing_fwhm}
tr : {t_r}
number of subjects : {numsubs}
subject ids : {subject_ids}
smooth_hp_dir : {smooth_hp_dir}
model ns : {model_n}

""")
# Out:
# this dataset : Leipzig_7T_GdH
# smoothing_fwhm : ['5p0']
# tr : 2.0
# number of subjects : 17
# subject ids : ['KCAT', 'MRCT', 'RSIT', 'TS6T', 'BI3T', 'SPGT', 'VL1T', 'NM3T', 'GAIT', 'WW2T', 'FMFT', 'LV2T', 'KP6T', 'PF5T', 'ZK4T', 'UM2T', 'SC1T']
# smooth_hp_dir : /home/scotti/projects/3t_7t_sst_comparison/derivatives/susan_smoothed_hp_func/Leipzig_7T_GdH
# model ns : [0]

# %% [markdown]
# # first & second level models

# %%
def get_session_info(subject_id, run, task='stop', this_dataset='Leipzig_7T_SM', space='T1w', shift=-1.38/2, model_n=0,
                    root_dir='/home/scotti/projects/3t_7t_sst_comparison', include_physio=True):
    # other space: MNI152NLin2009cAsym
    import pandas as pd
    import numpy as np
    import os
    from nipype.interfaces.base import Bunch
            
    ### files ###
    sub = subject_id
    event_fn = f'{root_dir}/derivatives/event_files/{this_dataset}/sub-{sub}/func/sub-{sub}_task-{task}_run-{run}_events.tsv'
#         func_fn = f'{root_dir}/derivatives/fmriprep/fmriprep/sub-{sub}/ses-{ses}/func/sub-{sub}_ses-{ses}_task-{task}_run-{run}_space-{space}_desc-preproc_bold.nii.gz'
    confounds_fn = f'{root_dir}/derivatives/fmriprep/{this_dataset}/fmriprep/fmriprep/sub-{sub}/func/sub-{sub}_task-{task}_run-{run}_desc-confounds_timeseries.tsv'

    events = pd.read_csv(event_fn, sep='\t', index_col=None)
    events['duration'] = 0.001  # stick functions
    if model_n == 0:
        events = events.loc[events.trial_type.isin(['ss', 'fs', 'go'])]
    elif model_n == 1:
        events = events.loc[events.trial_type.isin(['response_left', 'response_right'])]
    events = events[['onset', 'trial_type', 'duration']]

    # slice time correction, nb: shift should be a negative number for STC
    events['onset'] += shift  

    ### confounds ###
    confounds = pd.read_csv(confounds_fn, sep='\t')
#        cosine_cols = [x for x in confounds.columns if 'cos' in x]
    include_confounds = ['trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z', 'dvars', 'framewise_displacement'] #+ cosine_cols
    confounds = confounds[include_confounds].fillna(method='bfill')

    # get retroicor
    if include_physio:
#         retroicor_fn = f'{root_dir}/derivatives/retroicor/sub-{sub}/ses-{ses}/func/sub-{sub}_ses-{ses}_task-{task}_run-{run}_desc-retroicor_regressors.tsv'
#         if not os.path.exists(retroicor_fn):
        ## take first 20 aCompCor components
        print("No retroicor found, including 20 a_comp_cor components")
        a_comp_cor = pd.read_csv(confounds_fn, sep='\t')[['a_comp_cor_' + str(x).zfill(2) for x in range(20)]]
        confounds = pd.concat([confounds, a_comp_cor], axis=1)
#         else:
#             retroicor = pd.read_csv(retroicor_fn, sep='\t', header=None).iloc[:,:20]  ## 20 components in total
#             retroicor.columns = ['cardiac_' + str(x) for x in range(6)] + ['respiratory_' + str(x) for x in range(8)] + ['respiratoryxcardiac_' + str(x) for x in range(4)] + ['HRV', 'RVT']
#             confounds = pd.concat([confounds, retroicor], axis=1)

    # save the confounds that we actually include in the GLM to csv, no header or index
    confounds_fn = f'{root_dir}/derivatives/confounds/{this_dataset}/sub-{sub}/func/sub-{sub}_task-{task}_run-{run}_desc-confounds_timeseries.txt'
    os.makedirs(os.path.dirname(confounds_fn), exist_ok=True)
    confounds.to_csv(confounds_fn, sep='\t', header=False, index=False)

    ### Make bunch ###
    if model_n == 0:
        conditions=['fs',
                    'ss',
                    'go']

    elif model_n ==1:
        conditions = [
                     'response_left',
                     'response_right'
                     ]

    onsets = [events.loc[events.trial_type==trial_type,'onset'].tolist() for trial_type in conditions]
    durations = [events.loc[events.trial_type==trial_type,'duration'].tolist() for trial_type in conditions]
    amplitudes = [[1] * events.loc[events.trial_type==trial_type,'onset'].shape[0] for trial_type in conditions]
#             amplitudes = [events.loc[events.trial_type==trial_type,'modulation'].tolist() for trial_type in conditions]

    info = Bunch(conditions=conditions,
                 onsets=onsets,
                 durations=durations,
                 amplitudes=amplitudes)
#         print(info)
    
    # always return info and the confounds_fn
    return info, confounds_fn #, contrasts[0]

if model_n == [0]:
    contrasts = [('fs', 'T', ['fs'], [1.0]),
                 ('ss', 'T', ['ss'], [1.0]),
                 ('go', 'T', ['go'], [1.0]),
                 ('fs-go', 'T', ['fs', 'go'], [1, -1]),
                 ('fs-ss', 'T', ['fs', 'ss'], [1, -1]),
                 ('ss-go', 'T', ['ss', 'go'], [1, -1]),
                 ]
    
elif model_n == [1]:
    contrasts = [('response_left', 'T', ['response_left'], [1.0]),
                 ('response_right', 'T', ['response_right'], [1.0]),
                 ('left-right', 'T', ['response_left','response_right'], [1,-1])
                 ]

# %%
def get_runs_per_sub(subject_id):
    # here we can add the runs per subject if some subject miss a run or two
    if not subject_id in ['DA9T']:
        runs = [1,2,3]
    else:
        runs = [1,2]
    
    return runs

# %%
workflow = pe.Workflow(name='feat_level12_sst_hp')
workflow.base_dir = os.path.join(base_dir, 'processing', 'nipype_workflow_folders', this_dataset)
workflow.config = {"execution": {"crashdump_dir":os.path.join(base_dir, 'processing', 'crashdumps')}}

# identity
identity = pe.Node(util.IdentityInterface(fields=['subject_id', 'space', 'model_n', 'smoothing_fwhm']), name='identity')
identity.iterables = [('subject_id', subject_ids),
                      ('space', spaces),
                      ('model_n', model_n),
                      ('smoothing_fwhm', smoothing_fwhm)]

# selector
# if running only one run, copy the mask from run 1 to run 2, 'mask' variable below needs a list, it will crash if only one is found
#(terrible way to get around this.. fix at some point.. lazy..)
templates = {'smoothed_funcs': os.path.join(base_dir, 'derivatives', 'susan_smoothed_hp_func', this_dataset,
                                            'sub-{subject_id}', 'func',  
                                            f'sub-{{subject_id}}_task-{task}_run-*_space-{{space}}*_fwhm-{{smoothing_fwhm}}_tempfilt.nii.gz'),
             'mask': os.path.join(base_dir, 'derivatives', 'fmriprep', this_dataset, 'fmriprep', 'fmriprep',
                                  'sub-{subject_id}', 'func', 
                                  f'sub-{{subject_id}}_task-{task}_run-*_space-{{space}}_desc-brain_mask.nii.gz'),
             'composite':  os.path.join(base_dir, 'derivatives', 'fmriprep', this_dataset, 'fmriprep', 'fmriprep',
                                        'sub-{subject_id}', 'anat', 
                                        'sub-{subject_id}_from-T1w_to-MNI152NLin2009cAsym_mode-image_xfm.h5'),
             'xfm': os.path.join(base_dir, 'derivatives', 'fmriprep', this_dataset, 'fmriprep', 'fmriprep',
                                  'sub-{subject_id}', 'func', 
                                  f'sub-{{subject_id}}_task-{task}_run-*_from-scanner_to-T1w_mode-image_xfm.txt'),}
selector = pe.Node(nio.SelectFiles(templates), name='selector')

workflow.connect(identity, 'subject_id', selector, 'subject_id')
workflow.connect(identity, 'space', selector, 'space')
workflow.connect(identity, 'smoothing_fwhm', selector, 'smoothing_fwhm')

# get run info per sub
run_info_getter = pe.Node(util.Function(function=get_runs_per_sub,
                                        input_names=['subject_id'],
                                        output_names=['runs']), name='run_info_getter')
workflow.connect(identity, 'subject_id', run_info_getter, 'subject_id')

# session info getter
session_info_getter = pe.MapNode(util.Function(function=get_session_info,
                                     input_names=['subject_id', 'run', 'task', 'this_dataset', 'space', 'shift', 'model_n'],
                                     output_names=['session_info', 'confounds']),
                                 iterfield=['run'],
                                 name='session_info_getter')
session_info_getter.inputs.task=task
session_info_getter.inputs.this_dataset=this_dataset
session_info_getter.inputs.space='T1w'
session_info_getter.inputs.shift = -t_r/2

workflow.connect(identity, 'subject_id', session_info_getter, 'subject_id')
workflow.connect(run_info_getter, 'runs', session_info_getter, 'run')
workflow.connect(identity, 'model_n', session_info_getter, 'model_n')


# model setup
specifymodel = pe.Node(model.SpecifyModel(), name='specifymodel1')
specifymodel.inputs.input_units = 'secs'
specifymodel.inputs.time_repetition = t_r
specifymodel.inputs.high_pass_filter_cutoff = hpcutoff

workflow.connect(session_info_getter, 'session_info', specifymodel, 'subject_info')
## old flow (with cosines): immediately connect to specifymodel
workflow.connect(selector, 'smoothed_funcs', specifymodel, 'functional_runs')

# Level 1 design
level1design = pe.Node(interface=fsl.Level1Design(), name="level1design")
level1design.inputs.interscan_interval = t_r
level1design.inputs.bases = {'dgamma': {'derivs': True}}
level1design.inputs.contrasts = contrasts
level1design.inputs.model_serial_correlations = True

workflow.connect(specifymodel, 'session_info', level1design, 'session_info')
# workflow.connect(session_info_getter, 'contrasts', level1design, 'contrasts')

# FEAT model
modelgen = pe.MapNode(interface=fsl.FEATModel(), iterfield=['ev_files', 'fsf_file', 'args'], name='modelgen')

workflow.connect(level1design, 'ev_files', modelgen, 'ev_files')
workflow.connect(level1design, 'fsf_files', modelgen, 'fsf_file')
workflow.connect(session_info_getter, 'confounds', modelgen, 'args')   # add confounds here


# FILM GLS
iterfield = ['design_file', 'in_file', 'tcon_file']
modelestimate = pe.MapNode(interface=fsl.FILMGLS(smooth_autocorr=True,
                                                 mask_size = 5,
                                                 threshold = 1000),  # 
                          name='modelestimate',
                          iterfield=iterfield,
                          mem_gb=10)

# ## old flow (with cosines): immediately connect to modelestimate
workflow.connect(selector, 'smoothed_funcs', modelestimate, 'in_file')
# # new flow: connect high-passed data
# workflow.connect(highpass, 'out_file', modelestimate, 'in_file')


workflow.connect(modelgen, 'design_file', modelestimate, 'design_file')
workflow.connect(modelgen, 'con_file', modelestimate, 'tcon_file')


#### Fixed effects
# merge copes, varcopes
copemerge = pe.MapNode(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="copemerge")

varcopemerge = pe.MapNode(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="varcopemerge")

maskemerge = pe.MapNode(interface=fsl.Merge(dimension='t'),
                       iterfield=['in_files'],
                       name="maskemerge")

def sort_copes(files):
    numelements = len(files[0])
    outfiles = []
    for i in range(numelements):
        outfiles.insert(i,[])
        for j, elements in enumerate(files):
            outfiles[i].append(elements[i])
    return outfiles

workflow.connect(modelestimate, ('copes',sort_copes), copemerge, 'in_files')
workflow.connect(modelestimate, ('varcopes',sort_copes), varcopemerge, 'in_files')


level2model = pe.Node(interface=fsl.L2Model(), name='l2model')
def num_copes(files):
    return len(files)
workflow.connect(modelestimate, ('copes',num_copes), level2model, 'num_copes')


pickfirst = lambda x: x[0]
flameo = pe.MapNode(
    interface=fsl.FLAMEO(run_mode='fe'),
    name="flameo",
    iterfield=['cope_file', 'var_cope_file'])

workflow.connect([
    (selector, flameo, [(('mask', pickfirst), 'mask_file')]),
    (copemerge, flameo, [('merged_file', 'cope_file')]),
    (varcopemerge, flameo, [('merged_file', 'var_cope_file')]),
    (level2model, flameo, [('design_mat', 'design_file'),
                           ('design_con', 't_con_file'), 
                           ('design_grp', 'cov_split_file')]),
])

## Warp to MNI-space
def warp_files(copes, varcopes, zstats, tdofs, mat, template_brain):
    # stolen from https://dpaniukov.github.io/2016/07/14/three-level-analysis-with-fsl-and-ants-2.html
    import nipype.interfaces.ants as ants

    out_copes = []
    out_varcopes = []
    out_zstats = []
    out_tdofs = []
    
    warp = ants.ApplyTransforms()
    warp.inputs.input_image_type = 0
    warp.inputs.interpolation = 'Linear'
    warp.inputs.invert_transform_flags = [False] #,False]
    warp.inputs.reference_image = template_brain
    warp.inputs.transforms = mat

    if not isinstance(copes, list):
        copes = [copes]
        varcopes = [varcopes]
        zstats = [zstats]
        tdofs = [tdofs]
    
    for cope in copes:
        warp.inputs.input_image = cope
        res=warp.run()
        out_copes.append(str(res.outputs.output_image))

    for varcope in varcopes:
        warp.inputs.input_image = varcope
        res=warp.run()
        out_varcopes.append(str(res.outputs.output_image))
        
    for zstat in zstats:
        warp.inputs.input_image = zstat
        res=warp.run()
        out_zstats.append(str(res.outputs.output_image))
    
    for tdof in tdofs:
        warp.inputs.input_image = tdof
        res=warp.run()
        out_tdofs.append(str(res.outputs.output_image))

    return out_copes, out_varcopes, out_zstats, out_tdofs

warpfunc = pe.MapNode(util.Function(input_names=['copes', 'varcopes', 'zstats', 'tdofs', 'mat','template_brain'],
                               output_names=['out_copes', 'out_varcopes', 'out_zstats', 'out_tdofs'],
                               function=warp_files),
                               iterfield=['copes', 'varcopes', 'zstats', 'tdofs'],
                  name='warpfunc')

warpfunc.inputs.template_brain = template_brain
workflow.connect(flameo, 'copes', warpfunc, 'copes')
workflow.connect(flameo, 'var_copes', warpfunc, 'varcopes')
workflow.connect(flameo, 'zstats', warpfunc, 'zstats')
workflow.connect(flameo, 'tdof', warpfunc, 'tdofs')
workflow.connect(selector, 'composite', warpfunc, 'mat')

#### post-FE analyis
# Smoothness estimation
smoothestimate = pe.MapNode(fsl.SmoothEstimate(), iterfield=['zstat_file'], name='smoothestimate')

workflow.connect(selector, ('mask', pickfirst), smoothestimate, 'mask_file')
workflow.connect(flameo, 'zstats', smoothestimate, 'zstat_file')

#
get_volume = pe.Node(fsl.ImageStats(op_string = '-V'), name='get_volume')
workflow.connect(selector, ('mask', pickfirst), get_volume, 'in_file')

# Cluster threshold
grf_cluster = pe.MapNode(fsl.Cluster(), iterfield=['dlh', 'in_file'], name='grf_cluster')
grf_cluster.iterables = [("threshold", [2.3, 3.1])] 
workflow.connect(smoothestimate, 'dlh', grf_cluster, 'dlh')
workflow.connect(flameo, 'zstats', grf_cluster, 'in_file')

def convert_volume(input):
    return int(input[1])

workflow.connect(get_volume, ('out_stat', convert_volume), grf_cluster, 'volume')
grf_cluster.inputs.out_threshold_file = True


## datasink
ds = pe.Node(nio.DataSink(), name='datasink')
ds.inputs.base_directory = os.path.join(base_dir, 'derivatives', 'glm_feat_hp_sct')

#_model_n_0_smoothing_fwhm_1p5_space_T1w_subject_id_002
substitutions = [(f't1w/level2_{stat_type}s/_model_n_{model_n_}_smoothing_fwhm_{fwhm}_space_T1w_subject_id_{sub}/_flameo{contrast_n}/{stat_type}1.nii.gz',
                  f'{this_dataset}/sub-{sub}/func/fwhm-{fwhm}/model-{model_n_}/sub-{sub}_task-{task}_space-T1w_model-{model_n_}_contrast-{contrast_n}_desc-{stat_type}.nii.gz')
                  for sub in subject_ids
                  for contrast_n in range(len(contrasts))
                  for model_n_ in model_n
                  for fwhm in smoothing_fwhm
                  for stat_type in ['cope', 'zstat', 'varcope', 'tdof_t']
                  ]


substitutions += [(f'mni/level2_{stat_type}s/_model_n_{model_n_}_smoothing_fwhm_{fwhm}_space_T1w_subject_id_{sub}/_warpfunc{contrast_n}/{stat_type}1_trans.nii.gz',
                   f'{this_dataset}/sub-{sub}/func/fwhm-{fwhm}/model-{model_n_}/sub-{sub}_task-{task}_space-MNI152NLin2009cAsym_model-{model_n_}_contrast-{contrast_n}_desc-{stat_type}.nii.gz')
                  for sub in subject_ids
                  for contrast_n in range(len(contrasts))
                  for model_n_ in model_n
                  for fwhm in smoothing_fwhm
                  for stat_type in ['cope', 'zstat', 'varcope', 'tdof_t']
                  ]

ds.inputs.substitutions = substitutions


## cluster thresholds: leave for now, this is more of a third-level model thing anyway
# workflow.connect(grf_cluster, 'threshold_file', ds, 'grf_thresholded_zstats_file')
# workflow.connect(grf_cluster, 'locnalmax_txt_file', ds, 'grf_localmax_txt_file')

## T1w-space
workflow.connect(flameo, 'zstats', ds, 'subject_level_model.t1w.level2_zstats')
workflow.connect(flameo, 'copes', ds, 'subject_level_model.t1w.level2_copes')
workflow.connect(flameo, 'var_copes', ds, 'subject_level_model.t1w.level2_varcopes')
workflow.connect(flameo, 'tdof', ds, 'subject_level_model.t1w.level2_tdof_ts')

## MNI-space
workflow.connect(warpfunc, 'out_zstats', ds, 'subject_level_model.mni.level2_zstats')
workflow.connect(warpfunc, 'out_copes', ds, 'subject_level_model.mni.level2_copes')
workflow.connect(warpfunc, 'out_varcopes', ds, 'subject_level_model.mni.level2_varcopes')
workflow.connect(warpfunc, 'out_tdofs', ds, 'subject_level_model.mni.level2_tdof_ts')
# workflow.connect(flameo, 'tdof', ds, 'level2_tdof')

# %%
workflow.run(plugin='MultiProc', plugin_args={'n_procs':10, 'memory_gb': 100})
# Out:
# 221003-10:05:23,834 nipype.workflow INFO:
# 	 Workflow feat_level12_sst_hp settings: ['check', 'execution', 'logging', 'monitoring']
# 221003-10:05:24,349 nipype.workflow INFO:
# 	 Running in parallel.
# 221003-10:05:24,354 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 34 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:05:24,440 nipype.workflow INFO:
# 	 [Job 1] Cached (feat_level12_sst_hp.run_info_getter).
# 221003-10:05:24,440 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_KCAT/selector".
# 221003-10:05:24,445 nipype.workflow INFO:
# 	 [Job 3] Cached (feat_level12_sst_hp.run_info_getter).
# 221003-10:05:24,445 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_MRCT/selector".
# 221003-10:05:24,447 nipype.workflow INFO:
# 	 [Job 5] Cached (feat_level12_sst_hp.run_info_getter).
# 221003-10:05:24,449 nipype.workflow INFO:
# 	 [Job 7] Cached (feat_level12_sst_hp.run_info_getter).
# 221003-10:05:24,448 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_RSIT/selector".
# 221003-10:05:24,452 nipype.workflow INFO:
# 	 [Job 9] Cached (feat_level12_sst_hp.run_info_getter).
# 221003-10:05:24,450 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_TS6T/selector".
# 221003-10:05:24,452 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_BI3T/selector".
# 221003-10:05:24,480 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221003-10:05:24,480 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221003-10:05:24,480 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221003-10:05:24,480 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221003-10:05:24,482 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221003-10:05:24,483 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001503s.
# 221003-10:05:24,483 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001532s.
# 221003-10:05:24,484 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.002032s.
# 221003-10:05:24,484 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001663s.
# 221003-10:05:24,485 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001421s.
# 221003-10:05:26,356 nipype.workflow INFO:
# 	 [Job 0] Completed (feat_level12_sst_hp.selector).
# 221003-10:05:26,357 nipype.workflow INFO:
# 	 [Job 2] Completed (feat_level12_sst_hp.selector).
# 221003-10:05:26,358 nipype.workflow INFO:
# 	 [Job 4] Completed (feat_level12_sst_hp.selector).
# 221003-10:05:26,359 nipype.workflow INFO:
# 	 [Job 6] Completed (feat_level12_sst_hp.selector).
# 221003-10:05:26,360 nipype.workflow INFO:
# 	 [Job 8] Completed (feat_level12_sst_hp.selector).
# 221003-10:05:26,362 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 34 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:05:26,429 nipype.workflow INFO:
# 	 [Job 11] Cached (feat_level12_sst_hp.run_info_getter).
# 221003-10:05:26,431 nipype.workflow INFO:
# 	 [Job 13] Cached (feat_level12_sst_hp.run_info_getter).
# 221003-10:05:26,430 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_SPGT/selector".
# 221003-10:05:26,434 nipype.workflow INFO:
# 	 [Job 15] Cached (feat_level12_sst_hp.run_info_getter).
# 221003-10:05:26,432 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_VL1T/selector".
# 221003-10:05:26,436 nipype.workflow INFO:
# 	 [Job 17] Cached (feat_level12_sst_hp.run_info_getter).
# 221003-10:05:26,435 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_NM3T/selector".
# 221003-10:05:26,438 nipype.workflow INFO:
# 	 [Job 19] Cached (feat_level12_sst_hp.run_info_getter).
# 221003-10:05:26,437 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_GAIT/selector".
# 221003-10:05:26,439 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_WW2T/selector".
# 221003-10:05:26,492 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221003-10:05:26,497 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.002149s.
# 221003-10:05:26,497 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221003-10:05:26,501 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001703s.
# 221003-10:05:26,525 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221003-10:05:26,529 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001673s.
# 221003-10:05:26,541 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221003-10:05:26,546 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.002115s.
# 221003-10:05:26,555 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221003-10:05:26,559 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.002098s.
# 221003-10:05:28,357 nipype.workflow INFO:
# 	 [Job 10] Completed (feat_level12_sst_hp.selector).
# 221003-10:05:28,359 nipype.workflow INFO:
# 	 [Job 12] Completed (feat_level12_sst_hp.selector).
# 221003-10:05:28,361 nipype.workflow INFO:
# 	 [Job 14] Completed (feat_level12_sst_hp.selector).
# 221003-10:05:28,362 nipype.workflow INFO:
# 	 [Job 16] Completed (feat_level12_sst_hp.selector).
# 221003-10:05:28,363 nipype.workflow INFO:
# 	 [Job 18] Completed (feat_level12_sst_hp.selector).
# 221003-10:05:28,366 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 44 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:05:28,415 nipype.workflow INFO:
# 	 [Job 21] Cached (feat_level12_sst_hp.run_info_getter).
# 221003-10:05:28,415 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_FMFT/selector".
# 221003-10:05:28,417 nipype.workflow INFO:
# 	 [Job 23] Cached (feat_level12_sst_hp.run_info_getter).
# 221003-10:05:28,417 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_LV2T/selector".
# 221003-10:05:28,418 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221003-10:05:28,419 nipype.workflow INFO:
# 	 [Job 25] Cached (feat_level12_sst_hp.run_info_getter).
# 221003-10:05:28,419 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_KP6T/selector".
# 221003-10:05:28,420 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001078s.
# 221003-10:05:28,421 nipype.workflow INFO:
# 	 [Job 27] Cached (feat_level12_sst_hp.run_info_getter).
# 221003-10:05:28,422 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_PF5T/selector".
# 221003-10:05:28,424 nipype.workflow INFO:
# 	 [Job 29] Cached (feat_level12_sst_hp.run_info_getter).
# 221003-10:05:28,424 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_ZK4T/selector".
# 221003-10:05:28,425 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221003-10:05:28,428 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001253s.
# 221003-10:05:28,443 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221003-10:05:28,447 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001741s.
# 221003-10:05:28,462 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221003-10:05:28,465 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001395s.
# 221003-10:05:28,484 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221003-10:05:28,487 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001408s.
# 221003-10:05:30,357 nipype.workflow INFO:
# 	 [Job 20] Completed (feat_level12_sst_hp.selector).
# 221003-10:05:30,359 nipype.workflow INFO:
# 	 [Job 22] Completed (feat_level12_sst_hp.selector).
# 221003-10:05:30,361 nipype.workflow INFO:
# 	 [Job 24] Completed (feat_level12_sst_hp.selector).
# 221003-10:05:30,362 nipype.workflow INFO:
# 	 [Job 26] Completed (feat_level12_sst_hp.selector).
# 221003-10:05:30,363 nipype.workflow INFO:
# 	 [Job 28] Completed (feat_level12_sst_hp.selector).
# 221003-10:05:30,365 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 54 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:05:30,420 nipype.workflow INFO:
# 	 [Job 31] Cached (feat_level12_sst_hp.run_info_getter).
# 221003-10:05:30,421 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_UM2T/selector".
# 221003-10:05:30,423 nipype.workflow INFO:
# 	 [Job 33] Cached (feat_level12_sst_hp.run_info_getter).
# 221003-10:05:30,423 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_SC1T/selector".
# 221003-10:05:30,423 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221003-10:05:30,424 nipype.workflow INFO:
# 	 [Job 34] Cached (feat_level12_sst_hp.get_volume).
# 221003-10:05:30,425 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221003-10:05:30,425 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001198s.
# 221003-10:05:30,428 nipype.workflow INFO:
# 	 [Job 36] Cached (feat_level12_sst_hp.get_volume).
# 221003-10:05:30,428 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001638s.
# 221003-10:05:30,432 nipype.workflow INFO:
# 	 [Job 38] Cached (feat_level12_sst_hp.get_volume).
# 221003-10:05:30,434 nipype.workflow INFO:
# 	 [Job 40] Cached (feat_level12_sst_hp.get_volume).
# 221003-10:05:30,437 nipype.workflow INFO:
# 	 [Job 42] Cached (feat_level12_sst_hp.get_volume).
# 221003-10:05:30,441 nipype.workflow INFO:
# 	 [Job 44] Cached (feat_level12_sst_hp.get_volume).
# 221003-10:05:32,359 nipype.workflow INFO:
# 	 [Job 30] Completed (feat_level12_sst_hp.selector).
# 221003-10:05:32,361 nipype.workflow INFO:
# 	 [Job 32] Completed (feat_level12_sst_hp.selector).
# 221003-10:05:32,364 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 58 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:05:32,425 nipype.workflow INFO:
# 	 [Job 46] Cached (feat_level12_sst_hp.get_volume).
# 221003-10:05:32,427 nipype.workflow INFO:
# 	 [Job 48] Cached (feat_level12_sst_hp.get_volume).
# 221003-10:05:32,428 nipype.workflow INFO:
# 	 [Job 50] Cached (feat_level12_sst_hp.get_volume).
# 221003-10:05:32,432 nipype.workflow INFO:
# 	 [Job 52] Cached (feat_level12_sst_hp.get_volume).
# 221003-10:05:32,436 nipype.workflow INFO:
# 	 [Job 54] Cached (feat_level12_sst_hp.get_volume).
# 221003-10:05:32,439 nipype.workflow INFO:
# 	 [Job 56] Cached (feat_level12_sst_hp.get_volume).
# 221003-10:05:32,442 nipype.workflow INFO:
# 	 [Job 58] Cached (feat_level12_sst_hp.get_volume).
# 221003-10:05:32,444 nipype.workflow INFO:
# 	 [Job 60] Cached (feat_level12_sst_hp.get_volume).
# 221003-10:05:32,491 nipype.workflow INFO:
# 	 [Job 62] Cached (feat_level12_sst_hp.get_volume).
# 221003-10:05:32,493 nipype.workflow INFO:
# 	 [Job 64] Cached (feat_level12_sst_hp.get_volume).
# 221003-10:05:34,362 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 52 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:05:34,428 nipype.workflow INFO:
# 	 [Job 66] Cached (feat_level12_sst_hp.get_volume).
# 221003-10:05:34,430 nipype.workflow INFO:
# 	 [Job 289] Cached (_session_info_getter0).
# 221003-10:05:34,431 nipype.workflow INFO:
# 	 [Job 290] Cached (_session_info_getter1).
# 221003-10:05:34,432 nipype.workflow INFO:
# 	 [Job 291] Cached (_session_info_getter2).
# 221003-10:05:34,432 nipype.workflow INFO:
# 	 [Job 292] Cached (_session_info_getter0).
# 221003-10:05:34,433 nipype.workflow INFO:
# 	 [Job 293] Cached (_session_info_getter1).
# 221003-10:05:34,434 nipype.workflow INFO:
# 	 [Job 294] Cached (_session_info_getter2).
# 221003-10:05:34,435 nipype.workflow INFO:
# 	 [Job 295] Cached (_session_info_getter0).
# 221003-10:05:34,436 nipype.workflow INFO:
# 	 [Job 296] Cached (_session_info_getter1).
# 221003-10:05:34,437 nipype.workflow INFO:
# 	 [Job 297] Cached (_session_info_getter2).
# 221003-10:05:36,362 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 45 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:05:36,428 nipype.workflow INFO:
# 	 [Job 35] Cached (feat_level12_sst_hp.session_info_getter).
# 221003-10:05:36,430 nipype.workflow INFO:
# 	 [Job 37] Cached (feat_level12_sst_hp.session_info_getter).
# 221003-10:05:36,433 nipype.workflow INFO:
# 	 [Job 39] Cached (feat_level12_sst_hp.session_info_getter).
# 221003-10:05:36,434 nipype.workflow INFO:
# 	 [Job 298] Cached (_session_info_getter0).
# 221003-10:05:36,435 nipype.workflow INFO:
# 	 [Job 299] Cached (_session_info_getter1).
# 221003-10:05:36,436 nipype.workflow INFO:
# 	 [Job 300] Cached (_session_info_getter2).
# 221003-10:05:36,437 nipype.workflow INFO:
# 	 [Job 301] Cached (_session_info_getter0).
# 221003-10:05:36,438 nipype.workflow INFO:
# 	 [Job 302] Cached (_session_info_getter1).
# 221003-10:05:36,439 nipype.workflow INFO:
# 	 [Job 303] Cached (_session_info_getter2).
# 221003-10:05:36,440 nipype.workflow INFO:
# 	 [Job 304] Cached (_session_info_getter0).
# 221003-10:05:38,365 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 40 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:05:38,438 nipype.workflow INFO:
# 	 [Job 41] Cached (feat_level12_sst_hp.session_info_getter).
# 221003-10:05:38,440 nipype.workflow INFO:
# 	 [Job 43] Cached (feat_level12_sst_hp.session_info_getter).
# 221003-10:05:38,453 nipype.workflow INFO:
# 	 [Job 68] Cached (feat_level12_sst_hp.specifymodel1).
# 221003-10:05:38,470 nipype.workflow INFO:
# 	 [Job 69] Cached (feat_level12_sst_hp.specifymodel1).
# 221003-10:05:38,490 nipype.workflow INFO:
# 	 [Job 70] Cached (feat_level12_sst_hp.specifymodel1).
# 221003-10:05:38,492 nipype.workflow INFO:
# 	 [Job 305] Cached (_session_info_getter1).
# 221003-10:05:38,493 nipype.workflow INFO:
# 	 [Job 306] Cached (_session_info_getter2).
# 221003-10:05:38,494 nipype.workflow INFO:
# 	 [Job 307] Cached (_session_info_getter0).
# 221003-10:05:38,496 nipype.workflow INFO:
# 	 [Job 308] Cached (_session_info_getter1).
# 221003-10:05:38,497 nipype.workflow INFO:
# 	 [Job 309] Cached (_session_info_getter2).
# 221003-10:05:40,366 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 37 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:05:40,425 nipype.workflow INFO:
# 	 [Job 45] Cached (feat_level12_sst_hp.session_info_getter).
# 221003-10:05:40,427 nipype.workflow INFO:
# 	 [Job 47] Cached (feat_level12_sst_hp.session_info_getter).
# 221003-10:05:40,456 nipype.workflow INFO:
# 	 [Job 71] Cached (feat_level12_sst_hp.specifymodel1).
# 221003-10:05:40,463 nipype.workflow INFO:
# 	 [Job 72] Cached (feat_level12_sst_hp.specifymodel1).
# 221003-10:05:40,493 nipype.workflow INFO:
# 	 [Job 85] Cached (feat_level12_sst_hp.level1design).
# 221003-10:05:40,530 nipype.workflow INFO:
# 	 [Job 86] Cached (feat_level12_sst_hp.level1design).
# 221003-10:05:40,546 nipype.workflow INFO:
# 	 [Job 87] Cached (feat_level12_sst_hp.level1design).
# 221003-10:05:40,547 nipype.workflow INFO:
# 	 [Job 310] Cached (_session_info_getter0).
# 221003-10:05:40,549 nipype.workflow INFO:
# 	 [Job 311] Cached (_session_info_getter1).
# 221003-10:05:40,550 nipype.workflow INFO:
# 	 [Job 312] Cached (_session_info_getter2).
# 221003-10:05:42,369 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 35 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:05:42,435 nipype.workflow INFO:
# 	 [Job 49] Cached (feat_level12_sst_hp.session_info_getter).
# 221003-10:05:42,458 nipype.workflow INFO:
# 	 [Job 73] Cached (feat_level12_sst_hp.specifymodel1).
# 221003-10:05:42,466 nipype.workflow INFO:
# 	 [Job 74] Cached (feat_level12_sst_hp.specifymodel1).
# 221003-10:05:42,509 nipype.workflow INFO:
# 	 [Job 88] Cached (feat_level12_sst_hp.level1design).
# 221003-10:05:42,539 nipype.workflow INFO:
# 	 [Job 89] Cached (feat_level12_sst_hp.level1design).
# 221003-10:05:42,668 nipype.workflow INFO:
# 	 [Job 313] Cached (_session_info_getter0).
# 221003-10:05:42,669 nipype.workflow INFO:
# 	 [Job 314] Cached (_session_info_getter1).
# 221003-10:05:42,671 nipype.workflow INFO:
# 	 [Job 315] Cached (_session_info_getter2).
# 221003-10:05:42,672 nipype.workflow INFO:
# 	 [Job 316] Cached (_session_info_getter0).
# 221003-10:05:42,673 nipype.workflow INFO:
# 	 [Job 317] Cached (_session_info_getter1).
# 221003-10:05:44,370 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 37 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:05:44,425 nipype.workflow INFO:
# 	 [Job 51] Cached (feat_level12_sst_hp.session_info_getter).
# 221003-10:05:44,431 nipype.workflow INFO:
# 	 [Job 75] Cached (feat_level12_sst_hp.specifymodel1).
# 221003-10:05:44,464 nipype.workflow INFO:
# 	 [Job 90] Cached (feat_level12_sst_hp.level1design).
# 221003-10:05:44,496 nipype.workflow INFO:
# 	 [Job 91] Cached (feat_level12_sst_hp.level1design).
# 221003-10:05:44,586 nipype.workflow INFO:
# 	 [Job 318] Cached (_session_info_getter2).
# 221003-10:05:44,587 nipype.workflow INFO:
# 	 [Job 319] Cached (_session_info_getter0).
# 221003-10:05:44,588 nipype.workflow INFO:
# 	 [Job 320] Cached (_session_info_getter1).
# 221003-10:05:44,590 nipype.workflow INFO:
# 	 [Job 321] Cached (_session_info_getter2).
# 221003-10:05:44,591 nipype.workflow INFO:
# 	 [Job 322] Cached (_session_info_getter0).
# 221003-10:05:44,592 nipype.workflow INFO:
# 	 [Job 323] Cached (_session_info_getter1).
# 221003-10:05:46,431 nipype.workflow INFO:
# 	 [Job 53] Cached (feat_level12_sst_hp.session_info_getter).
# 221003-10:05:46,434 nipype.workflow INFO:
# 	 [Job 55] Cached (feat_level12_sst_hp.session_info_getter).
# 221003-10:05:46,441 nipype.workflow INFO:
# 	 [Job 76] Cached (feat_level12_sst_hp.specifymodel1).
# 221003-10:05:46,483 nipype.workflow INFO:
# 	 [Job 92] Cached (feat_level12_sst_hp.level1design).
# 221003-10:05:46,573 nipype.workflow INFO:
# 	 [Job 324] Cached (_session_info_getter2).
# 221003-10:05:46,574 nipype.workflow INFO:
# 	 [Job 325] Cached (_session_info_getter0).
# 221003-10:05:46,575 nipype.workflow INFO:
# 	 [Job 326] Cached (_session_info_getter1).
# 221003-10:05:46,576 nipype.workflow INFO:
# 	 [Job 327] Cached (_session_info_getter2).
# 221003-10:05:46,577 nipype.workflow INFO:
# 	 [Job 328] Cached (_session_info_getter0).
# 221003-10:05:46,578 nipype.workflow INFO:
# 	 [Job 329] Cached (_session_info_getter1).
# 221003-10:05:48,432 nipype.workflow INFO:
# 	 [Job 57] Cached (feat_level12_sst_hp.session_info_getter).
# 221003-10:05:48,435 nipype.workflow INFO:
# 	 [Job 59] Cached (feat_level12_sst_hp.session_info_getter).
# 221003-10:05:48,459 nipype.workflow INFO:
# 	 [Job 77] Cached (feat_level12_sst_hp.specifymodel1).
# 221003-10:05:48,465 nipype.workflow INFO:
# 	 [Job 78] Cached (feat_level12_sst_hp.specifymodel1).
# 221003-10:05:48,497 nipype.workflow INFO:
# 	 [Job 93] Cached (feat_level12_sst_hp.level1design).
# 221003-10:05:48,532 nipype.workflow INFO:
# 	 [Job 330] Cached (_session_info_getter2).
# 221003-10:05:48,533 nipype.workflow INFO:
# 	 [Job 331] Cached (_session_info_getter0).
# 221003-10:05:48,534 nipype.workflow INFO:
# 	 [Job 332] Cached (_session_info_getter1).
# 221003-10:05:48,535 nipype.workflow INFO:
# 	 [Job 333] Cached (_session_info_getter2).
# 221003-10:05:48,536 nipype.workflow INFO:
# 	 [Job 334] Cached (_session_info_getter0).
# 221003-10:05:50,374 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 36 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:05:50,437 nipype.workflow INFO:
# 	 [Job 61] Cached (feat_level12_sst_hp.session_info_getter).
# 221003-10:05:50,439 nipype.workflow INFO:
# 	 [Job 63] Cached (feat_level12_sst_hp.session_info_getter).
# 221003-10:05:50,463 nipype.workflow INFO:
# 	 [Job 79] Cached (feat_level12_sst_hp.specifymodel1).
# 221003-10:05:50,469 nipype.workflow INFO:
# 	 [Job 80] Cached (feat_level12_sst_hp.specifymodel1).
# 221003-10:05:50,502 nipype.workflow INFO:
# 	 [Job 94] Cached (feat_level12_sst_hp.level1design).
# 221003-10:05:50,520 nipype.workflow INFO:
# 	 [Job 95] Cached (feat_level12_sst_hp.level1design).
# 221003-10:05:50,572 nipype.workflow INFO:
# 	 [Job 335] Cached (_session_info_getter1).
# 221003-10:05:50,574 nipype.workflow INFO:
# 	 [Job 336] Cached (_session_info_getter2).
# 221003-10:05:50,575 nipype.workflow INFO:
# 	 [Job 337] Cached (_session_info_getter0).
# 221003-10:05:50,576 nipype.workflow INFO:
# 	 [Job 338] Cached (_session_info_getter1).
# 221003-10:05:52,374 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 35 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:05:52,433 nipype.workflow INFO:
# 	 [Job 65] Cached (feat_level12_sst_hp.session_info_getter).
# 221003-10:05:52,441 nipype.workflow INFO:
# 	 [Job 81] Cached (feat_level12_sst_hp.specifymodel1).
# 221003-10:05:52,447 nipype.workflow INFO:
# 	 [Job 82] Cached (feat_level12_sst_hp.specifymodel1).
# 221003-10:05:52,465 nipype.workflow INFO:
# 	 [Job 96] Cached (feat_level12_sst_hp.level1design).
# 221003-10:05:52,481 nipype.workflow INFO:
# 	 [Job 97] Cached (feat_level12_sst_hp.level1design).
# 221003-10:05:52,583 nipype.workflow INFO:
# 	 [Job 339] Cached (_session_info_getter2).
# 221003-10:05:52,584 nipype.workflow INFO:
# 	 [Job 340] Cached (_modelgen0).
# 221003-10:05:52,586 nipype.workflow INFO:
# 	 [Job 341] Cached (_modelgen1).
# 221003-10:05:52,587 nipype.workflow INFO:
# 	 [Job 342] Cached (_modelgen2).
# 221003-10:05:52,588 nipype.workflow INFO:
# 	 [Job 343] Cached (_modelgen0).
# 221003-10:05:54,376 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 36 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:05:54,442 nipype.workflow INFO:
# 	 [Job 67] Cached (feat_level12_sst_hp.session_info_getter).
# 221003-10:05:54,474 nipype.workflow INFO:
# 	 [Job 83] Cached (feat_level12_sst_hp.specifymodel1).
# 221003-10:05:54,504 nipype.workflow INFO:
# 	 [Job 98] Cached (feat_level12_sst_hp.level1design).
# 221003-10:05:54,521 nipype.workflow INFO:
# 	 [Job 99] Cached (feat_level12_sst_hp.level1design).
# 221003-10:05:54,524 nipype.workflow INFO:
# 	 [Job 102] Cached (feat_level12_sst_hp.modelgen).
# 221003-10:05:54,628 nipype.workflow INFO:
# 	 [Job 344] Cached (_modelgen1).
# 221003-10:05:54,629 nipype.workflow INFO:
# 	 [Job 345] Cached (_modelgen2).
# 221003-10:05:54,630 nipype.workflow INFO:
# 	 [Job 346] Cached (_modelgen0).
# 221003-10:05:54,631 nipype.workflow INFO:
# 	 [Job 347] Cached (_modelgen1).
# 221003-10:05:54,632 nipype.workflow INFO:
# 	 [Job 348] Cached (_modelgen2).
# 221003-10:05:56,378 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 37 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:05:56,434 nipype.workflow INFO:
# 	 [Job 84] Cached (feat_level12_sst_hp.specifymodel1).
# 221003-10:05:56,450 nipype.workflow INFO:
# 	 [Job 100] Cached (feat_level12_sst_hp.level1design).
# 221003-10:05:56,453 nipype.workflow INFO:
# 	 [Job 103] Cached (feat_level12_sst_hp.modelgen).
# 221003-10:05:56,457 nipype.workflow INFO:
# 	 [Job 104] Cached (feat_level12_sst_hp.modelgen).
# 221003-10:05:56,558 nipype.workflow INFO:
# 	 [Job 349] Cached (_modelgen0).
# 221003-10:05:56,559 nipype.workflow INFO:
# 	 [Job 350] Cached (_modelgen1).
# 221003-10:05:56,560 nipype.workflow INFO:
# 	 [Job 351] Cached (_modelgen2).
# 221003-10:05:56,561 nipype.workflow INFO:
# 	 [Job 352] Cached (_modelgen0).
# 221003-10:05:56,562 nipype.workflow INFO:
# 	 [Job 353] Cached (_modelgen1).
# 221003-10:05:56,564 nipype.workflow INFO:
# 	 [Job 354] Cached (_modelgen2).
# 221003-10:05:58,378 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 39 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:05:58,468 nipype.workflow INFO:
# 	 [Job 101] Cached (feat_level12_sst_hp.level1design).
# 221003-10:05:58,471 nipype.workflow INFO:
# 	 [Job 105] Cached (feat_level12_sst_hp.modelgen).
# 221003-10:05:58,473 nipype.workflow INFO:
# 	 [Job 106] Cached (feat_level12_sst_hp.modelgen).
# 221003-10:05:58,626 nipype.workflow INFO:
# 	 [Job 355] Cached (_modelgen0).
# 221003-10:05:58,627 nipype.workflow INFO:
# 	 [Job 356] Cached (_modelgen1).
# 221003-10:05:58,628 nipype.workflow INFO:
# 	 [Job 357] Cached (_modelgen2).
# 221003-10:05:58,629 nipype.workflow INFO:
# 	 [Job 358] Cached (_modelgen0).
# 221003-10:05:58,630 nipype.workflow INFO:
# 	 [Job 359] Cached (_modelgen1).
# 221003-10:05:58,631 nipype.workflow INFO:
# 	 [Job 360] Cached (_modelgen2).
# 221003-10:05:58,632 nipype.workflow INFO:
# 	 [Job 361] Cached (_modelgen0).
# 221003-10:06:00,380 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 40 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:00,438 nipype.workflow INFO:
# 	 [Job 107] Cached (feat_level12_sst_hp.modelgen).
# 221003-10:06:00,442 nipype.workflow INFO:
# 	 [Job 108] Cached (feat_level12_sst_hp.modelgen).
# 221003-10:06:00,561 nipype.workflow INFO:
# 	 [Job 362] Cached (_modelgen1).
# 221003-10:06:00,562 nipype.workflow INFO:
# 	 [Job 363] Cached (_modelgen2).
# 221003-10:06:00,563 nipype.workflow INFO:
# 	 [Job 364] Cached (_modelgen0).
# 221003-10:06:00,564 nipype.workflow INFO:
# 	 [Job 365] Cached (_modelgen1).
# 221003-10:06:00,566 nipype.workflow INFO:
# 	 [Job 366] Cached (_modelgen2).
# 221003-10:06:00,567 nipype.workflow INFO:
# 	 [Job 367] Cached (_modelgen0).
# 221003-10:06:00,568 nipype.workflow INFO:
# 	 [Job 368] Cached (_modelgen1).
# 221003-10:06:00,569 nipype.workflow INFO:
# 	 [Job 369] Cached (_modelgen2).
# 221003-10:06:02,382 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 41 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:02,433 nipype.workflow INFO:
# 	 [Job 109] Cached (feat_level12_sst_hp.modelgen).
# 221003-10:06:02,436 nipype.workflow INFO:
# 	 [Job 110] Cached (feat_level12_sst_hp.modelgen).
# 221003-10:06:02,439 nipype.workflow INFO:
# 	 [Job 111] Cached (feat_level12_sst_hp.modelgen).
# 221003-10:06:02,542 nipype.workflow INFO:
# 	 [Job 370] Cached (_modelgen0).
# 221003-10:06:02,543 nipype.workflow INFO:
# 	 [Job 371] Cached (_modelgen1).
# 221003-10:06:02,544 nipype.workflow INFO:
# 	 [Job 372] Cached (_modelgen2).
# 221003-10:06:02,545 nipype.workflow INFO:
# 	 [Job 373] Cached (_modelgen0).
# 221003-10:06:02,546 nipype.workflow INFO:
# 	 [Job 374] Cached (_modelgen1).
# 221003-10:06:02,547 nipype.workflow INFO:
# 	 [Job 375] Cached (_modelgen2).
# 221003-10:06:02,548 nipype.workflow INFO:
# 	 [Job 376] Cached (_modelgen0).
# 221003-10:06:04,383 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 40 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:04,439 nipype.workflow INFO:
# 	 [Job 112] Cached (feat_level12_sst_hp.modelgen).
# 221003-10:06:04,442 nipype.workflow INFO:
# 	 [Job 113] Cached (feat_level12_sst_hp.modelgen).
# 221003-10:06:04,569 nipype.workflow INFO:
# 	 [Job 377] Cached (_modelgen1).
# 221003-10:06:04,571 nipype.workflow INFO:
# 	 [Job 378] Cached (_modelgen2).
# 221003-10:06:04,572 nipype.workflow INFO:
# 	 [Job 379] Cached (_modelgen0).
# 221003-10:06:04,573 nipype.workflow INFO:
# 	 [Job 380] Cached (_modelgen1).
# 221003-10:06:04,574 nipype.workflow INFO:
# 	 [Job 381] Cached (_modelgen2).
# 221003-10:06:04,576 nipype.workflow INFO:
# 	 [Job 382] Cached (_modelgen0).
# 221003-10:06:04,577 nipype.workflow INFO:
# 	 [Job 383] Cached (_modelgen1).
# 221003-10:06:04,578 nipype.workflow INFO:
# 	 [Job 384] Cached (_modelgen2).
# 221003-10:06:06,385 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 41 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:06,450 nipype.workflow INFO:
# 	 [Job 114] Cached (feat_level12_sst_hp.modelgen).
# 221003-10:06:06,454 nipype.workflow INFO:
# 	 [Job 115] Cached (feat_level12_sst_hp.modelgen).
# 221003-10:06:06,458 nipype.workflow INFO:
# 	 [Job 116] Cached (feat_level12_sst_hp.modelgen).
# 221003-10:06:06,557 nipype.workflow INFO:
# 	 [Job 385] Cached (_modelestimate0).
# 221003-10:06:06,558 nipype.workflow INFO:
# 	 [Job 386] Cached (_modelestimate1).
# 221003-10:06:06,559 nipype.workflow INFO:
# 	 [Job 387] Cached (_modelestimate2).
# 221003-10:06:06,561 nipype.workflow INFO:
# 	 [Job 388] Cached (_modelgen0).
# 221003-10:06:06,562 nipype.workflow INFO:
# 	 [Job 389] Cached (_modelgen1).
# 221003-10:06:06,563 nipype.workflow INFO:
# 	 [Job 390] Cached (_modelgen2).
# 221003-10:06:06,565 nipype.workflow INFO:
# 	 [Job 391] Cached (_modelestimate0).
# 221003-10:06:08,386 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 40 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:08,440 nipype.workflow INFO:
# 	 [Job 117] Cached (feat_level12_sst_hp.modelgen).
# 221003-10:06:08,444 nipype.workflow INFO:
# 	 [Job 119] Cached (feat_level12_sst_hp.modelestimate).
# 221003-10:06:08,580 nipype.workflow INFO:
# 	 [Job 392] Cached (_modelestimate1).
# 221003-10:06:08,581 nipype.workflow INFO:
# 	 [Job 393] Cached (_modelestimate2).
# 221003-10:06:08,583 nipype.workflow INFO:
# 	 [Job 394] Cached (_modelestimate0).
# 221003-10:06:08,584 nipype.workflow INFO:
# 	 [Job 395] Cached (_modelestimate1).
# 221003-10:06:08,586 nipype.workflow INFO:
# 	 [Job 396] Cached (_modelestimate2).
# 221003-10:06:08,587 nipype.workflow INFO:
# 	 [Job 397] Cached (_modelgen0).
# 221003-10:06:08,588 nipype.workflow INFO:
# 	 [Job 398] Cached (_modelgen1).
# 221003-10:06:08,589 nipype.workflow INFO:
# 	 [Job 399] Cached (_modelgen2).
# 221003-10:06:10,387 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 43 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:10,438 nipype.workflow INFO:
# 	 [Job 118] Cached (feat_level12_sst_hp.modelgen).
# 221003-10:06:10,443 nipype.workflow INFO:
# 	 [Job 120] Cached (feat_level12_sst_hp.modelestimate).
# 221003-10:06:10,446 nipype.workflow INFO:
# 	 [Job 121] Cached (feat_level12_sst_hp.modelestimate).
# 221003-10:06:10,589 nipype.workflow INFO:
# 	 [Job 138] Cached (feat_level12_sst_hp.l2model).
# 221003-10:06:10,591 nipype.workflow INFO:
# 	 [Job 400] Cached (_modelestimate0).
# 221003-10:06:10,592 nipype.workflow INFO:
# 	 [Job 401] Cached (_modelestimate1).
# 221003-10:06:10,593 nipype.workflow INFO:
# 	 [Job 402] Cached (_modelestimate2).
# 221003-10:06:10,594 nipype.workflow INFO:
# 	 [Job 403] Cached (_modelestimate0).
# 221003-10:06:10,596 nipype.workflow INFO:
# 	 [Job 404] Cached (_modelestimate1).
# 221003-10:06:10,597 nipype.workflow INFO:
# 	 [Job 405] Cached (_modelestimate2).
# 221003-10:06:12,388 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 54 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:12,449 nipype.workflow INFO:
# 	 [Job 122] Cached (feat_level12_sst_hp.modelestimate).
# 221003-10:06:12,453 nipype.workflow INFO:
# 	 [Job 123] Cached (feat_level12_sst_hp.modelestimate).
# 221003-10:06:12,581 nipype.workflow INFO:
# 	 [Job 141] Cached (feat_level12_sst_hp.l2model).
# 221003-10:06:12,685 nipype.workflow INFO:
# 	 [Job 144] Cached (feat_level12_sst_hp.l2model).
# 221003-10:06:12,686 nipype.workflow INFO:
# 	 [Job 406] Cached (_modelestimate0).
# 221003-10:06:12,688 nipype.workflow INFO:
# 	 [Job 407] Cached (_modelestimate1).
# 221003-10:06:12,689 nipype.workflow INFO:
# 	 [Job 408] Cached (_modelestimate2).
# 221003-10:06:12,690 nipype.workflow INFO:
# 	 [Job 409] Cached (_modelestimate0).
# 221003-10:06:12,691 nipype.workflow INFO:
# 	 [Job 410] Cached (_modelestimate1).
# 221003-10:06:12,692 nipype.workflow INFO:
# 	 [Job 411] Cached (_modelestimate2).
# 221003-10:06:14,389 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 74 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:14,449 nipype.workflow INFO:
# 	 [Job 124] Cached (feat_level12_sst_hp.modelestimate).
# 221003-10:06:14,454 nipype.workflow INFO:
# 	 [Job 125] Cached (feat_level12_sst_hp.modelestimate).
# 221003-10:06:14,550 nipype.workflow INFO:
# 	 [Job 147] Cached (feat_level12_sst_hp.l2model).
# 221003-10:06:14,613 nipype.workflow INFO:
# 	 [Job 150] Cached (feat_level12_sst_hp.l2model).
# 221003-10:06:14,614 nipype.workflow INFO:
# 	 [Job 412] Cached (_modelestimate0).
# 221003-10:06:14,616 nipype.workflow INFO:
# 	 [Job 413] Cached (_modelestimate1).
# 221003-10:06:14,617 nipype.workflow INFO:
# 	 [Job 414] Cached (_modelestimate2).
# 221003-10:06:14,618 nipype.workflow INFO:
# 	 [Job 415] Cached (_modelestimate0).
# 221003-10:06:14,619 nipype.workflow INFO:
# 	 [Job 416] Cached (_modelestimate1).
# 221003-10:06:14,620 nipype.workflow INFO:
# 	 [Job 417] Cached (_modelestimate2).
# 221003-10:06:16,391 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 92 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:16,461 nipype.workflow INFO:
# 	 [Job 126] Cached (feat_level12_sst_hp.modelestimate).
# 221003-10:06:16,466 nipype.workflow INFO:
# 	 [Job 127] Cached (feat_level12_sst_hp.modelestimate).
# 221003-10:06:16,539 nipype.workflow INFO:
# 	 [Job 153] Cached (feat_level12_sst_hp.l2model).
# 221003-10:06:16,623 nipype.workflow INFO:
# 	 [Job 156] Cached (feat_level12_sst_hp.l2model).
# 221003-10:06:16,625 nipype.workflow INFO:
# 	 [Job 418] Cached (_modelestimate0).
# 221003-10:06:16,626 nipype.workflow INFO:
# 	 [Job 419] Cached (_modelestimate1).
# 221003-10:06:16,628 nipype.workflow INFO:
# 	 [Job 420] Cached (_modelestimate2).
# 221003-10:06:16,629 nipype.workflow INFO:
# 	 [Job 421] Cached (_modelestimate0).
# 221003-10:06:16,630 nipype.workflow INFO:
# 	 [Job 422] Cached (_modelestimate1).
# 221003-10:06:16,631 nipype.workflow INFO:
# 	 [Job 423] Cached (_modelestimate2).
# 221003-10:06:18,393 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 110 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:18,454 nipype.workflow INFO:
# 	 [Job 128] Cached (feat_level12_sst_hp.modelestimate).
# 221003-10:06:18,457 nipype.workflow INFO:
# 	 [Job 129] Cached (feat_level12_sst_hp.modelestimate).
# 221003-10:06:18,504 nipype.workflow INFO:
# 	 [Job 159] Cached (feat_level12_sst_hp.l2model).
# 221003-10:06:18,577 nipype.workflow INFO:
# 	 [Job 162] Cached (feat_level12_sst_hp.l2model).
# 221003-10:06:18,578 nipype.workflow INFO:
# 	 [Job 424] Cached (_modelestimate0).
# 221003-10:06:18,579 nipype.workflow INFO:
# 	 [Job 425] Cached (_modelestimate1).
# 221003-10:06:18,580 nipype.workflow INFO:
# 	 [Job 426] Cached (_modelestimate2).
# 221003-10:06:18,581 nipype.workflow INFO:
# 	 [Job 427] Cached (_modelestimate0).
# 221003-10:06:18,582 nipype.workflow INFO:
# 	 [Job 428] Cached (_modelestimate1).
# 221003-10:06:18,583 nipype.workflow INFO:
# 	 [Job 429] Cached (_modelestimate2).
# 221003-10:06:20,394 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 128 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:20,448 nipype.workflow INFO:
# 	 [Job 130] Cached (feat_level12_sst_hp.modelestimate).
# 221003-10:06:20,451 nipype.workflow INFO:
# 	 [Job 131] Cached (feat_level12_sst_hp.modelestimate).
# 221003-10:06:20,499 nipype.workflow INFO:
# 	 [Job 165] Cached (feat_level12_sst_hp.l2model).
# 221003-10:06:20,557 nipype.workflow INFO:
# 	 [Job 168] Cached (feat_level12_sst_hp.l2model).
# 221003-10:06:20,558 nipype.workflow INFO:
# 	 [Job 430] Cached (_modelestimate0).
# 221003-10:06:20,559 nipype.workflow INFO:
# 	 [Job 431] Cached (_modelestimate1).
# 221003-10:06:20,560 nipype.workflow INFO:
# 	 [Job 432] Cached (_modelestimate2).
# 221003-10:06:20,561 nipype.workflow INFO:
# 	 [Job 433] Cached (_modelestimate0).
# 221003-10:06:20,562 nipype.workflow INFO:
# 	 [Job 434] Cached (_modelestimate1).
# 221003-10:06:20,563 nipype.workflow INFO:
# 	 [Job 435] Cached (_modelestimate2).
# 221003-10:06:22,397 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 146 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:22,456 nipype.workflow INFO:
# 	 [Job 132] Cached (feat_level12_sst_hp.modelestimate).
# 221003-10:06:22,459 nipype.workflow INFO:
# 	 [Job 133] Cached (feat_level12_sst_hp.modelestimate).
# 221003-10:06:22,504 nipype.workflow INFO:
# 	 [Job 171] Cached (feat_level12_sst_hp.l2model).
# 221003-10:06:22,557 nipype.workflow INFO:
# 	 [Job 174] Cached (feat_level12_sst_hp.l2model).
# 221003-10:06:22,559 nipype.workflow INFO:
# 	 [Job 436] Cached (_modelestimate0).
# 221003-10:06:22,560 nipype.workflow INFO:
# 	 [Job 437] Cached (_modelestimate1).
# 221003-10:06:22,561 nipype.workflow INFO:
# 	 [Job 438] Cached (_modelestimate2).
# 221003-10:06:22,562 nipype.workflow INFO:
# 	 [Job 439] Cached (_copemerge0).
# 221003-10:06:22,563 nipype.workflow INFO:
# 	 [Job 440] Cached (_copemerge1).
# 221003-10:06:22,564 nipype.workflow INFO:
# 	 [Job 441] Cached (_copemerge2).
# 221003-10:06:24,399 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 163 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:24,465 nipype.workflow INFO:
# 	 [Job 134] Cached (feat_level12_sst_hp.modelestimate).
# 221003-10:06:24,526 nipype.workflow INFO:
# 	 [Job 177] Cached (feat_level12_sst_hp.l2model).
# 221003-10:06:24,599 nipype.workflow INFO:
# 	 [Job 180] Cached (feat_level12_sst_hp.l2model).
# 221003-10:06:24,601 nipype.workflow INFO:
# 	 [Job 442] Cached (_copemerge3).
# 221003-10:06:24,602 nipype.workflow INFO:
# 	 [Job 443] Cached (_copemerge4).
# 221003-10:06:24,603 nipype.workflow INFO:
# 	 [Job 444] Cached (_copemerge5).
# 221003-10:06:24,604 nipype.workflow INFO:
# 	 [Job 445] Cached (_varcopemerge0).
# 221003-10:06:24,605 nipype.workflow INFO:
# 	 [Job 446] Cached (_varcopemerge1).
# 221003-10:06:24,606 nipype.workflow INFO:
# 	 [Job 447] Cached (_varcopemerge2).
# 221003-10:06:24,607 nipype.workflow INFO:
# 	 [Job 448] Cached (_varcopemerge3).
# 221003-10:06:26,400 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 177 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:26,454 nipype.workflow INFO:
# 	 [Job 136] Cached (feat_level12_sst_hp.copemerge).
# 221003-10:06:26,556 nipype.workflow INFO:
# 	 [Job 183] Cached (feat_level12_sst_hp.l2model).
# 221003-10:06:26,558 nipype.workflow INFO:
# 	 [Job 449] Cached (_varcopemerge4).
# 221003-10:06:26,559 nipype.workflow INFO:
# 	 [Job 450] Cached (_varcopemerge5).
# 221003-10:06:26,561 nipype.workflow INFO:
# 	 [Job 451] Cached (_modelestimate0).
# 221003-10:06:26,562 nipype.workflow INFO:
# 	 [Job 452] Cached (_modelestimate1).
# 221003-10:06:26,563 nipype.workflow INFO:
# 	 [Job 453] Cached (_modelestimate2).
# 221003-10:06:26,564 nipype.workflow INFO:
# 	 [Job 454] Cached (_copemerge0).
# 221003-10:06:26,564 nipype.workflow INFO:
# 	 [Job 455] Cached (_copemerge1).
# 221003-10:06:26,565 nipype.workflow INFO:
# 	 [Job 456] Cached (_copemerge2).
# 221003-10:06:28,404 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 179 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:28,486 nipype.workflow INFO:
# 	 [Job 135] Cached (feat_level12_sst_hp.modelestimate).
# 221003-10:06:28,490 nipype.workflow INFO:
# 	 [Job 137] Cached (feat_level12_sst_hp.varcopemerge).
# 221003-10:06:28,492 nipype.workflow INFO:
# 	 [Job 457] Cached (_copemerge3).
# 221003-10:06:28,493 nipype.workflow INFO:
# 	 [Job 458] Cached (_copemerge4).
# 221003-10:06:28,494 nipype.workflow INFO:
# 	 [Job 459] Cached (_copemerge5).
# 221003-10:06:28,495 nipype.workflow INFO:
# 	 [Job 460] Cached (_varcopemerge0).
# 221003-10:06:28,496 nipype.workflow INFO:
# 	 [Job 461] Cached (_varcopemerge1).
# 221003-10:06:28,497 nipype.workflow INFO:
# 	 [Job 462] Cached (_varcopemerge2).
# 221003-10:06:28,498 nipype.workflow INFO:
# 	 [Job 463] Cached (_varcopemerge3).
# 221003-10:06:28,499 nipype.workflow INFO:
# 	 [Job 464] Cached (_varcopemerge4).
# 221003-10:06:30,404 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 174 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:30,462 nipype.workflow INFO:
# 	 [Job 139] Cached (feat_level12_sst_hp.copemerge).
# 221003-10:06:30,512 nipype.workflow INFO:
# 	 [Job 186] Cached (feat_level12_sst_hp.l2model).
# 221003-10:06:30,575 nipype.workflow INFO:
# 	 [Job 465] Cached (_varcopemerge5).
# 221003-10:06:30,576 nipype.workflow INFO:
# 	 [Job 466] Cached (_copemerge0).
# 221003-10:06:30,577 nipype.workflow INFO:
# 	 [Job 467] Cached (_copemerge1).
# 221003-10:06:30,578 nipype.workflow INFO:
# 	 [Job 468] Cached (_copemerge2).
# 221003-10:06:30,579 nipype.workflow INFO:
# 	 [Job 469] Cached (_copemerge3).
# 221003-10:06:30,580 nipype.workflow INFO:
# 	 [Job 470] Cached (_copemerge4).
# 221003-10:06:30,581 nipype.workflow INFO:
# 	 [Job 471] Cached (_copemerge5).
# 221003-10:06:30,581 nipype.workflow INFO:
# 	 [Job 472] Cached (_varcopemerge0).
# 221003-10:06:32,407 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 181 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:32,465 nipype.workflow INFO:
# 	 [Job 140] Cached (feat_level12_sst_hp.varcopemerge).
# 221003-10:06:32,468 nipype.workflow INFO:
# 	 [Job 142] Cached (feat_level12_sst_hp.copemerge).
# 221003-10:06:32,469 nipype.workflow INFO:
# 	 [Job 473] Cached (_varcopemerge1).
# 221003-10:06:32,470 nipype.workflow INFO:
# 	 [Job 474] Cached (_varcopemerge2).
# 221003-10:06:32,471 nipype.workflow INFO:
# 	 [Job 475] Cached (_varcopemerge3).
# 221003-10:06:32,472 nipype.workflow INFO:
# 	 [Job 476] Cached (_varcopemerge4).
# 221003-10:06:32,473 nipype.workflow INFO:
# 	 [Job 477] Cached (_varcopemerge5).
# 221003-10:06:32,474 nipype.workflow INFO:
# 	 [Job 478] Cached (_copemerge0).
# 221003-10:06:32,475 nipype.workflow INFO:
# 	 [Job 479] Cached (_copemerge1).
# 221003-10:06:32,475 nipype.workflow INFO:
# 	 [Job 480] Cached (_copemerge2).
# 221003-10:06:34,408 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 173 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:34,462 nipype.workflow INFO:
# 	 [Job 143] Cached (feat_level12_sst_hp.varcopemerge).
# 221003-10:06:34,629 nipype.workflow INFO:
# 	 [Job 481] Cached (_copemerge3).
# 221003-10:06:34,630 nipype.workflow INFO:
# 	 [Job 482] Cached (_copemerge4).
# 221003-10:06:34,631 nipype.workflow INFO:
# 	 [Job 483] Cached (_copemerge5).
# 221003-10:06:34,632 nipype.workflow INFO:
# 	 [Job 484] Cached (_varcopemerge0).
# 221003-10:06:34,633 nipype.workflow INFO:
# 	 [Job 485] Cached (_varcopemerge1).
# 221003-10:06:34,634 nipype.workflow INFO:
# 	 [Job 486] Cached (_varcopemerge2).
# 221003-10:06:34,635 nipype.workflow INFO:
# 	 [Job 487] Cached (_varcopemerge3).
# 221003-10:06:34,636 nipype.workflow INFO:
# 	 [Job 488] Cached (_varcopemerge4).
# 221003-10:06:34,637 nipype.workflow INFO:
# 	 [Job 489] Cached (_varcopemerge5).
# 221003-10:06:36,411 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 171 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:36,516 nipype.workflow INFO:
# 	 [Job 145] Cached (feat_level12_sst_hp.copemerge).
# 221003-10:06:36,520 nipype.workflow INFO:
# 	 [Job 146] Cached (feat_level12_sst_hp.varcopemerge).
# 221003-10:06:36,629 nipype.workflow INFO:
# 	 [Job 490] Cached (_copemerge0).
# 221003-10:06:36,631 nipype.workflow INFO:
# 	 [Job 491] Cached (_copemerge1).
# 221003-10:06:36,632 nipype.workflow INFO:
# 	 [Job 492] Cached (_copemerge2).
# 221003-10:06:36,633 nipype.workflow INFO:
# 	 [Job 493] Cached (_copemerge3).
# 221003-10:06:36,634 nipype.workflow INFO:
# 	 [Job 494] Cached (_copemerge4).
# 221003-10:06:36,636 nipype.workflow INFO:
# 	 [Job 495] Cached (_copemerge5).
# 221003-10:06:36,637 nipype.workflow INFO:
# 	 [Job 496] Cached (_varcopemerge0).
# 221003-10:06:36,638 nipype.workflow INFO:
# 	 [Job 497] Cached (_varcopemerge1).
# 221003-10:06:38,411 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 168 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:38,479 nipype.workflow INFO:
# 	 [Job 148] Cached (feat_level12_sst_hp.copemerge).
# 221003-10:06:38,562 nipype.workflow INFO:
# 	 [Job 498] Cached (_varcopemerge2).
# 221003-10:06:38,564 nipype.workflow INFO:
# 	 [Job 499] Cached (_varcopemerge3).
# 221003-10:06:38,565 nipype.workflow INFO:
# 	 [Job 500] Cached (_varcopemerge4).
# 221003-10:06:38,566 nipype.workflow INFO:
# 	 [Job 501] Cached (_varcopemerge5).
# 221003-10:06:38,567 nipype.workflow INFO:
# 	 [Job 502] Cached (_copemerge0).
# 221003-10:06:38,568 nipype.workflow INFO:
# 	 [Job 503] Cached (_copemerge1).
# 221003-10:06:38,569 nipype.workflow INFO:
# 	 [Job 504] Cached (_copemerge2).
# 221003-10:06:38,570 nipype.workflow INFO:
# 	 [Job 505] Cached (_copemerge3).
# 221003-10:06:38,571 nipype.workflow INFO:
# 	 [Job 506] Cached (_copemerge4).
# 221003-10:06:40,413 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 164 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:40,472 nipype.workflow INFO:
# 	 [Job 149] Cached (feat_level12_sst_hp.varcopemerge).
# 221003-10:06:40,474 nipype.workflow INFO:
# 	 [Job 507] Cached (_copemerge5).
# 221003-10:06:40,474 nipype.workflow INFO:
# 	 [Job 508] Cached (_varcopemerge0).
# 221003-10:06:40,475 nipype.workflow INFO:
# 	 [Job 509] Cached (_varcopemerge1).
# 221003-10:06:40,476 nipype.workflow INFO:
# 	 [Job 510] Cached (_varcopemerge2).
# 221003-10:06:40,477 nipype.workflow INFO:
# 	 [Job 511] Cached (_varcopemerge3).
# 221003-10:06:40,478 nipype.workflow INFO:
# 	 [Job 512] Cached (_varcopemerge4).
# 221003-10:06:40,479 nipype.workflow INFO:
# 	 [Job 513] Cached (_varcopemerge5).
# 221003-10:06:40,480 nipype.workflow INFO:
# 	 [Job 514] Cached (_copemerge0).
# 221003-10:06:40,481 nipype.workflow INFO:
# 	 [Job 515] Cached (_copemerge1).
# 221003-10:06:42,415 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 157 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:42,472 nipype.workflow INFO:
# 	 [Job 151] Cached (feat_level12_sst_hp.copemerge).
# 221003-10:06:42,475 nipype.workflow INFO:
# 	 [Job 152] Cached (feat_level12_sst_hp.varcopemerge).
# 221003-10:06:42,563 nipype.workflow INFO:
# 	 [Job 516] Cached (_copemerge2).
# 221003-10:06:42,564 nipype.workflow INFO:
# 	 [Job 517] Cached (_copemerge3).
# 221003-10:06:42,565 nipype.workflow INFO:
# 	 [Job 518] Cached (_copemerge4).
# 221003-10:06:42,567 nipype.workflow INFO:
# 	 [Job 519] Cached (_copemerge5).
# 221003-10:06:42,568 nipype.workflow INFO:
# 	 [Job 520] Cached (_varcopemerge0).
# 221003-10:06:42,569 nipype.workflow INFO:
# 	 [Job 521] Cached (_varcopemerge1).
# 221003-10:06:42,571 nipype.workflow INFO:
# 	 [Job 522] Cached (_varcopemerge2).
# 221003-10:06:42,572 nipype.workflow INFO:
# 	 [Job 523] Cached (_varcopemerge3).
# 221003-10:06:44,417 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 154 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:44,482 nipype.workflow INFO:
# 	 [Job 154] Cached (feat_level12_sst_hp.copemerge).
# 221003-10:06:44,574 nipype.workflow INFO:
# 	 [Job 524] Cached (_varcopemerge4).
# 221003-10:06:44,575 nipype.workflow INFO:
# 	 [Job 525] Cached (_varcopemerge5).
# 221003-10:06:44,576 nipype.workflow INFO:
# 	 [Job 526] Cached (_copemerge0).
# 221003-10:06:44,577 nipype.workflow INFO:
# 	 [Job 527] Cached (_copemerge1).
# 221003-10:06:44,578 nipype.workflow INFO:
# 	 [Job 528] Cached (_copemerge2).
# 221003-10:06:44,579 nipype.workflow INFO:
# 	 [Job 529] Cached (_copemerge3).
# 221003-10:06:44,580 nipype.workflow INFO:
# 	 [Job 530] Cached (_copemerge4).
# 221003-10:06:44,580 nipype.workflow INFO:
# 	 [Job 531] Cached (_copemerge5).
# 221003-10:06:44,581 nipype.workflow INFO:
# 	 [Job 532] Cached (_varcopemerge0).
# 221003-10:06:46,419 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 151 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:46,487 nipype.workflow INFO:
# 	 [Job 155] Cached (feat_level12_sst_hp.varcopemerge).
# 221003-10:06:46,491 nipype.workflow INFO:
# 	 [Job 157] Cached (feat_level12_sst_hp.copemerge).
# 221003-10:06:46,493 nipype.workflow INFO:
# 	 [Job 533] Cached (_varcopemerge1).
# 221003-10:06:46,494 nipype.workflow INFO:
# 	 [Job 534] Cached (_varcopemerge2).
# 221003-10:06:46,495 nipype.workflow INFO:
# 	 [Job 535] Cached (_varcopemerge3).
# 221003-10:06:46,496 nipype.workflow INFO:
# 	 [Job 536] Cached (_varcopemerge4).
# 221003-10:06:46,497 nipype.workflow INFO:
# 	 [Job 537] Cached (_varcopemerge5).
# 221003-10:06:46,498 nipype.workflow INFO:
# 	 [Job 538] Cached (_copemerge0).
# 221003-10:06:46,499 nipype.workflow INFO:
# 	 [Job 539] Cached (_copemerge1).
# 221003-10:06:46,500 nipype.workflow INFO:
# 	 [Job 540] Cached (_copemerge2).
# 221003-10:06:48,419 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 143 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:48,484 nipype.workflow INFO:
# 	 [Job 158] Cached (feat_level12_sst_hp.varcopemerge).
# 221003-10:06:48,604 nipype.workflow INFO:
# 	 [Job 541] Cached (_copemerge3).
# 221003-10:06:48,605 nipype.workflow INFO:
# 	 [Job 542] Cached (_copemerge4).
# 221003-10:06:48,606 nipype.workflow INFO:
# 	 [Job 543] Cached (_copemerge5).
# 221003-10:06:48,607 nipype.workflow INFO:
# 	 [Job 544] Cached (_varcopemerge0).
# 221003-10:06:48,608 nipype.workflow INFO:
# 	 [Job 545] Cached (_varcopemerge1).
# 221003-10:06:48,609 nipype.workflow INFO:
# 	 [Job 546] Cached (_varcopemerge2).
# 221003-10:06:48,610 nipype.workflow INFO:
# 	 [Job 547] Cached (_varcopemerge3).
# 221003-10:06:48,611 nipype.workflow INFO:
# 	 [Job 548] Cached (_varcopemerge4).
# 221003-10:06:48,612 nipype.workflow INFO:
# 	 [Job 549] Cached (_varcopemerge5).
# 221003-10:06:50,422 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 141 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:50,500 nipype.workflow INFO:
# 	 [Job 160] Cached (feat_level12_sst_hp.copemerge).
# 221003-10:06:50,503 nipype.workflow INFO:
# 	 [Job 161] Cached (feat_level12_sst_hp.varcopemerge).
# 221003-10:06:50,559 nipype.workflow INFO:
# 	 [Job 550] Cached (_copemerge0).
# 221003-10:06:50,560 nipype.workflow INFO:
# 	 [Job 551] Cached (_copemerge1).
# 221003-10:06:50,561 nipype.workflow INFO:
# 	 [Job 552] Cached (_copemerge2).
# 221003-10:06:50,562 nipype.workflow INFO:
# 	 [Job 553] Cached (_copemerge3).
# 221003-10:06:50,563 nipype.workflow INFO:
# 	 [Job 554] Cached (_copemerge4).
# 221003-10:06:50,564 nipype.workflow INFO:
# 	 [Job 555] Cached (_copemerge5).
# 221003-10:06:50,565 nipype.workflow INFO:
# 	 [Job 556] Cached (_varcopemerge0).
# 221003-10:06:50,566 nipype.workflow INFO:
# 	 [Job 557] Cached (_varcopemerge1).
# 221003-10:06:52,423 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 138 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:52,483 nipype.workflow INFO:
# 	 [Job 163] Cached (feat_level12_sst_hp.copemerge).
# 221003-10:06:52,580 nipype.workflow INFO:
# 	 [Job 558] Cached (_varcopemerge2).
# 221003-10:06:52,582 nipype.workflow INFO:
# 	 [Job 559] Cached (_varcopemerge3).
# 221003-10:06:52,583 nipype.workflow INFO:
# 	 [Job 560] Cached (_varcopemerge4).
# 221003-10:06:52,584 nipype.workflow INFO:
# 	 [Job 561] Cached (_varcopemerge5).
# 221003-10:06:52,585 nipype.workflow INFO:
# 	 [Job 562] Cached (_copemerge0).
# 221003-10:06:52,586 nipype.workflow INFO:
# 	 [Job 563] Cached (_copemerge1).
# 221003-10:06:52,587 nipype.workflow INFO:
# 	 [Job 564] Cached (_copemerge2).
# 221003-10:06:52,588 nipype.workflow INFO:
# 	 [Job 565] Cached (_copemerge3).
# 221003-10:06:52,589 nipype.workflow INFO:
# 	 [Job 566] Cached (_copemerge4).
# 221003-10:06:54,425 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 134 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:54,481 nipype.workflow INFO:
# 	 [Job 164] Cached (feat_level12_sst_hp.varcopemerge).
# 221003-10:06:54,482 nipype.workflow INFO:
# 	 [Job 567] Cached (_copemerge5).
# 221003-10:06:54,483 nipype.workflow INFO:
# 	 [Job 568] Cached (_varcopemerge0).
# 221003-10:06:54,484 nipype.workflow INFO:
# 	 [Job 569] Cached (_varcopemerge1).
# 221003-10:06:54,485 nipype.workflow INFO:
# 	 [Job 570] Cached (_varcopemerge2).
# 221003-10:06:54,486 nipype.workflow INFO:
# 	 [Job 571] Cached (_varcopemerge3).
# 221003-10:06:54,487 nipype.workflow INFO:
# 	 [Job 572] Cached (_varcopemerge4).
# 221003-10:06:54,488 nipype.workflow INFO:
# 	 [Job 573] Cached (_varcopemerge5).
# 221003-10:06:54,489 nipype.workflow INFO:
# 	 [Job 574] Cached (_copemerge0).
# 221003-10:06:54,489 nipype.workflow INFO:
# 	 [Job 575] Cached (_copemerge1).
# 221003-10:06:56,427 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 127 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:56,491 nipype.workflow INFO:
# 	 [Job 166] Cached (feat_level12_sst_hp.copemerge).
# 221003-10:06:56,494 nipype.workflow INFO:
# 	 [Job 167] Cached (feat_level12_sst_hp.varcopemerge).
# 221003-10:06:56,594 nipype.workflow INFO:
# 	 [Job 576] Cached (_copemerge2).
# 221003-10:06:56,596 nipype.workflow INFO:
# 	 [Job 577] Cached (_copemerge3).
# 221003-10:06:56,597 nipype.workflow INFO:
# 	 [Job 578] Cached (_copemerge4).
# 221003-10:06:56,598 nipype.workflow INFO:
# 	 [Job 579] Cached (_copemerge5).
# 221003-10:06:56,599 nipype.workflow INFO:
# 	 [Job 580] Cached (_varcopemerge0).
# 221003-10:06:56,600 nipype.workflow INFO:
# 	 [Job 581] Cached (_varcopemerge1).
# 221003-10:06:56,601 nipype.workflow INFO:
# 	 [Job 582] Cached (_varcopemerge2).
# 221003-10:06:56,602 nipype.workflow INFO:
# 	 [Job 583] Cached (_varcopemerge3).
# 221003-10:06:58,429 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 124 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 221003-10:06:58,488 nipype.workflow INFO:
# 	 [Job 169] Cached (feat_level12_sst_hp.copemerge).
# 221003-10:06:58,526 nipype.workflow INFO:
# 	 [Job 584] Cached (_varcopemerge4).
# 221003-10:06:58,527 nipype.workflow INFO:
# 	 [Job 585] Cached (_varcopemerge5).
# 221003-10:06:58,528 nipype.workflow INFO:
# 	 [Job 586] Cached (_copemerge0).
# 221003-10:06:58,529 nipype.workflow INFO:
# 	 [Job 587] Cached (_copemerge1).
# 221003-10:06:58,530 nipype.workflow INFO:
# 	 [Job 588] Cached (_copemerge2).
# 221003-10:06:58,531 nipype.workflow INFO:
# 	 [Job 589] Cached (_copemerge3).
# 221003-10:06:58,532 nipype.workflow INFO:
# 	 [Job 590] Cached (_copemerge4).
# 221003-10:06:58,533 nipype.workflow INFO:
# 	 [Job 591] Cached (_copemerge5).
# 221003-10:06:58,534 nipype.workflow INFO:
# 	 [Job 592] Cached (_varcopemerge0).

# %%
from nipype.utils.filemanip import loadpkl
res = loadpkl('/home/scotti/projects/3t_7t_sst_comparison/processing/crashdumps/crash-20220728-174554-scotti-_modelgen2-7ffee7d4-2bae-4519-9ecd-bf5add208a01.pklz')
res
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 275
# {'node': _modelgen2,
#  'traceback': ['Traceback (most recent call last):\n',
#   '  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/pipeline/plugins/multiproc.py", line 67, in run_node\n    result["result"] = node.run(updatehash=updatehash)\n',
#   '  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 521, in run\n    result = self._run_interface(execute=True)\n',
#   '  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 639, in _run_interface\n    return self._run_command(execute)\n',
#   '  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 750, in _run_command\n    raise NodeExecutionError(\n',
#   'nipype.pipeline.engine.nodes.NodeExecutionError: Exception raised while executing Node _modelgen2.\n\nTraceback (most recent call last):\n  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/interfaces/base/core.py", line 401, in run\n    outputs = self.aggregate_outputs(runtime)\n  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/interfaces/base/core.py", line 430, in aggregate_outputs\n    predicted_outputs = self._list_outputs()  # Predictions from _list_outputs\n  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/interfaces/fsl/model.py", line 544, in _list_outputs\n    assert len(design_file) == 1, "No mat file generated by FEAT Model"\nAssertionError: No mat file generated by FEAT Model\n\n']}

# %%
from nipype.utils.filemanip import loadpkl
res = loadpkl('/home/scotti/projects/3t_7t_sst_comparison/processing/crashdumps/crash-20220725-201456-scotti-_modelgen2-853c3a8d-a5d2-434c-9c99-ac3b0735bd4a.pklz')
res
# Out:
# {'node': _modelgen2,
#  'traceback': ['Traceback (most recent call last):\n',
#   '  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/pipeline/plugins/multiproc.py", line 67, in run_node\n    result["result"] = node.run(updatehash=updatehash)\n',
#   '  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 521, in run\n    result = self._run_interface(execute=True)\n',
#   '  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 639, in _run_interface\n    return self._run_command(execute)\n',
#   '  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 750, in _run_command\n    raise NodeExecutionError(\n',
#   'nipype.pipeline.engine.nodes.NodeExecutionError: Exception raised while executing Node _modelgen2.\n\nTraceback (most recent call last):\n  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/interfaces/base/core.py", line 401, in run\n    outputs = self.aggregate_outputs(runtime)\n  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/interfaces/base/core.py", line 430, in aggregate_outputs\n    predicted_outputs = self._list_outputs()  # Predictions from _list_outputs\n  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/interfaces/fsl/model.py", line 544, in _list_outputs\n    assert len(design_file) == 1, "No mat file generated by FEAT Model"\nAssertionError: No mat file generated by FEAT Model\n\n']}
# ERROR! Session/line number was not unique in database. History logging moved to new session 260

# %%
from nipype.utils.filemanip import loadpkl
res = loadpkl('/home/scotti/projects/3t_7t_sst_comparison/processing/crashdumps/crash-20220725-201450-scotti-_modelgen0-f309bcf2-f7a0-42a2-8b46-32fb7dce39b4.pklz')
res
# Out:
# {'node': _modelgen0,
#  'traceback': ['Traceback (most recent call last):\n',
#   '  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/pipeline/plugins/multiproc.py", line 67, in run_node\n    result["result"] = node.run(updatehash=updatehash)\n',
#   '  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 521, in run\n    result = self._run_interface(execute=True)\n',
#   '  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 639, in _run_interface\n    return self._run_command(execute)\n',
#   '  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 750, in _run_command\n    raise NodeExecutionError(\n',
#   'nipype.pipeline.engine.nodes.NodeExecutionError: Exception raised while executing Node _modelgen0.\n\nTraceback (most recent call last):\n  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/interfaces/base/core.py", line 401, in run\n    outputs = self.aggregate_outputs(runtime)\n  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/interfaces/base/core.py", line 430, in aggregate_outputs\n    predicted_outputs = self._list_outputs()  # Predictions from _list_outputs\n  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/interfaces/fsl/model.py", line 544, in _list_outputs\n    assert len(design_file) == 1, "No mat file generated by FEAT Model"\nAssertionError: No mat file generated by FEAT Model\n\n']}
