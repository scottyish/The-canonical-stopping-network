# %%
import os, sys                               # system functions
import nipype.interfaces.io as nio           # Data i/o
from nipype.interfaces.io import DataSink
import nipype.interfaces.fsl as fsl          # fsl
import nipype.pipeline.engine as pe          # pypeline engine
import nipype.interfaces.utility as util     # utility
import nipype.algorithms.modelgen as model   # model generation
import errno
import glob
import pandas as pd

fsl.FSLCommand.set_default_output_type('NIFTI_GZ')

# updating nipype from 1.7.0 -> 1.8.1, will hopefully ifx no PE estimates founds error # didn't fix
# Out:
# 230204-11:09:15,716 nipype.utils WARNING:
# 	 A newer version (1.8.4) of nipy/nipype is available. You are using 1.7.0

# %% [markdown]
# ### Copes at level 2:
# ##### Model 0:
# 1. FS
# 2. SS
# 3. Go
# 4. FS-Go
# 5. FS-SS
# 6. SS-Go
#
# ##### Model 1:
# 1. response_left
# 2. response_right
# 3. response_left-response_right

# %% [markdown]
# NOTE: had to manually change reg expression for this dataset as fwhm name was longer than all others

# %%
# dataset = 'Leipzig_7T_SM'
# dataset = 'Leipzig_7T_GdH'
# dataset = 'aron_3T'
dataset = 'NTNU_7T_SJSI'

# %% [markdown]
# #### !!! must manually change subject numbers in nipype code based on dataset !!!

# %%
# general set-up
project_folder = '/home/scotti/projects/3t_7t_sst_comparison'

if dataset == 'Leipzig_7T_SM':
    task = 'stop'
    spaces = ['T1w'] 
    model_ns = ['0']
    fwhms = ['1p6']
    
elif dataset == 'Leipzig_7T_GdH':
    task = 'stop'
    spaces = ['T1w'] 
    model_ns = ['0']
    fwhms = ['1p5']
    
elif dataset == 'aron_3T':
    task = 'stopsignal'
    spaces = ['T1w'] 
    model_ns = ['0']
    fwhms = ['5p0']#['3p125']
    
elif dataset == 'NTNU_7T_SJSI':
    task = 'sst'
    model_ns = ['0']

if model_ns[0] == '0':
    contrasts = ['0','1','2','3','4','5']  # task from second level model
elif model_ns[0] == '1':
    contrasts = ['0','1','2'] # motor from second level model

subject_ids = [x.split('/')[-4].split('-')[-1] for x in sorted(glob.glob(os.path.join(project_folder, 'derivatives', 'glm_feat_sst_roi', 
                                     'subject_level_model', dataset, 'sub-*', 'func',f'model-{model_ns[0]}',
                                     f'*task-{task}_space-MNI*contrast-0_desc-zstat*')))]
work_dir = os.path.join(project_folder, 'processing', 'nipype_workflow_folders', dataset)
slm_folder = os.path.join(project_folder, 'derivatives', 'glm_feat_sst_roi', 'subject_level_model', dataset)

template_brain = os.path.join(project_folder, 'sourcedata/templates/mni_icbm152_t1_tal_nlin_asym_09c_brain.nii')
template_brain_mask = os.path.join(project_folder, 'sourcedata/templates/mni_icbm152_t1_tal_nlin_asym_09c_brain_mask.nii')

output_dir = os.path.join(project_folder, 'derivatives', "glm_feat_sst_roi", "group_level_model", dataset,f'model-{model_ns[0]}')

templates = {'level2_cope': os.path.join(slm_folder, 'sub-*', 'func', 'model-{model_n}', '*task-sst_space-MNI152NLin2009cAsym_model-{model_n}_contrast-{contrast_n}_desc-cope.nii.gz'),
             'level2_varcope': os.path.join(slm_folder, 'sub-*', 'func', 'model-{model_n}', '*task-sst_space-MNI152NLin2009cAsym_model-{model_n}_contrast-{contrast_n}_desc-varcope.nii.gz'),
             'level2_tdof': os.path.join(slm_folder, 'sub-*', 'func', 'model-{model_n}', '*task-sst_space-MNI152NLin2009cAsym_model-{model_n}_contrast-{contrast_n}_desc-tdof_t.nii.gz')}

# %%
print(f"""
dataset : {dataset}
model_n : {model_ns}
task : {task}
no. subs : {len(subject_ids)}
subs : {subject_ids}
work_dir : {work_dir}
slm folder : {slm_folder}
output dir : {output_dir}
contrasts : {contrasts}

## if uneven number of template / designs / subs the code will crash
no.copes = {len(glob.glob(templates['level2_cope'].format(model_n=model_ns[0],contrast_n=0)))}
no.varvopes = {len(glob.glob(templates['level2_varcope'].format(model_n=model_ns[0],contrast_n=0)))}
no.tdofs = {len(glob.glob(templates['level2_tdof'].format(model_n=model_ns[0],contrast_n=0)))}
""")
# Out:
# dataset : NTNU_7T_SJSI
# model_n : ['0']
# task : sst
# no. subs : 31
# subs : ['002', '003', '005', '006', '007', '009', '011', '012', '014', '015', '016', '017', '018', '020', '021', '023', '024', '025', '026', '029', '031', '032', '033', '034', '035', '037', '038', '039', '040', '041', '042']
# work_dir : /home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI
# slm folder : /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/NTNU_7T_SJSI
# output dir : /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0
# contrasts : ['0', '1', '2', '3', '4', '5']
#
# ## if uneven number of template / designs / subs the code will crash
# no.copes = 31
# no.varvopes = 31
# no.tdofs = 31

# %%
# ## make brain mask for flameo
# import nilearn
# from nilearn import plotting
# import nibabel as nib

# hdr = nib.load('../sourcedata/templates/mni_icbm152_t1_tal_nlin_asym_09c_brain.nii')
# brain_data = hdr.get_fdata()
# brain_data[brain_data>0] = 1
# brain_mask = nib.Nifti1Image(brain_data, affine=hdr.affine, header=hdr.header)
# brain_mask.to_filename('../sourcedata/templates/mni_icbm152_t1_tal_nlin_asym_09c_brain_mask.nii')

# %%
##
workflow = pe.Workflow(name='feat_level3_sst_roi')
workflow.base_dir = work_dir
workflow.config = {"execution": {"crashdump_dir":os.path.join(project_folder, 'processing', 'crashdumps')}}

# Identity
identity = pe.Node(util.IdentityInterface(fields=['contrast_n', 'model_n']), name='identity')
identity.iterables = [('contrast_n', contrasts),
                      ('model_n', model_ns)]

# Selector
selector = pe.Node(nio.SelectFiles(templates), name='selector')
workflow.connect(identity, 'contrast_n', selector, 'contrast_n')
workflow.connect(identity, 'model_n', selector, 'model_n')

## Merge copes, varcopes, masks
copemerge    = pe.Node(interface=fsl.Merge(dimension='t'),
                          name="copemerge")

varcopemerge = pe.Node(interface=fsl.Merge(dimension='t'),
                       name="varcopemerge")

workflow.connect(selector, 'level2_cope', copemerge, 'in_files')
workflow.connect(selector, 'level2_varcope', varcopemerge, 'in_files')

# %%
def get_subject_ids():
#     if dataset == 'Leipzig_7T_SM':
    subject_ids = ['002', '003', '005', '006', '007', '009', '011', '012', '014', '015', '016', '017', 
                   '018', '020', '021', '023', '024', '025', '026', '029', '031', '032', '033', '034', 
                   '035', '037', '038', '039', '040', '041', '042']
        
#     elif dataset == 'Leipzig_7T_GdH':
#     subject_ids = ['BI3T', 'DA9T', 'FMFT', 'GAIT', 'HCBT', 'KCAT', 'KP6T', 'LV2T', 'MRCT', 'NM3T', 'PF5T', 
#                        'RSIT', 'SC1T', 'SPGT', 'TS6T', 'UM2T', 'VL1T', 'WSFT', 'WW2T', 'ZK4T']
        
    return subject_ids

subject_id_getter = pe.Node(util.Function(output_names=['subject_ids'],
                                          function=get_subject_ids),
                            name='subject_id_getter')

def get_design_matrix(second_level_contrast, subject_ids): #=subject_ids):
    print(second_level_contrast)
    regressors = {'intercept': [1 for x in range(len(subject_ids))]}
    
    # contrasts (3rd-level)
    third_level_contrasts = [('Group mean', 'T', ['intercept'], [1.0]),
                             ('-Group mean', 'T', ['intercept'], [-1.0])
                             ]
    
    return third_level_contrasts, regressors


contrastgen_l3 = pe.Node(util.Function(input_names=['second_level_contrast', 'subject_ids'],
                                       output_names=['third_level_contrasts', 'regressors'],
                                       function=get_design_matrix),
                      name='contrastgen_l3')

level3model = pe.Node(interface=fsl.MultipleRegressDesign(),
                      name='l3model')


workflow.connect(subject_id_getter, 'subject_ids', contrastgen_l3, 'subject_ids')
workflow.connect(identity, 'contrast_n', contrastgen_l3, 'second_level_contrast')
workflow.connect(contrastgen_l3, 'third_level_contrasts', level3model, 'contrasts')
workflow.connect(contrastgen_l3, 'regressors', level3model, 'regressors')

# %%
# flameo = pe.Node(
#     interface=fsl.FLAMEO(run_mode='flame1'),
#     name="flame1")

# flameo.inputs.mask_file = template_brain_mask

# workflow.connect([
#     (copemerge, flameo, [('merged_file', 'cope_file')]),
#     (varcopemerge, flameo, [('merged_file', 'var_cope_file')]),
#     (level3model, flameo, [('design_mat', 'design_file'),
#                            ('design_con', 't_con_file'), 
#                            ('design_grp', 'cov_split_file')]),
# ])

flameo = pe.Node(
    interface=fsl.FLAMEO(),
    name="flameo")

flameo.iterables = ('run_mode', ['flame1', 'flame12'])
flameo.inputs.mask_file = template_brain_mask
flameo.inputs.infer_outliers = False   # run with automatic outlier detection

workflow.connect([
    (copemerge, flameo, [('merged_file', 'cope_file')]),
    (varcopemerge, flameo, [('merged_file', 'var_cope_file')]),
    (level3model, flameo, [('design_mat', 'design_file'),
                           ('design_con', 't_con_file'), 
                           ('design_grp', 'cov_split_file')]),
])

# %%
## cluster thresholding
# Smoothness estimation
smoothestimate = pe.MapNode(fsl.SmoothEstimate(), iterfield=['zstat_file'], name='smoothestimate')
smoothestimate.inputs.mask_file = template_brain_mask

workflow.connect(flameo, 'zstats', smoothestimate, 'zstat_file')

# get volume
get_volume = pe.Node(fsl.ImageStats(op_string = '-V'), name='get_volume')
get_volume.inputs.in_file = template_brain_mask


# Cluster threshold
grf_cluster = pe.MapNode(fsl.Cluster(), iterfield=['dlh', 'in_file'], name='grf_cluster')
grf_cluster.iterables = [("threshold", [2.3, 3.1])]
grf_cluster.inputs.out_localmax_txt_file = True
grf_cluster.inputs.pthreshold = 0.05
grf_cluster.inputs.out_index_file = True
grf_cluster.inputs.out_threshold_file = True


def volume_convert(input):
    return int(input[0])

workflow.connect(get_volume, ('out_stat', volume_convert), grf_cluster, 'volume')
workflow.connect(smoothestimate, 'dlh', grf_cluster, 'dlh')
workflow.connect(flameo, 'zstats', grf_cluster, 'in_file')

# %%
# ## Datasink
# datasink = pe.Node(nio.DataSink(), name='sinker')
# datasink.inputs.base_directory=os.path.join(project_folder, 'derivatives', "glm_feat", "group_level_model", "ses-sstmsit","task-sst")

# workflow.connect(copemerge, 'merged_file', datasink, 'copes_merged')
# workflow.connect(level3model, 'design_con', datasink, 'design_con')
# workflow.connect(level3model, 'design_mat', datasink, 'design_mat')

# ## todo: substitutions
# workflow.connect(flameo, 'zstats', datasink, 'third_level_model.level3_zstats')
# workflow.connect(flameo, 'copes', datasink, 'third_level_model.level3_copes')
# workflow.connect(flameo, 'var_copes', datasink, 'third_level_model.level3_varcopes')
# workflow.connect(flameo, 'tdof', datasink, 'third_level_model.level3_tdof_ts')

# ## cluster results
# workflow.connect(grf_cluster, 'threshold_file', datasink, 'grf_thresholded_zstats_file')
# workflow.connect(grf_cluster, 'localmax_txt_file', datasink, 'grf_localmax_txt_file')
# workflow.connect(grf_cluster, 'index_file', datasink, 'cluster_indices')

# %%
## Datasink
datasink = pe.Node(nio.DataSink(), name='sinker')
datasink.inputs.base_directory=output_dir


substitutions_regexp = [(r'third_level_model/grf_thresholded_zstats_file/_contrast_n_(\d+)_model_n_(\S+)/_run_mode_flame(\d+)/_threshold_(\S+)/_grf_cluster(\d)/(\S+)(\d)_threshold.nii.gz',
                         'model-\\2/model-\\2_subjectlevelcontrast-\\1_grouplevelcontrast-\\7_flame-\\3_desc-\\6_voxelthreshold-\\4.nii.gz'),
                        (r'third_level_model/level3_.*/_contrast_n_(\d+)_model_n_(\S+)/_run_mode_flame(\d+)/(\S+)(\d).nii.gz',
                          'model-\\2/model-\\2_subjectlevelcontrast-\\1_grouplevelcontrast-\\5_flame-\\3_desc-\\4.nii.gz'),
                        # (r'third_level_model/grf_localmax_.*/fwhm-(\S{3})/model-(\S+)/contrast-(\d+)/_run_mode_flame(\d+)/_threshold_(\S+)/_grf_cluster(\d)/zstat1_(\S+).txt',
                        #   'model-\\2/model-\\2_fwhm-\\1_subjectlevelcontrast-\\3_grouplevelcontrast-\\6_flame-\\4_desc-zstat_\\7-voxelthreshold-\\5.txt')
                       ]

datasink.inputs.regexp_substitutions = substitutions_regexp

## todo: substitutions
workflow.connect(flameo, 'zstats', datasink, 'third_level_model.level3_zstats')
workflow.connect(flameo, 'copes', datasink, 'third_level_model.level3_copes')
workflow.connect(flameo, 'var_copes', datasink, 'third_level_model.level3_varcopes')
workflow.connect(flameo, 'tdof', datasink, 'third_level_model.level3_tdof_ts')

## cluster results
workflow.connect(grf_cluster, 'threshold_file', datasink, 'third_level_model.grf_thresholded_zstats_file')
workflow.connect(grf_cluster, 'localmax_txt_file', datasink, 'third_level_model.grf_localmax_txt_file')
workflow.connect(grf_cluster, 'index_file', datasink, 'third_level_model.grf_cluster_indices')

# %%
workflow.run(plugin='MultiProc', plugin_args={'n_procs': 12, 'memory_gb': 120})
# Out:
# 230204-11:12:07,881 nipype.workflow INFO:
# 	 Workflow feat_level3_sst_roi settings: ['check', 'execution', 'logging', 'monitoring']
# 230204-11:12:08,110 nipype.workflow INFO:
# 	 Running in parallel.
# 230204-11:12:09,260 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 8 jobs ready. Free memory (GB): 120.00/120.00, Free processors: 12/12.
# 230204-11:12:09,358 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.subject_id_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/subject_id_getter".
# 230204-11:12:09,360 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/get_volume".
# 230204-11:12:09,362 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_1_model_n_0/selector".
# 230204-11:12:09,362 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_0_model_n_0/selector".
# 230204-11:12:09,363 nipype.workflow INFO:
# 	 [Node] Executing "subject_id_getter" <nipype.interfaces.utility.wrappers.Function>
# 230204-11:12:09,363 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_2_model_n_0/selector".
# 230204-11:12:09,363 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_4_model_n_0/selector".
# 230204-11:12:09,364 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 230204-11:12:09,363 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_5_model_n_0/selector".
# 230204-11:12:09,363 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_3_model_n_0/selector".
# 230204-11:12:09,366 nipype.workflow INFO:
# 	 [Node] Finished "subject_id_getter", elapsed time 0.000572s.
# 230204-11:12:09,367 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230204-11:12:09,368 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230204-11:12:09,368 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230204-11:12:09,369 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230204-11:12:09,370 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230204-11:12:09,369 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230204-11:12:09,376 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.007453s.
# 230204-11:12:09,376 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.006609s.
# 230204-11:12:09,379 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.008246s.
# 230204-11:12:09,380 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.008034s.
# 230204-11:12:09,383 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.011471s.
# 230204-11:12:09,384 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.011775s.
# 230204-11:12:10,397 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 1.030011s.
# 230204-11:12:11,263 nipype.workflow INFO:
# 	 [Job 0] Completed (feat_level3_sst_roi.subject_id_getter).
# 230204-11:12:11,265 nipype.workflow INFO:
# 	 [Job 1] Completed (feat_level3_sst_roi.get_volume).
# 230204-11:12:11,266 nipype.workflow INFO:
# 	 [Job 2] Completed (feat_level3_sst_roi.selector).
# 230204-11:12:11,267 nipype.workflow INFO:
# 	 [Job 3] Completed (feat_level3_sst_roi.selector).
# 230204-11:12:11,268 nipype.workflow INFO:
# 	 [Job 4] Completed (feat_level3_sst_roi.selector).
# 230204-11:12:11,269 nipype.workflow INFO:
# 	 [Job 5] Completed (feat_level3_sst_roi.selector).
# 230204-11:12:11,270 nipype.workflow INFO:
# 	 [Job 6] Completed (feat_level3_sst_roi.selector).
# 230204-11:12:11,270 nipype.workflow INFO:
# 	 [Job 7] Completed (feat_level3_sst_roi.selector).
# 230204-11:12:11,272 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 18 jobs ready. Free memory (GB): 120.00/120.00, Free processors: 12/12.
# 230204-11:12:11,372 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.contrastgen_l3" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_4_model_n_0/contrastgen_l3".
# 230204-11:12:11,372 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.contrastgen_l3" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_5_model_n_0/contrastgen_l3".
# 230204-11:12:11,372 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.copemerge" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_0_model_n_0/copemerge".
# 230204-11:12:11,372 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.varcopemerge" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_0_model_n_0/varcopemerge".
# 230204-11:12:11,372 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.copemerge" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_2_model_n_0/copemerge".
# 230204-11:12:11,372 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.copemerge" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_1_model_n_0/copemerge".
# 230204-11:12:11,372 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.contrastgen_l3" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_0_model_n_0/contrastgen_l3".
# 230204-11:12:11,372 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.contrastgen_l3" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_2_model_n_0/contrastgen_l3".
# 230204-11:12:11,372 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.varcopemerge" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_1_model_n_0/varcopemerge".
# 230204-11:12:11,373 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.varcopemerge" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_2_model_n_0/varcopemerge".
# 230204-11:12:11,372 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.contrastgen_l3" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_1_model_n_0/contrastgen_l3".
# 230204-11:12:11,372 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.contrastgen_l3" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_3_model_n_0/contrastgen_l3".
# 230204-11:12:11,377 nipype.workflow INFO:
# 	 [Node] Executing "contrastgen_l3" <nipype.interfaces.utility.wrappers.Function>
# 230204-11:12:11,377 nipype.workflow INFO:
# 	 [Node] Executing "contrastgen_l3" <nipype.interfaces.utility.wrappers.Function>
# 54
#
# 230204-11:12:11,380 nipype.workflow INFO:
# 	 [Node] Executing "contrastgen_l3" <nipype.interfaces.utility.wrappers.Function>
# 230204-11:12:11,380 nipype.workflow INFO:
# 	 [Node] Executing "copemerge" <nipype.interfaces.fsl.utils.Merge>
# 230204-11:12:11,381 nipype.workflow INFO:
# 	 [Node] Finished "contrastgen_l3", elapsed time 0.00184s.
# 0230204-11:12:11,381 nipype.workflow INFO:
# 	 [Node] Finished "contrastgen_l3", elapsed time 0.003002s.
#
# 230204-11:12:11,384 nipype.workflow INFO:
# 	 [Node] Finished "contrastgen_l3", elapsed time 0.00201s.
# 230204-11:12:11,402 nipype.workflow INFO:
# 	 [Node] Executing "contrastgen_l3" <nipype.interfaces.utility.wrappers.Function>
# 230204-11:12:11,403 nipype.workflow INFO:
# 	 [Node] Executing "contrastgen_l3" <nipype.interfaces.utility.wrappers.Function>
# 230204-11:12:11,404 nipype.workflow INFO:
# 	 [Node] Executing "contrastgen_l3" <nipype.interfaces.utility.wrappers.Function>
# 230204-11:12:11,404 nipype.workflow INFO:
# 	 [Node] Executing "varcopemerge" <nipype.interfaces.fsl.utils.Merge>
# 230204-11:12:11,404 nipype.workflow INFO:
# 	 [Node] Executing "copemerge" <nipype.interfaces.fsl.utils.Merge>
# 230204-11:12:11,404 nipype.workflow INFO:
# 	 [Node] Executing "varcopemerge" <nipype.interfaces.fsl.utils.Merge>
# 230204-11:12:11,405 nipype.workflow INFO:
# 	 [Node] Executing "varcopemerge" <nipype.interfaces.fsl.utils.Merge>
# 230204-11:12:11,405 nipype.workflow INFO:
# 	 [Node] Executing "copemerge" <nipype.interfaces.fsl.utils.Merge>
# 12
#
# 3
# 230204-11:12:11,409 nipype.workflow INFO:
# 	 [Node] Finished "contrastgen_l3", elapsed time 0.002438s.
# 230204-11:12:11,409 nipype.workflow INFO:
# 	 [Node] Finished "contrastgen_l3", elapsed time 0.003077s.
# 230204-11:12:11,410 nipype.workflow INFO:
# 	 [Node] Finished "contrastgen_l3", elapsed time 0.004431s.
# 230204-11:12:13,263 nipype.workflow INFO:
# 	 [Job 8] Completed (feat_level3_sst_roi.contrastgen_l3).
# 230204-11:12:13,265 nipype.workflow INFO:
# 	 [Job 9] Completed (feat_level3_sst_roi.contrastgen_l3).
# 230204-11:12:13,266 nipype.workflow INFO:
# 	 [Job 10] Completed (feat_level3_sst_roi.contrastgen_l3).
# 230204-11:12:13,267 nipype.workflow INFO:
# 	 [Job 11] Completed (feat_level3_sst_roi.contrastgen_l3).
# 230204-11:12:13,267 nipype.workflow INFO:
# 	 [Job 12] Completed (feat_level3_sst_roi.contrastgen_l3).
# 230204-11:12:13,268 nipype.workflow INFO:
# 	 [Job 13] Completed (feat_level3_sst_roi.contrastgen_l3).
# 230204-11:12:13,269 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 12 jobs ready. Free memory (GB): 118.80/120.00, Free processors: 6/12.
#                      Currently running:
#                        * feat_level3_sst_roi.varcopemerge
#                        * feat_level3_sst_roi.copemerge
#                        * feat_level3_sst_roi.varcopemerge
#                        * feat_level3_sst_roi.copemerge
#                        * feat_level3_sst_roi.varcopemerge
#                        * feat_level3_sst_roi.copemerge
# 230204-11:12:13,372 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.copemerge" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_4_model_n_0/copemerge".
# 230204-11:12:13,372 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.varcopemerge" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_3_model_n_0/varcopemerge".
# 230204-11:12:13,372 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.copemerge" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_3_model_n_0/copemerge".
# 230204-11:12:13,372 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.copemerge" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_5_model_n_0/copemerge".
# 230204-11:12:13,372 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.varcopemerge" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_5_model_n_0/varcopemerge".
# 230204-11:12:13,372 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.varcopemerge" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_4_model_n_0/varcopemerge".
# 230204-11:12:13,379 nipype.workflow INFO:
# 	 [Node] Executing "copemerge" <nipype.interfaces.fsl.utils.Merge>
# 230204-11:12:13,380 nipype.workflow INFO:
# 	 [Node] Executing "varcopemerge" <nipype.interfaces.fsl.utils.Merge>
# 230204-11:12:13,381 nipype.workflow INFO:
# 	 [Node] Executing "copemerge" <nipype.interfaces.fsl.utils.Merge>
# 230204-11:12:13,380 nipype.workflow INFO:
# 	 [Node] Executing "copemerge" <nipype.interfaces.fsl.utils.Merge>
# 230204-11:12:13,381 nipype.workflow INFO:
# 	 [Node] Executing "varcopemerge" <nipype.interfaces.fsl.utils.Merge>
# 230204-11:12:13,381 nipype.workflow INFO:
# 	 [Node] Executing "varcopemerge" <nipype.interfaces.fsl.utils.Merge>
# 230204-11:12:15,266 nipype.workflow INFO:
# 	 [MultiProc] Running 12 tasks, and 6 jobs ready. Free memory (GB): 117.60/120.00, Free processors: 0/12.
#                      Currently running:
#                        * feat_level3_sst_roi.varcopemerge
#                        * feat_level3_sst_roi.copemerge
#                        * feat_level3_sst_roi.varcopemerge
#                        * feat_level3_sst_roi.copemerge
#                        * feat_level3_sst_roi.varcopemerge
#                        * feat_level3_sst_roi.copemerge
#                        * feat_level3_sst_roi.varcopemerge
#                        * feat_level3_sst_roi.copemerge
#                        * feat_level3_sst_roi.varcopemerge
#                        * feat_level3_sst_roi.copemerge
#                        * feat_level3_sst_roi.varcopemerge
#                        * feat_level3_sst_roi.copemerge
# 230204-11:12:22,864 nipype.workflow INFO:
# 	 [Node] Finished "varcopemerge", elapsed time 11.456764s.
# 230204-11:12:22,917 nipype.workflow INFO:
# 	 [Node] Finished "varcopemerge", elapsed time 11.511131s.
# 230204-11:12:23,128 nipype.workflow INFO:
# 	 [Node] Finished "copemerge", elapsed time 11.71961s.
# 230204-11:12:23,260 nipype.workflow INFO:
# 	 [Node] Finished "copemerge", elapsed time 11.878722s.
# 230204-11:12:23,273 nipype.workflow INFO:
# 	 [Job 14] Completed (feat_level3_sst_roi.copemerge).
# 230204-11:12:23,275 nipype.workflow INFO:
# 	 [Job 17] Completed (feat_level3_sst_roi.varcopemerge).
# 230204-11:12:23,276 nipype.workflow INFO:
# 	 [Job 18] Completed (feat_level3_sst_roi.copemerge).
# 230204-11:12:23,277 nipype.workflow INFO:
# 	 [Job 19] Completed (feat_level3_sst_roi.varcopemerge).
# 230204-11:12:23,279 nipype.workflow INFO:
# 	 [MultiProc] Running 8 tasks, and 6 jobs ready. Free memory (GB): 118.40/120.00, Free processors: 4/12.
#                      Currently running:
#                        * feat_level3_sst_roi.varcopemerge
#                        * feat_level3_sst_roi.copemerge
#                        * feat_level3_sst_roi.varcopemerge
#                        * feat_level3_sst_roi.copemerge
#                        * feat_level3_sst_roi.varcopemerge
#                        * feat_level3_sst_roi.copemerge
#                        * feat_level3_sst_roi.copemerge
#                        * feat_level3_sst_roi.varcopemerge
# 230204-11:12:23,385 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.l3model" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_1_model_n_0/l3model".
# 230204-11:12:23,385 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.l3model" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_0_model_n_0/l3model".
# 230204-11:12:23,386 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.l3model" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_3_model_n_0/l3model".
# 230204-11:12:23,386 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.l3model" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_2_model_n_0/l3model".
# 230204-11:12:23,390 nipype.workflow INFO:
# 	 [Node] Executing "l3model" <nipype.interfaces.fsl.model.MultipleRegressDesign>
# 230204-11:12:23,391 nipype.workflow INFO:
# 	 [Node] Executing "l3model" <nipype.interfaces.fsl.model.MultipleRegressDesign>
# 230204-11:12:23,392 nipype.workflow INFO:
# 	 [Node] Executing "l3model" <nipype.interfaces.fsl.model.MultipleRegressDesign>
# 230204-11:12:23,393 nipype.workflow INFO:
# 	 [Node] Finished "l3model", elapsed time 0.001872s.
# 230204-11:12:23,395 nipype.workflow INFO:
# 	 [Node] Finished "l3model", elapsed time 0.001272s.
# 230204-11:12:23,396 nipype.workflow INFO:
# 	 [Node] Finished "l3model", elapsed time 0.002109s.
# 230204-11:12:23,400 nipype.workflow INFO:
# 	 [Node] Executing "l3model" <nipype.interfaces.fsl.model.MultipleRegressDesign>
# 230204-11:12:23,403 nipype.workflow INFO:
# 	 [Node] Finished "l3model", elapsed time 0.001396s.
# 230204-11:12:23,936 nipype.workflow INFO:
# 	 [Node] Finished "copemerge", elapsed time 12.52959s.
# 230204-11:12:24,102 nipype.workflow INFO:
# 	 [Node] Finished "varcopemerge", elapsed time 12.696049s.
# 230204-11:12:24,571 nipype.workflow INFO:
# 	 [Node] Finished "copemerge", elapsed time 11.188494s.
# 230204-11:12:24,866 nipype.workflow INFO:
# 	 [Node] Finished "copemerge", elapsed time 11.485659s.
# 230204-11:12:25,50 nipype.workflow INFO:
# 	 [Node] Finished "varcopemerge", elapsed time 11.666417s.
# 230204-11:12:25,275 nipype.workflow INFO:
# 	 [Job 15] Completed (feat_level3_sst_roi.varcopemerge).
# 230204-11:12:25,276 nipype.workflow INFO:
# 	 [Job 16] Completed (feat_level3_sst_roi.copemerge).
# 230204-11:12:25,277 nipype.workflow INFO:
# 	 [Job 20] Completed (feat_level3_sst_roi.copemerge).
# 230204-11:12:25,278 nipype.workflow INFO:
# 	 [Job 23] Completed (feat_level3_sst_roi.varcopemerge).
# 230204-11:12:25,279 nipype.workflow INFO:
# 	 [Job 24] Completed (feat_level3_sst_roi.copemerge).
# 230204-11:12:25,281 nipype.workflow INFO:
# 	 [Job 26] Completed (feat_level3_sst_roi.l3model).
# 230204-11:12:25,282 nipype.workflow INFO:
# 	 [Job 27] Completed (feat_level3_sst_roi.l3model).
# 230204-11:12:25,283 nipype.workflow INFO:
# 	 [Job 28] Completed (feat_level3_sst_roi.l3model).
# 230204-11:12:25,283 nipype.workflow INFO:
# 	 [Job 29] Completed (feat_level3_sst_roi.l3model).
# 230204-11:12:25,285 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 8 jobs ready. Free memory (GB): 119.40/120.00, Free processors: 9/12.
#                      Currently running:
#                        * feat_level3_sst_roi.varcopemerge
#                        * feat_level3_sst_roi.copemerge
#                        * feat_level3_sst_roi.varcopemerge
# 230204-11:12:25,372 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.l3model" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_4_model_n_0/l3model".
# 230204-11:12:25,373 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.l3model" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_5_model_n_0/l3model".
# 230204-11:12:25,375 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.flameo" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_0_model_n_0/_run_mode_flame12/flameo".
# 230204-11:12:25,375 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.flameo" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_0_model_n_0/_run_mode_flame1/flameo".
# 230204-11:12:25,376 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.flameo" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_1_model_n_0/_run_mode_flame12/flameo".
# 230204-11:12:25,376 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.flameo" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_2_model_n_0/_run_mode_flame12/flameo".
# 230204-11:12:25,377 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.flameo" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_2_model_n_0/_run_mode_flame1/flameo".
# 230204-11:12:25,376 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.flameo" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_1_model_n_0/_run_mode_flame1/flameo".
# 230204-11:12:25,378 nipype.workflow INFO:
# 	 [Node] Executing "l3model" <nipype.interfaces.fsl.model.MultipleRegressDesign>
# 230204-11:12:25,382 nipype.workflow INFO:
# 	 [Node] Executing "l3model" <nipype.interfaces.fsl.model.MultipleRegressDesign>
# 230204-11:12:25,383 nipype.workflow INFO:
# 	 [Node] Finished "l3model", elapsed time 0.002905s.
# 230204-11:12:25,382 nipype.workflow INFO:
# 	 [Node] Executing "flameo" <nipype.interfaces.fsl.model.FLAMEO>
# 230204-11:12:25,383 nipype.workflow INFO:
# 	 [Node] Executing "flameo" <nipype.interfaces.fsl.model.FLAMEO>
# 230204-11:12:25,387 nipype.workflow INFO:
# 	 [Node] Finished "l3model", elapsed time 0.001378s.
# 230204-11:12:25,388 nipype.workflow INFO:
# 	 [Node] Executing "flameo" <nipype.interfaces.fsl.model.FLAMEO>
# 230204-11:12:25,388 nipype.workflow INFO:
# 	 [Node] Finished "varcopemerge", elapsed time 12.004859s.
# 230204-11:12:25,389 nipype.workflow INFO:
# 	 [Node] Executing "flameo" <nipype.interfaces.fsl.model.FLAMEO>
# 230204-11:12:25,510 nipype.workflow INFO:
# 	 [Node] Executing "flameo" <nipype.interfaces.fsl.model.FLAMEO>
# 230204-11:12:25,510 nipype.workflow INFO:
# 	 [Node] Executing "flameo" <nipype.interfaces.fsl.model.FLAMEO>
# 230204-11:12:25,521 nipype.workflow INFO:
# 	 [Node] Finished "varcopemerge", elapsed time 12.138322s.
# 230204-11:12:26,287 nipype.workflow INFO:
# 	 [Node] Finished "copemerge", elapsed time 12.904278s.
# 230204-11:12:27,277 nipype.workflow INFO:
# 	 [Job 21] Completed (feat_level3_sst_roi.varcopemerge).
# 230204-11:12:27,278 nipype.workflow INFO:
# 	 [Job 22] Completed (feat_level3_sst_roi.copemerge).
# 230204-11:12:27,279 nipype.workflow INFO:
# 	 [Job 25] Completed (feat_level3_sst_roi.varcopemerge).
# 230204-11:12:27,280 nipype.workflow INFO:
# 	 [Job 30] Completed (feat_level3_sst_roi.l3model).
# 230204-11:12:27,281 nipype.workflow INFO:
# 	 [Job 31] Completed (feat_level3_sst_roi.l3model).
# 230204-11:12:27,282 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 6 jobs ready. Free memory (GB): 118.80/120.00, Free processors: 6/12.
#                      Currently running:
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
# 230204-11:12:27,353 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.flameo" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_3_model_n_0/_run_mode_flame12/flameo".
# 230204-11:12:27,353 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.flameo" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_3_model_n_0/_run_mode_flame1/flameo".
# 230204-11:12:27,354 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.flameo" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_4_model_n_0/_run_mode_flame1/flameo".
# 230204-11:12:27,354 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.flameo" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_4_model_n_0/_run_mode_flame12/flameo".
# 230204-11:12:27,354 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.flameo" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_5_model_n_0/_run_mode_flame1/flameo".
# 230204-11:12:27,354 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.flameo" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_5_model_n_0/_run_mode_flame12/flameo".
# 230204-11:12:27,361 nipype.workflow INFO:
# 	 [Node] Executing "flameo" <nipype.interfaces.fsl.model.FLAMEO>
# 230204-11:12:27,361 nipype.workflow INFO:
# 	 [Node] Executing "flameo" <nipype.interfaces.fsl.model.FLAMEO>
# 230204-11:12:27,364 nipype.workflow INFO:
# 	 [Node] Executing "flameo" <nipype.interfaces.fsl.model.FLAMEO>
# 230204-11:12:27,365 nipype.workflow INFO:
# 	 [Node] Executing "flameo" <nipype.interfaces.fsl.model.FLAMEO>
# 230204-11:12:27,365 nipype.workflow INFO:
# 	 [Node] Executing "flameo" <nipype.interfaces.fsl.model.FLAMEO>
# 230204-11:12:27,365 nipype.workflow INFO:
# 	 [Node] Executing "flameo" <nipype.interfaces.fsl.model.FLAMEO>
# 230204-11:12:29,279 nipype.workflow INFO:
# 	 [MultiProc] Running 12 tasks, and 0 jobs ready. Free memory (GB): 117.60/120.00, Free processors: 0/12.
#                      Currently running:
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
# 230204-11:13:16,417 nipype.workflow INFO:
# 	 [Node] Finished "flameo", elapsed time 51.02301s.
# 230204-11:13:17,327 nipype.workflow INFO:
# 	 [Job 36] Completed (feat_level3_sst_roi.flameo).
# 230204-11:13:17,330 nipype.workflow INFO:
# 	 [MultiProc] Running 11 tasks, and 1 jobs ready. Free memory (GB): 117.80/120.00, Free processors: 1/12.
#                      Currently running:
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
# 230204-11:13:18,579 nipype.workflow INFO:
# 	 [Node] Finished "flameo", elapsed time 53.193183s.
# 230204-11:13:19,329 nipype.workflow INFO:
# 	 [Job 32] Completed (feat_level3_sst_roi.flameo).
# 230204-11:13:19,332 nipype.workflow INFO:
# 	 [MultiProc] Running 10 tasks, and 3 jobs ready. Free memory (GB): 118.00/120.00, Free processors: 2/12.
#                      Currently running:
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
# 230204-11:13:19,446 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_2_model_n_0/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate0".
# 230204-11:13:19,446 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_2_model_n_0/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate1".
# 230204-11:13:19,450 nipype.workflow INFO:
# 	 [Node] Executing "_smoothestimate1" <nipype.interfaces.fsl.model.SmoothEstimate>
# 230204-11:13:19,450 nipype.workflow INFO:
# 	 [Node] Executing "_smoothestimate0" <nipype.interfaces.fsl.model.SmoothEstimate>
# 230204-11:13:20,314 nipype.workflow INFO:
# 	 [Node] Finished "_smoothestimate1", elapsed time 0.862524s.
# 230204-11:13:20,429 nipype.workflow INFO:
# 	 [Node] Finished "_smoothestimate0", elapsed time 0.976025s.
# 230204-11:13:21,331 nipype.workflow INFO:
# 	 [Job 104] Completed (_smoothestimate0).
# 230204-11:13:21,332 nipype.workflow INFO:
# 	 [Job 105] Completed (_smoothestimate1).
# 230204-11:13:21,333 nipype.workflow INFO:
# 	 [MultiProc] Running 10 tasks, and 3 jobs ready. Free memory (GB): 118.00/120.00, Free processors: 2/12.
#                      Currently running:
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
# 230204-11:13:21,435 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_0_model_n_0/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate0".
# 230204-11:13:21,438 nipype.workflow INFO:
# 	 [Node] Executing "_smoothestimate0" <nipype.interfaces.fsl.model.SmoothEstimate>
# 230204-11:13:21,439 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_2_model_n_0/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate0".
# 230204-11:13:21,537 nipype.workflow INFO:
# 	 [Node] Cached "_smoothestimate0" - collecting precomputed outputs
# 230204-11:13:21,538 nipype.workflow INFO:
# 	 [Node] "_smoothestimate0" found cached.
# 230204-11:13:21,540 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_2_model_n_0/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate1".
# 230204-11:13:21,544 nipype.workflow INFO:
# 	 [Node] Cached "_smoothestimate1" - collecting precomputed outputs
# 230204-11:13:21,544 nipype.workflow INFO:
# 	 [Node] "_smoothestimate1" found cached.
# 230204-11:13:21,887 nipype.workflow INFO:
# 	 [Node] Finished "flameo", elapsed time 56.375211s.
# 230204-11:13:21,909 nipype.workflow INFO:
# 	 [Node] Finished "flameo", elapsed time 54.54226s.
# 230204-11:13:22,222 nipype.workflow INFO:
# 	 [Node] Finished "_smoothestimate0", elapsed time 0.781104s.
# 230204-11:13:23,333 nipype.workflow INFO:
# 	 [Job 34] Completed (feat_level3_sst_roi.flameo).
# 230204-11:13:23,335 nipype.workflow INFO:
# 	 [Job 42] Completed (feat_level3_sst_roi.flameo).
# 230204-11:13:23,336 nipype.workflow INFO:
# 	 [Job 48] Completed (feat_level3_sst_roi.smoothestimate).
# 230204-11:13:23,337 nipype.workflow INFO:
# 	 [Job 106] Completed (_smoothestimate0).
# 230204-11:13:23,339 nipype.workflow INFO:
# 	 [MultiProc] Running 8 tasks, and 5 jobs ready. Free memory (GB): 118.40/120.00, Free processors: 4/12.
#                      Currently running:
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
# 230204-11:13:23,511 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_0_model_n_0/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate1".
# 230204-11:13:23,516 nipype.workflow INFO:
# 	 [Node] Executing "_smoothestimate1" <nipype.interfaces.fsl.model.SmoothEstimate>
# 230204-11:13:24,156 nipype.workflow INFO:
# 	 [Node] Finished "_smoothestimate1", elapsed time 0.637734s.
# 230204-11:13:24,576 nipype.workflow INFO:
# 	 [Node] Finished "flameo", elapsed time 57.213593s.
# 230204-11:13:24,624 nipype.workflow INFO:
# 	 [Node] Finished "flameo", elapsed time 57.257997s.
# 230204-11:13:25,335 nipype.workflow INFO:
# 	 [Job 38] Completed (feat_level3_sst_roi.flameo).
# 230204-11:13:25,337 nipype.workflow INFO:
# 	 [Job 40] Completed (feat_level3_sst_roi.flameo).
# 230204-11:13:25,338 nipype.workflow INFO:
# 	 [Job 107] Completed (_smoothestimate1).
# 230204-11:13:25,340 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 11 jobs ready. Free memory (GB): 118.80/120.00, Free processors: 6/12.
#                      Currently running:
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
# 230204-11:13:25,460 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_0_model_n_0/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate0".
# 230204-11:13:25,462 nipype.workflow INFO:
# 	 [Node] Cached "_smoothestimate0" - collecting precomputed outputs
# 230204-11:13:25,463 nipype.workflow INFO:
# 	 [Node] "_smoothestimate0" found cached.
# 230204-11:13:25,465 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_0_model_n_0/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate1".
# 230204-11:13:25,465 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_1_model_n_0/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate0".
# 230204-11:13:25,467 nipype.workflow INFO:
# 	 [Node] Cached "_smoothestimate1" - collecting precomputed outputs
# 230204-11:13:25,466 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_1_model_n_0/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate1".
# 230204-11:13:25,466 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_5_model_n_0/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate0".
# 230204-11:13:25,467 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_5_model_n_0/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate1".
# 230204-11:13:25,467 nipype.workflow INFO:
# 	 [Node] "_smoothestimate1" found cached.
# 230204-11:13:25,468 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_2_model_n_0/_run_mode_flame1/_threshold_2.3/grf_cluster/mapflow/_grf_cluster0".
# 230204-11:13:25,470 nipype.workflow INFO:
# 	 [Node] Executing "_smoothestimate1" <nipype.interfaces.fsl.model.SmoothEstimate>
# 230204-11:13:25,470 nipype.workflow INFO:
# 	 [Node] Executing "_smoothestimate0" <nipype.interfaces.fsl.model.SmoothEstimate>
# 230204-11:13:25,470 nipype.workflow INFO:
# 	 [Node] Executing "_smoothestimate0" <nipype.interfaces.fsl.model.SmoothEstimate>
# 230204-11:13:25,471 nipype.workflow INFO:
# 	 [Node] Executing "_smoothestimate1" <nipype.interfaces.fsl.model.SmoothEstimate>
# 230204-11:13:25,473 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster0" <nipype.interfaces.fsl.model.Cluster>
# 230204-11:13:26,12 nipype.workflow INFO:
# 	 [Node] Finished "_smoothestimate0", elapsed time 0.540551s.
# 230204-11:13:26,13 nipype.workflow INFO:
# 	 [Node] Finished "_smoothestimate1", elapsed time 0.541004s.
# 230204-11:13:26,22 nipype.workflow INFO:
# 	 [Node] Finished "_smoothestimate1", elapsed time 0.547866s.
# 230204-11:13:26,180 nipype.workflow INFO:
# 	 [Node] Finished "_smoothestimate0", elapsed time 0.706718s.
# 230204-11:13:27,143 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster0", elapsed time 1.667435s.
# 230204-11:13:27,337 nipype.workflow INFO:
# 	 [Job 44] Completed (feat_level3_sst_roi.smoothestimate).
# 230204-11:13:27,339 nipype.workflow INFO:
# 	 [Job 108] Completed (_smoothestimate0).
# 230204-11:13:27,340 nipype.workflow INFO:
# 	 [Job 109] Completed (_smoothestimate1).
# 230204-11:13:27,341 nipype.workflow INFO:
# 	 [Job 110] Completed (_smoothestimate0).
# 230204-11:13:27,342 nipype.workflow INFO:
# 	 [Job 111] Completed (_smoothestimate1).
# 230204-11:13:27,343 nipype.workflow INFO:
# 	 [Job 112] Completed (_grf_cluster0).
# 230204-11:13:27,344 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 11 jobs ready. Free memory (GB): 118.80/120.00, Free processors: 6/12.
#                      Currently running:
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
# 230204-11:13:27,448 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_1_model_n_0/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate0".
# 230204-11:13:27,450 nipype.workflow INFO:
# 	 [Node] Cached "_smoothestimate0" - collecting precomputed outputs
# 230204-11:13:27,450 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_5_model_n_0/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate0".
# 230204-11:13:27,451 nipype.workflow INFO:
# 	 [Node] "_smoothestimate0" found cached.
# 230204-11:13:27,453 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_1_model_n_0/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate1".
# 230204-11:13:27,453 nipype.workflow INFO:
# 	 [Node] Cached "_smoothestimate0" - collecting precomputed outputs
# 230204-11:13:27,454 nipype.workflow INFO:
# 	 [Node] "_smoothestimate0" found cached.
# 230204-11:13:27,455 nipype.workflow INFO:
# 	 [Node] Cached "_smoothestimate1" - collecting precomputed outputs
# 230204-11:13:27,456 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_5_model_n_0/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate1".
# 230204-11:13:27,456 nipype.workflow INFO:
# 	 [Node] "_smoothestimate1" found cached.
# 230204-11:13:27,460 nipype.workflow INFO:
# 	 [Node] Cached "_smoothestimate1" - collecting precomputed outputs
# 230204-11:13:27,461 nipype.workflow INFO:
# 	 [Node] "_smoothestimate1" found cached.
# 230204-11:13:27,463 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_2_model_n_0/_run_mode_flame1/_threshold_2.3/grf_cluster/mapflow/_grf_cluster1".
# 230204-11:13:27,465 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_2_model_n_0/_run_mode_flame1/_threshold_3.1/grf_cluster/mapflow/_grf_cluster0".
# 230204-11:13:27,467 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster1" <nipype.interfaces.fsl.model.Cluster>
# 230204-11:13:27,467 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_2_model_n_0/_run_mode_flame1/_threshold_3.1/grf_cluster/mapflow/_grf_cluster1".
# 230204-11:13:27,469 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster0" <nipype.interfaces.fsl.model.Cluster>
# 230204-11:13:27,470 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_3_model_n_0/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate0".
# 230204-11:13:27,472 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster1" <nipype.interfaces.fsl.model.Cluster>
# 230204-11:13:27,474 nipype.workflow INFO:
# 	 [Node] Executing "_smoothestimate0" <nipype.interfaces.fsl.model.SmoothEstimate>
# 230204-11:13:28,209 nipype.workflow INFO:
# 	 [Node] Finished "_smoothestimate0", elapsed time 0.733154s.
# 230204-11:13:28,520 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster1", elapsed time 1.046487s.
# 230204-11:13:28,545 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster1", elapsed time 1.075569s.
# 230204-11:13:28,726 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster0", elapsed time 1.2551649999999999s.
# 230204-11:13:29,339 nipype.workflow INFO:
# 	 [Job 46] Completed (feat_level3_sst_roi.smoothestimate).
# 230204-11:13:29,341 nipype.workflow INFO:
# 	 [Job 54] Completed (feat_level3_sst_roi.smoothestimate).
# 230204-11:13:29,342 nipype.workflow INFO:
# 	 [Job 113] Completed (_grf_cluster1).
# 230204-11:13:29,343 nipype.workflow INFO:
# 	 [Job 114] Completed (_grf_cluster0).
# 230204-11:13:29,344 nipype.workflow INFO:
# 	 [Job 115] Completed (_grf_cluster1).
# 230204-11:13:29,344 nipype.workflow INFO:
# 	 [Job 116] Completed (_smoothestimate0).
# 230204-11:13:29,346 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 13 jobs ready. Free memory (GB): 118.80/120.00, Free processors: 6/12.
#                      Currently running:
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
#                        * feat_level3_sst_roi.flameo
# 230204-11:13:29,469 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_2_model_n_0/_run_mode_flame1/_threshold_2.3/grf_cluster/mapflow/_grf_cluster0".
# 230204-11:13:29,472 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_2_model_n_0/_run_mode_flame1/_threshold_3.1/grf_cluster/mapflow/_grf_cluster0".
# 230204-11:13:29,473 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster0" - collecting precomputed outputs
# 230204-11:13:29,474 nipype.workflow INFO:
# 	 [Node] "_grf_cluster0" found cached.
# 230204-11:13:29,474 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster0" - collecting precomputed outputs
# 230204-11:13:29,475 nipype.workflow INFO:
# 	 [Node] "_grf_cluster0" found cached.
# 230204-11:13:29,475 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_2_model_n_0/_run_mode_flame1/_threshold_2.3/grf_cluster/mapflow/_grf_cluster1".
# 230204-11:13:29,476 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_2_model_n_0/_run_mode_flame1/_threshold_3.1/grf_cluster/mapflow/_grf_cluster1".
# 230204-11:13:29,477 nipype.workflow INFO:
# 	 [Node] "_grf_cluster1" found cached.
# 230204-11:13:29,476 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster1" - collecting precomputed outputs
# 230204-11:13:29,478 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster1" - collecting precomputed outputs
# 230204-11:13:29,478 nipype.workflow INFO:
# 	 [Node] "_grf_cluster1" found cached.
# 230204-11:13:29,484 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_3_model_n_0/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate1".
# 230204-11:13:29,484 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_4_model_n_0/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate0".
# 230204-11:13:29,485 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_4_model_n_0/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate1".
# 230204-11:13:29,487 nipype.workflow INFO:
# 	 [Node] Executing "_smoothestimate0" <nipype.interfaces.fsl.model.SmoothEstimate>
# 230204-11:13:29,487 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_0_model_n_0/_run_mode_flame1/_threshold_2.3/grf_cluster/mapflow/_grf_cluster0".
# 230204-11:13:29,488 nipype.workflow INFO:
# 	 [Node] Executing "_smoothestimate1" <nipype.interfaces.fsl.model.SmoothEstimate>
# 230204-11:13:29,487 nipype.workflow INFO:
# 	 [Node] Executing "_smoothestimate1" <nipype.interfaces.fsl.model.SmoothEstimate>
# 230204-11:13:29,492 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster0" <nipype.interfaces.fsl.model.Cluster>
# 230204-11:13:30,12 nipype.workflow INFO:
# 	 [Node] Finished "_smoothestimate1", elapsed time 0.522149s.
# 230204-11:13:30,33 nipype.workflow INFO:
# 	 [Node] Finished "_smoothestimate1", elapsed time 0.54269s.
# 230204-11:13:30,165 nipype.workflow INFO:
# 	 [Node] Finished "_smoothestimate0", elapsed time 0.675604s.
# 230204-11:13:30,706 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster0", elapsed time 1.212652s.
# 230204-11:13:31,341 nipype.workflow INFO:
# 	 [Job 64] Completed (feat_level3_sst_roi.grf_cluster).
# 230204-11:13:31,342 nipype.workflow INFO:
# 	 [Job 65] Completed (feat_level3_sst_roi.grf_cluster).
# 230204-11:13:31,343 nipype.workflow INFO:
# 	 [Job 117] Completed (_smoothestimate1).
# 230204-11:13:31,344 nipype.workflow INFO:
# 	 [Job 118] Completed (_smoothestimate0).
# 230204-11:13:31,344 nipype.workflow INFO:
# 	 [Job 119] Completed (_smoothestimate1).
# ...
# 230204-11:43:59,288 nipype.workflow INFO:
# 	 [Node] Cached "_smoothestimate1" - collecting precomputed outputs
# 230204-11:43:59,289 nipype.workflow INFO:
# 	 [Node] "_smoothestimate1" found cached.
# 230204-11:44:01,141 nipype.workflow INFO:
# 	 [Job 45] Completed (feat_level3_sst_roi.smoothestimate).
# 230204-11:44:01,143 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 120.00/120.00, Free processors: 12/12.
# 230204-11:44:03,143 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 120.00/120.00, Free processors: 12/12.
# 230204-11:44:03,206 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_0_model_n_0/_run_mode_flame12/_threshold_2.3/grf_cluster/mapflow/_grf_cluster0".
# 230204-11:44:03,207 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_0_model_n_0/_run_mode_flame12/_threshold_2.3/grf_cluster/mapflow/_grf_cluster1".
# 230204-11:44:03,207 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_0_model_n_0/_run_mode_flame12/_threshold_3.1/grf_cluster/mapflow/_grf_cluster0".
# 230204-11:44:03,207 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_0_model_n_0/_run_mode_flame12/_threshold_3.1/grf_cluster/mapflow/_grf_cluster1".
# 230204-11:44:03,209 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster0" <nipype.interfaces.fsl.model.Cluster>
# 230204-11:44:03,210 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster1" <nipype.interfaces.fsl.model.Cluster>
# 230204-11:44:03,210 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster0" <nipype.interfaces.fsl.model.Cluster>
# 230204-11:44:03,212 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster1" <nipype.interfaces.fsl.model.Cluster>
# 230204-11:44:04,3 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster1", elapsed time 0.790956s.
# 230204-11:44:04,22 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster1", elapsed time 0.808881s.
# 230204-11:44:04,290 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster0", elapsed time 1.079232s.
# 230204-11:44:04,332 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster0", elapsed time 1.119455s.
# 230204-11:44:05,145 nipype.workflow INFO:
# 	 [Job 172] Completed (_grf_cluster0).
# 230204-11:44:05,146 nipype.workflow INFO:
# 	 [Job 173] Completed (_grf_cluster1).
# 230204-11:44:05,147 nipype.workflow INFO:
# 	 [Job 174] Completed (_grf_cluster0).
# 230204-11:44:05,148 nipype.workflow INFO:
# 	 [Job 175] Completed (_grf_cluster1).
# 230204-11:44:05,149 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 120.00/120.00, Free processors: 12/12.
# 230204-11:44:05,244 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_0_model_n_0/_run_mode_flame12/_threshold_2.3/grf_cluster/mapflow/_grf_cluster0".
# 230204-11:44:05,244 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_0_model_n_0/_run_mode_flame12/_threshold_3.1/grf_cluster/mapflow/_grf_cluster0".
# 230204-11:44:05,246 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster0" - collecting precomputed outputs
# 230204-11:44:05,246 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster0" - collecting precomputed outputs
# 230204-11:44:05,246 nipype.workflow INFO:
# 	 [Node] "_grf_cluster0" found cached.
# 230204-11:44:05,247 nipype.workflow INFO:
# 	 [Node] "_grf_cluster0" found cached.
# 230204-11:44:05,248 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_0_model_n_0/_run_mode_flame12/_threshold_2.3/grf_cluster/mapflow/_grf_cluster1".
# 230204-11:44:05,248 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_0_model_n_0/_run_mode_flame12/_threshold_3.1/grf_cluster/mapflow/_grf_cluster1".
# 230204-11:44:05,249 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster1" - collecting precomputed outputs
# 230204-11:44:05,250 nipype.workflow INFO:
# 	 [Node] "_grf_cluster1" found cached.
# 230204-11:44:05,250 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster1" - collecting precomputed outputs
# 230204-11:44:05,251 nipype.workflow INFO:
# 	 [Node] "_grf_cluster1" found cached.
# 230204-11:44:07,147 nipype.workflow INFO:
# 	 [Job 58] Completed (feat_level3_sst_roi.grf_cluster).
# 230204-11:44:07,149 nipype.workflow INFO:
# 	 [Job 59] Completed (feat_level3_sst_roi.grf_cluster).
# 230204-11:44:07,152 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 120.00/120.00, Free processors: 12/12.
# 230204-11:44:07,245 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.sinker" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_0_model_n_0/_run_mode_flame12/_threshold_2.3/sinker".
# 230204-11:44:07,246 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_sst_roi.sinker" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/NTNU_7T_SJSI/feat_level3_sst_roi/_contrast_n_0_model_n_0/_run_mode_flame12/_threshold_3.1/sinker".
# 230204-11:44:07,253 nipype.workflow INFO:
# 	 [Node] Executing "sinker" <nipype.interfaces.io.DataSink>
# 230204-11:44:07,255 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/third_level_model/level3_zstats/_contrast_n_0_model_n_0/_run_mode_flame12/zstat1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/model-0/model-0_subjectlevelcontrast-0_grouplevelcontrast-1_flame-12_desc-zstat.nii.gz
# 230204-11:44:07,256 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/third_level_model/level3_zstats/_contrast_n_0_model_n_0/_run_mode_flame12/zstat2.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/model-0/model-0_subjectlevelcontrast-0_grouplevelcontrast-2_flame-12_desc-zstat.nii.gz
# 230204-11:44:07,257 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/third_level_model/level3_copes/_contrast_n_0_model_n_0/_run_mode_flame12/cope1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/model-0/model-0_subjectlevelcontrast-0_grouplevelcontrast-1_flame-12_desc-cope.nii.gz
# 230204-11:44:07,257 nipype.workflow INFO:
# 	 [Node] Executing "sinker" <nipype.interfaces.io.DataSink>
# 230204-11:44:07,258 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/third_level_model/level3_copes/_contrast_n_0_model_n_0/_run_mode_flame12/cope2.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/model-0/model-0_subjectlevelcontrast-0_grouplevelcontrast-2_flame-12_desc-cope.nii.gz
# 230204-11:44:07,259 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/third_level_model/grf_thresholded_zstats_file/_contrast_n_0_model_n_0/_run_mode_flame12/_threshold_3.1/_grf_cluster0/zstat1_threshold.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/model-0/model-0_subjectlevelcontrast-0_grouplevelcontrast-1_flame-12_desc-zstat_voxelthreshold-3.1.nii.gz
# 230204-11:44:07,259 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/third_level_model/level3_varcopes/_contrast_n_0_model_n_0/_run_mode_flame12/varcope1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/model-0/model-0_subjectlevelcontrast-0_grouplevelcontrast-1_flame-12_desc-varcope.nii.gz
# 230204-11:44:07,260 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/third_level_model/grf_thresholded_zstats_file/_contrast_n_0_model_n_0/_run_mode_flame12/_threshold_3.1/_grf_cluster1/zstat2_threshold.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/model-0/model-0_subjectlevelcontrast-0_grouplevelcontrast-2_flame-12_desc-zstat_voxelthreshold-3.1.nii.gz
# 230204-11:44:07,260 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/third_level_model/level3_varcopes/_contrast_n_0_model_n_0/_run_mode_flame12/varcope2.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/model-0/model-0_subjectlevelcontrast-0_grouplevelcontrast-2_flame-12_desc-varcope.nii.gz
# 230204-11:44:07,261 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/third_level_model/level3_tdof_ts/_contrast_n_0_model_n_0/_run_mode_flame12/tdof_t1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/model-0/model-0_subjectlevelcontrast-0_grouplevelcontrast-1_flame-12_desc-tdof_t.nii.gz
# 230204-11:44:07,262 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/third_level_model/level3_zstats/_contrast_n_0_model_n_0/_run_mode_flame12/zstat1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/model-0/model-0_subjectlevelcontrast-0_grouplevelcontrast-1_flame-12_desc-zstat.nii.gz
# 230204-11:44:07,262 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/third_level_model/level3_zstats/_contrast_n_0_model_n_0/_run_mode_flame12/zstat2.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/model-0/model-0_subjectlevelcontrast-0_grouplevelcontrast-2_flame-12_desc-zstat.nii.gz
# 230204-11:44:07,263 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/third_level_model/level3_tdof_ts/_contrast_n_0_model_n_0/_run_mode_flame12/tdof_t2.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/model-0/model-0_subjectlevelcontrast-0_grouplevelcontrast-2_flame-12_desc-tdof_t.nii.gz
# 230204-11:44:07,263 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/third_level_model/level3_copes/_contrast_n_0_model_n_0/_run_mode_flame12/cope1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/model-0/model-0_subjectlevelcontrast-0_grouplevelcontrast-1_flame-12_desc-cope.nii.gz
# 230204-11:44:07,264 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/third_level_model/grf_thresholded_zstats_file/_contrast_n_0_model_n_0/_run_mode_flame12/_threshold_2.3/_grf_cluster0/zstat1_threshold.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/model-0/model-0_subjectlevelcontrast-0_grouplevelcontrast-1_flame-12_desc-zstat_voxelthreshold-2.3.nii.gz
# 230204-11:44:07,264 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/third_level_model/level3_copes/_contrast_n_0_model_n_0/_run_mode_flame12/cope2.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/model-0/model-0_subjectlevelcontrast-0_grouplevelcontrast-2_flame-12_desc-cope.nii.gz
# 230204-11:44:07,265 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/third_level_model/grf_thresholded_zstats_file/_contrast_n_0_model_n_0/_run_mode_flame12/_threshold_2.3/_grf_cluster1/zstat2_threshold.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/model-0/model-0_subjectlevelcontrast-0_grouplevelcontrast-2_flame-12_desc-zstat_voxelthreshold-2.3.nii.gz
# 230204-11:44:07,265 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/third_level_model/level3_varcopes/_contrast_n_0_model_n_0/_run_mode_flame12/varcope1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/model-0/model-0_subjectlevelcontrast-0_grouplevelcontrast-1_flame-12_desc-varcope.nii.gz
# 230204-11:44:07,265 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/third_level_model/level3_varcopes/_contrast_n_0_model_n_0/_run_mode_flame12/varcope2.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/model-0/model-0_subjectlevelcontrast-0_grouplevelcontrast-2_flame-12_desc-varcope.nii.gz
# 230204-11:44:07,266 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/third_level_model/level3_tdof_ts/_contrast_n_0_model_n_0/_run_mode_flame12/tdof_t1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/model-0/model-0_subjectlevelcontrast-0_grouplevelcontrast-1_flame-12_desc-tdof_t.nii.gz
# 230204-11:44:07,267 nipype.workflow INFO:
# 	 [Node] Finished "sinker", elapsed time 0.011735s.
# 230204-11:44:07,267 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/third_level_model/level3_tdof_ts/_contrast_n_0_model_n_0/_run_mode_flame12/tdof_t2.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/group_level_model/NTNU_7T_SJSI/model-0/model-0/model-0_subjectlevelcontrast-0_grouplevelcontrast-2_flame-12_desc-tdof_t.nii.gz
# 230204-11:44:07,268 nipype.workflow INFO:
# 	 [Node] Finished "sinker", elapsed time 0.008935s.
# 230204-11:44:09,149 nipype.workflow INFO:
# 	 [Job 82] Completed (feat_level3_sst_roi.sinker).
# 230204-11:44:09,151 nipype.workflow INFO:
# 	 [Job 83] Completed (feat_level3_sst_roi.sinker).
# 230204-11:44:09,153 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 120.00/120.00, Free processors: 12/12.

# %%
from nipype.utils.filemanip import loadpkl
res = loadpkl('/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level3_sst_roi/_contrast_n_0_model_n_0/_run_mode_flame1/_threshold_3.1/sinker/result_sinker.pklz')
res

# %%
res.outputs
