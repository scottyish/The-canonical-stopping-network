# %% [markdown]
# # FSL FEAT nipype

# %%
import os
import glob

import nipype
import nipype.interfaces.io as nio
import nipype.interfaces.fsl as fsl
import nipype.interfaces.ants as ants
import nipype.pipeline.engine as pe
import nipype.interfaces.utility as util
import nipype.algorithms.modelgen as model
# Out:
# 230223-10:11:05,799 nipype.utils WARNING:
# 	 A newer version (1.8.4) of nipy/nipype is available. You are using 1.7.0

# %% [markdown]
# ## pipeline setup

# %%
# Which dataset are we looking at?
# this_dataset = 'Leipzig_7T_SM'
this_dataset = 'Leipzig_7T_GdH'
# this_dataset = 'NTNU_7T_SJSI'
# this_dataset = 'aron_3T'
# this_dataset = 'openfmri_3T'

# %%
# general set-up
base_dir = '/home/scotti/projects/3t_7t_sst_comparison'
work_dir = os.path.join(base_dir, 'processing', 'nipype_workflow_folders')
roi_hp_dir = os.path.join(base_dir, 'derivatives', 'fsl_feat_roi_func', this_dataset)

hpcutoff = 10000.   # in seconds
model_n = [0]
spaces = ['MNI152NLin2009cAsym']   # shouldn't touch this but just in case we _do_ want to go back to MNI....

if this_dataset == 'Leipzig_7T_SM':
    t_r = 3.0
    subject_ids = [x.split('/')[-2].split('-')[-1] for x in glob.glob(os.path.join(roi_hp_dir, 'sub-*/'))]
    numsubs = len(subject_ids)
    task = 'stop'
elif this_dataset == 'Leipzig_7T_GdH':
    t_r = 2.0
    subject_ids = [x.split('/')[-1].split('-')[-1] for x in glob.glob(os.path.join(roi_hp_dir, 'sub-*T'))]
    numsubs = len(subject_ids)
    task = 'stop'
elif this_dataset == 'aron_3T':
    t_r = 2.0
    subject_ids = [x.split('/')[-2].split('-')[-1] for x in glob.glob(os.path.join(roi_hp_dir, 'sub-*/'))]
    numsubs = len(subject_ids)
    task = 'stopsignal'
elif this_dataset == 'NTNU_7T_SJSI':
    t_r = 1.38
#     numsubs = 20
    subject_ids = [x.split('/')[-2].split('-')[-1] for x in glob.glob(os.path.join(roi_hp_dir, 'sub-*/'))]
    numsubs = len(subject_ids)
    task = 'sst'
elif this_dataset == 'openfmri_3T':
    t_r = 2.0
#     numsubs = 97
    subject_ids = [x.split('/')[-2].split('-')[-1] for x in glob.glob(os.path.join(roi_hp_dir, 'sub-*/'))]
    numsubs = len(subject_ids)
    task = 'stopsignal'
    
# make sure all files required are found correctly    
rois_ = glob.glob(os.path.join(base_dir, 'derivatives', 'fsl_feat_roi_func', this_dataset,
                                        'sub-*', 'func',  f'sub-*_task-{task}_run-*_space-*_desc-preproc_bold.nii.gz'))
masks_ = glob.glob(os.path.join(base_dir, 'derivatives', 'fmriprep_feat_hack', this_dataset, 
                              'sub-*', 'func', f'sub-*_task-{task}_run-*_space-*_desc-brain_mask.nii.gz'))
# comp_ = glob.glob(os.path.join(base_dir, 'derivatives', 'fmriprep_feat_hack', this_dataset, 
#                                     'sub-*', 'anat', 'sub-*_from-T1w_to-MNI152NLin2009cAsym_mode-image_xfm.h5'))
# xfm_ = glob.glob(os.path.join(base_dir, 'derivatives', 'fmriprep_feat_hack', this_dataset,
#                               'sub-*', 'func',  f'sub-*_task-{task}_run-*_from-scanner_to-T1w_mode-image_xfm.txt'))
events_ = glob.glob(os.path.join(base_dir, f'derivatives/event_files/{this_dataset}/sub-*/func/sub-*run-*_events.tsv'))
    
template_brain = os.path.join(base_dir,'sourcedata/templates/mni_icbm152_t1_tal_nlin_asym_09c_brain.nii')

# %%
print(f"""
this dataset : {this_dataset}
tr : {t_r}
number of subjects : {numsubs}
subject ids : {subject_ids}
roi_hp_dir : {roi_hp_dir}
model ns : {model_n}
no. rois : {len(rois_)}
no. masks : {len(masks_)}
no.events : {len(events_)}

""")
# Out:
# this dataset : Leipzig_7T_GdH
# tr : 2.0
# number of subjects : 17
# subject ids : ['KCAT', 'MRCT', 'RSIT', 'TS6T', 'BI3T', 'SPGT', 'VL1T', 'NM3T', 'GAIT', 'WW2T', 'FMFT', 'LV2T', 'KP6T', 'PF5T', 'ZK4T', 'UM2T', 'SC1T']
# roi_hp_dir : /home/scotti/projects/3t_7t_sst_comparison/derivatives/fsl_feat_roi_func/Leipzig_7T_GdH
# model ns : [0]
# no. rois : 51
# no. masks : 51
# no.events : 51

# %% [markdown]
# # first & second level models

# %%
def get_session_info(subject_id, run, task='stop', this_dataset='Leipzig_7T_SM', space='T1w', shift=-1.38/2, model_n=0,
                    root_dir='/home/scotti/projects/3t_7t_sst_comparison', include_physio=True):
    # other space: MNI152NLin2009cAsym
    import pandas as pd
    import numpy as np
    import os
    from nipype.interfaces.base import Bunch
            
    ### files ###
    sub = subject_id
    event_fn = f'{root_dir}/derivatives/event_files/{this_dataset}/sub-{sub}/func/sub-{sub}_task-{task}_run-{run}_events.tsv'
    confounds_fn = f'{root_dir}/derivatives/fmriprep/{this_dataset}/fmriprep/fmriprep/sub-{sub}/func/sub-{sub}_task-{task}_run-{run}_desc-confounds_timeseries.tsv'

    events = pd.read_csv(event_fn, sep='\t', index_col=None)
    events['duration'] = 0.001  # stick functions
    if model_n == 0:
        events = events.loc[events.trial_type.isin(['ss', 'fs', 'go'])]
    elif model_n == 1:
        events = events.loc[events.trial_type.isin(['response_left', 'response_right'])]
    events = events[['onset', 'trial_type', 'duration']]

    # slice time correction, nb: shift should be a negative number for STC
    events['onset'] += shift  

    ### confounds ###
    confounds = pd.read_csv(confounds_fn, sep='\t')
#        cosine_cols = [x for x in confounds.columns if 'cos' in x]
    include_confounds = ['trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z', 'dvars', 'framewise_displacement'] #+ cosine_cols
    confounds = confounds[include_confounds].fillna(method='bfill')

    # get retroicor
    if include_physio:
        ## take first 20 aCompCor components
#         print("No retroicor found, including 20 a_comp_cor components")
        a_comp_cor = pd.read_csv(confounds_fn, sep='\t')[['a_comp_cor_' + str(x).zfill(2) for x in range(20)]]
        confounds = pd.concat([confounds, a_comp_cor], axis=1)

    # save the confounds that we actually include in the GLM to csv, no header or index
    confounds_fn = f'{root_dir}/derivatives/confounds/{this_dataset}/sub-{sub}/func/sub-{sub}_task-{task}_run-{run}_desc-confounds_timeseries.txt'
    os.makedirs(os.path.dirname(confounds_fn), exist_ok=True)
    confounds.to_csv(confounds_fn, sep='\t', header=False, index=False)

    ### Make bunch ###
    if model_n == 0:
        conditions=['fs',
                    'ss',
                    'go']

    elif model_n ==1:
        conditions = [
                     'response_left',
                     'response_right'
                     ]

    onsets = [events.loc[events.trial_type==trial_type,'onset'].tolist() for trial_type in conditions]
    durations = [events.loc[events.trial_type==trial_type,'duration'].tolist() for trial_type in conditions]
    amplitudes = [[1] * events.loc[events.trial_type==trial_type,'onset'].shape[0] for trial_type in conditions]
#             amplitudes = [events.loc[events.trial_type==trial_type,'modulation'].tolist() for trial_type in conditions]

    info = Bunch(conditions=conditions,
                 onsets=onsets,
                 durations=durations,
                 amplitudes=amplitudes)
#         print(info)
    
    # always return info and the confounds_fn
    return info, confounds_fn #, contrasts[0]

if model_n == [0]:
    contrasts = [('fs', 'T', ['fs'], [1.0]),
                 ('ss', 'T', ['ss'], [1.0]),
                 ('go', 'T', ['go'], [1.0]),
                 ('fs-go', 'T', ['fs', 'go'], [1, -1]),
                 ('fs-ss', 'T', ['fs', 'ss'], [1, -1]),
                 ('ss-go', 'T', ['ss', 'go'], [1, -1])
                 ]
    
elif model_n == [1]:
    contrasts = [('response_left', 'T', ['response_left'], [1.0]),
                 ('response_right', 'T', ['response_right'], [1.0]),
                 ('left-right', 'T', ['response_left','response_right'], [1,-1])
                 ]

# %%
def get_runs_per_sub(subject_id):
    # here we can add the runs per subject if some subject miss a run or two
    if not subject_id in ['DA9T']:
        runs = [1,2,3]
    else:
        runs = [1,2]
    
    return runs

# %%
workflow = pe.Workflow(name='feat_level12_sst_roi')
workflow.base_dir = os.path.join(base_dir, 'processing', 'nipype_workflow_folders', this_dataset)
workflow.config = {"execution": {"crashdump_dir":os.path.join(base_dir, 'processing', 'crashdumps')}}

# identity
identity = pe.Node(util.IdentityInterface(fields=['subject_id', 'space', 'model_n']), name='identity')
identity.iterables = [('subject_id', subject_ids),
                      ('space', spaces),
                      ('model_n', model_n)]

# selector
# if running only one run, copy the mask from run 1 to run 2, 'mask' variable below needs a list, it will crash if only one is found
#(terrible way to get around this.. fix at some point.. lazy..)
templates = {'roi_funcs': os.path.join(base_dir, 'derivatives', 'fsl_feat_roi_func', this_dataset,
                                            'sub-{subject_id}', 'func',  
                                            f'sub-{{subject_id}}_task-{task}_run-*_space-{{space}}*_desc-preproc_bold.nii.gz'),
             'mask': os.path.join(base_dir, 'derivatives', 'fmriprep_feat_hack', this_dataset, 
                                  'sub-{subject_id}', 'func', 
                                  f'sub-{{subject_id}}_task-{task}_run-*_space-{{space}}_desc-brain_mask.nii.gz')}

selector = pe.Node(nio.SelectFiles(templates), name='selector')

workflow.connect(identity, 'subject_id', selector, 'subject_id')
workflow.connect(identity, 'space', selector, 'space')

# get run info per sub
run_info_getter = pe.Node(util.Function(function=get_runs_per_sub,
                                        input_names=['subject_id'],
                                        output_names=['runs']), name='run_info_getter')
workflow.connect(identity, 'subject_id', run_info_getter, 'subject_id')

# session info getter
session_info_getter = pe.MapNode(util.Function(function=get_session_info,
                                     input_names=['subject_id', 'run', 'task', 'this_dataset', 'space', 'shift', 'model_n'],
                                     output_names=['session_info', 'confounds']),
                                 iterfield=['run'],
                                 name='session_info_getter')
session_info_getter.inputs.task=task
session_info_getter.inputs.this_dataset=this_dataset
session_info_getter.inputs.space='MNI152NLin2009cAsym'
session_info_getter.inputs.shift = -t_r/2

workflow.connect(identity, 'subject_id', session_info_getter, 'subject_id')
workflow.connect(run_info_getter, 'runs', session_info_getter, 'run')
workflow.connect(identity, 'model_n', session_info_getter, 'model_n')


# model setup
specifymodel = pe.Node(model.SpecifyModel(), name='specifymodel1')
specifymodel.inputs.input_units = 'secs'
specifymodel.inputs.time_repetition = t_r
specifymodel.inputs.high_pass_filter_cutoff = hpcutoff

workflow.connect(session_info_getter, 'session_info', specifymodel, 'subject_info')
## old flow (with cosines): immediately connect to specifymodel
workflow.connect(selector, 'roi_funcs', specifymodel, 'functional_runs')

# Level 1 design
level1design = pe.Node(interface=fsl.Level1Design(), name="level1design")
level1design.inputs.interscan_interval = t_r
level1design.inputs.bases = {'dgamma': {'derivs': True}}
level1design.inputs.contrasts = contrasts
level1design.inputs.model_serial_correlations = True

workflow.connect(specifymodel, 'session_info', level1design, 'session_info')
# workflow.connect(session_info_getter, 'contrasts', level1design, 'contrasts')

# FEAT model
modelgen = pe.MapNode(interface=fsl.FEATModel(), iterfield=['ev_files', 'fsf_file', 'args'], name='modelgen')

workflow.connect(level1design, 'ev_files', modelgen, 'ev_files')
workflow.connect(level1design, 'fsf_files', modelgen, 'fsf_file')
workflow.connect(session_info_getter, 'confounds', modelgen, 'args')   # add confounds here


# FILM GLS
iterfield = ['design_file', 'in_file', 'tcon_file']
modelestimate = pe.MapNode(interface=fsl.FILMGLS(smooth_autocorr=False, # prewhitening yes or no?
#                                                  autocorr_noestimate=True,
                                                 mask_size = 0,
                                                 threshold = 100),  # threshold for signal, default = 1000 but will lose data that way as 1000 is higher than alot of the voxel signals
                                                 name='modelestimate',
                                                 iterfield=iterfield,
                                                 mem_gb=10,
                                                 full_data = True,
                                                 output_pwdata=True)

# ## old flow (with cosines): immediately connect to modelestimate
workflow.connect(selector, 'roi_funcs', modelestimate, 'in_file')
# # new flow: connect high-passed data
# workflow.connect(highpass, 'out_file', modelestimate, 'in_file')


workflow.connect(modelgen, 'design_file', modelestimate, 'design_file')
workflow.connect(modelgen, 'con_file', modelestimate, 'tcon_file')


#### Fixed effects
# merge copes, varcopes
copemerge = pe.MapNode(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="copemerge")

varcopemerge = pe.MapNode(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="varcopemerge")

maskemerge = pe.MapNode(interface=fsl.Merge(dimension='t'),
                       iterfield=['in_files'],
                       name="maskemerge")

def sort_copes(files):
    numelements = len(files[0])
    outfiles = []
    for i in range(numelements):
        outfiles.insert(i,[])
        for j, elements in enumerate(files):
            outfiles[i].append(elements[i])
    return outfiles

workflow.connect(modelestimate, ('copes',sort_copes), copemerge, 'in_files')
workflow.connect(modelestimate, ('varcopes',sort_copes), varcopemerge, 'in_files')


level2model = pe.Node(interface=fsl.L2Model(), name='l2model')
def num_copes(files):
    return len(files)
workflow.connect(modelestimate, ('copes',num_copes), level2model, 'num_copes')


pickfirst = lambda x: x[0]
flameo = pe.MapNode(
    interface=fsl.FLAMEO(run_mode='fe'),
    name="flameo",
    iterfield=['cope_file', 'var_cope_file'])

workflow.connect([
    (selector, flameo, [(('mask', pickfirst), 'mask_file')]),
    (copemerge, flameo, [('merged_file', 'cope_file')]),
    (varcopemerge, flameo, [('merged_file', 'var_cope_file')]),
    (level2model, flameo, [('design_mat', 'design_file'),
                           ('design_con', 't_con_file'), 
                           ('design_grp', 'cov_split_file')]),
])

# ## Warp to MNI-space
# def warp_files(copes, varcopes, zstats, tdofs, mat, template_brain):
#     # stolen from https://dpaniukov.github.io/2016/07/14/three-level-analysis-with-fsl-and-ants-2.html
#     import nipype.interfaces.ants as ants

#     out_copes = []
#     out_varcopes = []
#     out_zstats = []
#     out_tdofs = []
    
#     warp = ants.ApplyTransforms()
#     warp.inputs.input_image_type = 0
#     warp.inputs.interpolation = 'Linear'
#     warp.inputs.invert_transform_flags = [False] #,False]
#     warp.inputs.reference_image = template_brain
#     warp.inputs.transforms = mat

#     if not isinstance(copes, list):
#         copes = [copes]
#         varcopes = [varcopes]
#         zstats = [zstats]
#         tdofs = [tdofs]
    
#     for cope in copes:
#         warp.inputs.input_image = cope
#         res=warp.run()
#         out_copes.append(str(res.outputs.output_image))

#     for varcope in varcopes:
#         warp.inputs.input_image = varcope
#         res=warp.run()
#         out_varcopes.append(str(res.outputs.output_image))
        
#     for zstat in zstats:
#         warp.inputs.input_image = zstat
#         res=warp.run()
#         out_zstats.append(str(res.outputs.output_image))
    
#     for tdof in tdofs:
#         warp.inputs.input_image = tdof
#         res=warp.run()
#         out_tdofs.append(str(res.outputs.output_image))

#     return out_copes, out_varcopes, out_zstats, out_tdofs

# warpfunc = pe.MapNode(util.Function(input_names=['copes', 'varcopes', 'zstats', 'tdofs', 'mat','template_brain'],
#                                output_names=['out_copes', 'out_varcopes', 'out_zstats', 'out_tdofs'],
#                                function=warp_files),
#                                iterfield=['copes', 'varcopes', 'zstats', 'tdofs'],
#                   name='warpfunc')

# warpfunc.inputs.template_brain = template_brain
# workflow.connect(flameo, 'copes', warpfunc, 'copes')
# workflow.connect(flameo, 'var_copes', warpfunc, 'varcopes')
# workflow.connect(flameo, 'zstats', warpfunc, 'zstats')
# workflow.connect(flameo, 'tdof', warpfunc, 'tdofs')
# workflow.connect(selector, 'composite', warpfunc, 'mat')

#### post-FE analyis
# Smoothness estimation
smoothestimate = pe.MapNode(fsl.SmoothEstimate(), iterfield=['zstat_file'], name='smoothestimate')

workflow.connect(selector, ('mask', pickfirst), smoothestimate, 'mask_file')
workflow.connect(flameo, 'zstats', smoothestimate, 'zstat_file')

#
get_volume = pe.Node(fsl.ImageStats(op_string = '-V'), name='get_volume')
workflow.connect(selector, ('mask', pickfirst), get_volume, 'in_file')

# Cluster threshold
grf_cluster = pe.MapNode(fsl.Cluster(), iterfield=['dlh', 'in_file'], name='grf_cluster')
grf_cluster.iterables = [("threshold", [2.3, 3.1])] 
workflow.connect(smoothestimate, 'dlh', grf_cluster, 'dlh')
workflow.connect(flameo, 'zstats', grf_cluster, 'in_file')

def convert_volume(input):
    return int(input[1])

workflow.connect(get_volume, ('out_stat', convert_volume), grf_cluster, 'volume')
grf_cluster.inputs.out_threshold_file = True


## datasink
ds = pe.Node(nio.DataSink(), name='datasink')
ds.inputs.base_directory = os.path.join(base_dir, 'derivatives', 'glm_feat_sst_roi')

#_model_n_0_smoothing_fwhm_1p5_space_T1w_subject_id_002
substitutions = [(f'mni/level2_{stat_type}s/_model_n_{model_n_}_space_MNI152NLin2009cAsym_subject_id_{sub}/_flameo{contrast_n}/{stat_type}1.nii.gz',
                  f'{this_dataset}/sub-{sub}/func/model-{model_n_}/sub-{sub}_task-{task}_space-MNI152NLin2009cAsym_model-{model_n_}_contrast-{contrast_n}_desc-{stat_type}.nii.gz')
                  for sub in subject_ids
                  for contrast_n in range(len(contrasts))
                  for model_n_ in model_n
                  for stat_type in ['cope', 'zstat', 'varcope', 'tdof_t']
                  ]


# substitutions = [(f'mni/level2_{stat_type}s/_model_n_{model_n_}_space_MNI152NLin2009cAsym_subject_id_{sub}/_warpfunc{contrast_n}/{stat_type}1_trans.nii.gz',
#                    f'{this_dataset}/sub-{sub}/func/model-{model_n_}/sub-{sub}_task-{task}_space-MNI152NLin2009cAsym_model-{model_n_}_contrast-{contrast_n}_desc-{stat_type}.nii.gz')
#                   for sub in subject_ids
#                   for contrast_n in range(len(contrasts))
#                   for model_n_ in model_n
#                   for stat_type in ['cope', 'zstat', 'varcope', 'tdof_t']
#                   ]

ds.inputs.substitutions = substitutions


## cluster thresholds: leave for now, this is more of a third-level model thing anyway
# workflow.connect(grf_cluster, 'threshold_file', ds, 'grf_thresholded_zstats_file')
# workflow.connect(grf_cluster, 'locnalmax_txt_file', ds, 'grf_localmax_txt_file')

## T1w-space
workflow.connect(flameo, 'zstats', ds, 'subject_level_model.mni.level2_zstats')
workflow.connect(flameo, 'copes', ds, 'subject_level_model.mni.level2_copes')
workflow.connect(flameo, 'var_copes', ds, 'subject_level_model.mni.level2_varcopes')
workflow.connect(flameo, 'tdof', ds, 'subject_level_model.mni.level2_tdof_ts')

# ## MNI-space
# workflow.connect(warpfunc, 'out_zstats', ds, 'subject_level_model.mni.level2_zstats')
# workflow.connect(warpfunc, 'out_copes', ds, 'subject_level_model.mni.level2_copes')
# workflow.connect(warpfunc, 'out_varcopes', ds, 'subject_level_model.mni.level2_varcopes')
# workflow.connect(warpfunc, 'out_tdofs', ds, 'subject_level_model.mni.level2_tdof_ts')
# workflow.connect(flameo, 'tdof', ds, 'level2_tdof')

# %%
workflow.run(plugin='MultiProc', plugin_args={'n_procs':8, 'memory_gb': 160})
# Out:
# 230223-10:11:15,171 nipype.workflow INFO:
# 	 Workflow feat_level12_sst_roi settings: ['check', 'execution', 'logging', 'monitoring']
# 230223-10:11:15,362 nipype.workflow INFO:
# 	 Running in parallel.
# 230223-10:11:15,417 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 34 jobs ready. Free memory (GB): 160.00/160.00, Free processors: 8/8.
# 230223-10:11:15,522 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_KCAT/run_info_getter".
# 230223-10:11:15,521 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_KCAT/selector".
# 230223-10:11:15,522 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_MRCT/selector".
# 230223-10:11:15,522 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_MRCT/run_info_getter".
# 230223-10:11:15,524 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_RSIT/run_info_getter".
# 230223-10:11:15,524 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_RSIT/selector".
# 230223-10:11:15,524 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_TS6T/run_info_getter".
# 230223-10:11:15,524 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_TS6T/selector".
# 230223-10:11:15,528 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:11:15,528 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:11:15,528 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230223-10:11:15,529 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230223-10:11:15,529 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:11:15,529 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:11:15,530 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230223-10:11:15,530 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230223-10:11:15,531 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000726s.
# 230223-10:11:15,532 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000614s.
# 230223-10:11:15,533 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001666s.
# 230223-10:11:15,533 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000668s.
# 230223-10:11:15,534 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001369s.
# 230223-10:11:15,534 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000689s.
# 230223-10:11:15,534 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001442s.
# 230223-10:11:15,534 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.002052s.
# 230223-10:11:17,418 nipype.workflow INFO:
# 	 [Job 0] Completed (feat_level12_sst_roi.selector).
# 230223-10:11:17,420 nipype.workflow INFO:
# 	 [Job 1] Completed (feat_level12_sst_roi.run_info_getter).
# 230223-10:11:17,421 nipype.workflow INFO:
# 	 [Job 2] Completed (feat_level12_sst_roi.selector).
# 230223-10:11:17,422 nipype.workflow INFO:
# 	 [Job 3] Completed (feat_level12_sst_roi.run_info_getter).
# 230223-10:11:17,423 nipype.workflow INFO:
# 	 [Job 4] Completed (feat_level12_sst_roi.selector).
# 230223-10:11:17,424 nipype.workflow INFO:
# 	 [Job 5] Completed (feat_level12_sst_roi.run_info_getter).
# 230223-10:11:17,425 nipype.workflow INFO:
# 	 [Job 6] Completed (feat_level12_sst_roi.selector).
# 230223-10:11:17,426 nipype.workflow INFO:
# 	 [Job 7] Completed (feat_level12_sst_roi.run_info_getter).
# 230223-10:11:17,428 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 34 jobs ready. Free memory (GB): 160.00/160.00, Free processors: 8/8.
# 230223-10:11:17,489 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_BI3T/run_info_getter".
# 230223-10:11:17,490 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SPGT/selector".
# 230223-10:11:17,490 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_VL1T/run_info_getter".
# 230223-10:11:17,490 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_VL1T/selector".
# 230223-10:11:17,490 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_NM3T/selector".
# 230223-10:11:17,490 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SPGT/run_info_getter".
# 230223-10:11:17,490 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_NM3T/run_info_getter".
# 230223-10:11:17,490 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_BI3T/selector".
# 230223-10:11:17,493 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:11:17,497 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000548s.
# 230223-10:11:17,493 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230223-10:11:17,493 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230223-10:11:17,494 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:11:17,494 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:11:17,495 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:11:17,495 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000383s.
# 230223-10:11:17,496 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001035s.
# 230223-10:11:17,496 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000382s.
# 230223-10:11:17,495 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230223-10:11:17,497 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001599s.
# 230223-10:11:17,499 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.000901s.
# 230223-10:11:17,499 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000368s.
# 230223-10:11:17,500 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230223-10:11:17,503 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001518s.
# 230223-10:11:19,419 nipype.workflow INFO:
# 	 [Job 8] Completed (feat_level12_sst_roi.selector).
# 230223-10:11:19,420 nipype.workflow INFO:
# 	 [Job 9] Completed (feat_level12_sst_roi.run_info_getter).
# 230223-10:11:19,422 nipype.workflow INFO:
# 	 [Job 10] Completed (feat_level12_sst_roi.selector).
# 230223-10:11:19,423 nipype.workflow INFO:
# 	 [Job 11] Completed (feat_level12_sst_roi.run_info_getter).
# 230223-10:11:19,424 nipype.workflow INFO:
# 	 [Job 12] Completed (feat_level12_sst_roi.selector).
# 230223-10:11:19,425 nipype.workflow INFO:
# 	 [Job 13] Completed (feat_level12_sst_roi.run_info_getter).
# 230223-10:11:19,426 nipype.workflow INFO:
# 	 [Job 14] Completed (feat_level12_sst_roi.selector).
# 230223-10:11:19,427 nipype.workflow INFO:
# 	 [Job 15] Completed (feat_level12_sst_roi.run_info_getter).
# 230223-10:11:19,429 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 42 jobs ready. Free memory (GB): 160.00/160.00, Free processors: 8/8.
# 230223-10:11:19,469 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_GAIT/selector".
# 230223-10:11:19,469 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_WW2T/selector".
# 230223-10:11:19,469 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_WW2T/run_info_getter".
# 230223-10:11:19,469 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_FMFT/run_info_getter".
# 230223-10:11:19,469 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_LV2T/selector".
# 230223-10:11:19,469 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_FMFT/selector".
# 230223-10:11:19,469 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_LV2T/run_info_getter".
# 230223-10:11:19,469 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_GAIT/run_info_getter".
# 230223-10:11:19,472 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230223-10:11:19,475 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001045s.
# 230223-10:11:19,473 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:11:19,473 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230223-10:11:19,474 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:11:19,474 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230223-10:11:19,474 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230223-10:11:19,474 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:11:19,475 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000397s.
# 230223-10:11:19,475 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:11:19,475 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000353s.
# 230223-10:11:19,476 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001209s.
# 230223-10:11:19,477 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001072s.
# 230223-10:11:19,477 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.00115s.
# 230223-10:11:19,478 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.00036s.
# 230223-10:11:19,479 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000389s.
# 230223-10:11:21,421 nipype.workflow INFO:
# 	 [Job 16] Completed (feat_level12_sst_roi.selector).
# 230223-10:11:21,423 nipype.workflow INFO:
# 	 [Job 17] Completed (feat_level12_sst_roi.run_info_getter).
# 230223-10:11:21,424 nipype.workflow INFO:
# 	 [Job 18] Completed (feat_level12_sst_roi.selector).
# 230223-10:11:21,425 nipype.workflow INFO:
# 	 [Job 19] Completed (feat_level12_sst_roi.run_info_getter).
# 230223-10:11:21,426 nipype.workflow INFO:
# 	 [Job 20] Completed (feat_level12_sst_roi.selector).
# 230223-10:11:21,427 nipype.workflow INFO:
# 	 [Job 21] Completed (feat_level12_sst_roi.run_info_getter).
# 230223-10:11:21,428 nipype.workflow INFO:
# 	 [Job 22] Completed (feat_level12_sst_roi.selector).
# 230223-10:11:21,429 nipype.workflow INFO:
# 	 [Job 23] Completed (feat_level12_sst_roi.run_info_getter).
# 230223-10:11:21,432 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 50 jobs ready. Free memory (GB): 160.00/160.00, Free processors: 8/8.
# 230223-10:11:21,503 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_KP6T/selector".
# 230223-10:11:21,511 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000367s.
# 230223-10:11:21,504 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_KP6T/run_info_getter".
# 230223-10:11:21,505 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_PF5T/selector".
# 230223-10:11:21,506 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_PF5T/run_info_getter".
# 230223-10:11:21,507 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230223-10:11:21,507 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:11:21,507 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_ZK4T/selector".
# 230223-10:11:21,509 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230223-10:11:21,509 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:11:21,509 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_ZK4T/run_info_getter".
# 230223-10:11:21,510 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000439s.
# 230223-10:11:21,510 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230223-10:11:21,510 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_UM2T/selector".
# 230223-10:11:21,511 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001398s.
# 230223-10:11:21,511 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_UM2T/run_info_getter".
# 230223-10:11:21,512 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001179s.
# 230223-10:11:21,512 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:11:21,513 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001073s.
# 230223-10:11:21,514 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230223-10:11:21,514 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000387s.
# 230223-10:11:21,515 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:11:21,517 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000322s.
# 230223-10:11:21,517 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001279s.
# 230223-10:11:23,423 nipype.workflow INFO:
# 	 [Job 24] Completed (feat_level12_sst_roi.selector).
# 230223-10:11:23,425 nipype.workflow INFO:
# 	 [Job 25] Completed (feat_level12_sst_roi.run_info_getter).
# 230223-10:11:23,426 nipype.workflow INFO:
# 	 [Job 26] Completed (feat_level12_sst_roi.selector).
# 230223-10:11:23,428 nipype.workflow INFO:
# 	 [Job 27] Completed (feat_level12_sst_roi.run_info_getter).
# 230223-10:11:23,429 nipype.workflow INFO:
# 	 [Job 28] Completed (feat_level12_sst_roi.selector).
# 230223-10:11:23,430 nipype.workflow INFO:
# 	 [Job 29] Completed (feat_level12_sst_roi.run_info_getter).
# 230223-10:11:23,431 nipype.workflow INFO:
# 	 [Job 30] Completed (feat_level12_sst_roi.selector).
# 230223-10:11:23,432 nipype.workflow INFO:
# 	 [Job 31] Completed (feat_level12_sst_roi.run_info_getter).
# 230223-10:11:23,435 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 58 jobs ready. Free memory (GB): 160.00/160.00, Free processors: 8/8.
# 230223-10:11:23,482 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/selector".
# 230223-10:11:23,484 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_KCAT/get_volume".
# 230223-10:11:23,483 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/run_info_getter".
# 230223-10:11:23,485 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_MRCT/get_volume".
# 230223-10:11:23,485 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230223-10:11:23,485 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:11:23,486 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_RSIT/get_volume".
# 230223-10:11:23,487 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_TS6T/get_volume".
# 230223-10:11:23,488 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 230223-10:11:23,488 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_BI3T/get_volume".
# 230223-10:11:23,488 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000371s.
# 230223-10:11:23,488 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001139s.
# 230223-10:11:23,489 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SPGT/get_volume".
# 230223-10:11:23,490 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 230223-10:11:23,491 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 230223-10:11:23,493 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 230223-10:11:23,493 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 230223-10:11:23,544 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 230223-10:11:25,425 nipype.workflow INFO:
# 	 [Job 32] Completed (feat_level12_sst_roi.selector).
# 230223-10:11:25,427 nipype.workflow INFO:
# 	 [Job 33] Completed (feat_level12_sst_roi.run_info_getter).
# 230223-10:11:25,430 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 60 jobs ready. Free memory (GB): 158.80/160.00, Free processors: 2/8.
#                      Currently running:
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
# 230223-10:11:25,487 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_VL1T/get_volume".
# 230223-10:11:25,492 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 230223-10:11:25,489 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_NM3T/get_volume".
# 230223-10:11:25,494 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 230223-10:11:27,429 nipype.workflow INFO:
# 	 [MultiProc] Running 8 tasks, and 60 jobs ready. Free memory (GB): 158.40/160.00, Free processors: 0/8.
#                      Currently running:
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
# 230223-10:12:33,674 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 70.12847s.
# 230223-10:12:35,497 nipype.workflow INFO:
# 	 [Job 36] Completed (feat_level12_sst_roi.get_volume).
# 230223-10:12:35,499 nipype.workflow INFO:
# 	 [MultiProc] Running 7 tasks, and 60 jobs ready. Free memory (GB): 158.60/160.00, Free processors: 1/8.
#                      Currently running:
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
# 230223-10:12:35,549 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_GAIT/get_volume".
# 230223-10:12:35,553 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 230223-10:12:37,500 nipype.workflow INFO:
# 	 [MultiProc] Running 8 tasks, and 59 jobs ready. Free memory (GB): 158.40/160.00, Free processors: 0/8.
#                      Currently running:
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
# 230223-10:12:45,658 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 82.162752s.
# 230223-10:12:47,508 nipype.workflow INFO:
# 	 [Job 42] Completed (feat_level12_sst_roi.get_volume).
# 230223-10:12:47,510 nipype.workflow INFO:
# 	 [MultiProc] Running 7 tasks, and 59 jobs ready. Free memory (GB): 158.60/160.00, Free processors: 1/8.
#                      Currently running:
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
# 230223-10:12:47,578 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_WW2T/get_volume".
# 230223-10:12:47,584 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 230223-10:12:47,875 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 84.385856s.
# 230223-10:12:49,510 nipype.workflow INFO:
# 	 [Job 34] Completed (feat_level12_sst_roi.get_volume).
# 230223-10:12:49,512 nipype.workflow INFO:
# 	 [MultiProc] Running 7 tasks, and 58 jobs ready. Free memory (GB): 158.60/160.00, Free processors: 1/8.
#                      Currently running:
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
# 230223-10:12:49,566 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_FMFT/get_volume".
# 230223-10:12:49,572 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 230223-10:12:51,512 nipype.workflow INFO:
# 	 [MultiProc] Running 8 tasks, and 57 jobs ready. Free memory (GB): 158.40/160.00, Free processors: 0/8.
#                      Currently running:
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
# 230223-10:12:52,189 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 86.695881s.
# 230223-10:12:52,596 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 89.100731s.
# 230223-10:12:53,387 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 89.894889s.
# 230223-10:12:53,513 nipype.workflow INFO:
# 	 [Job 38] Completed (feat_level12_sst_roi.get_volume).
# 230223-10:12:53,515 nipype.workflow INFO:
# 	 [Job 44] Completed (feat_level12_sst_roi.get_volume).
# 230223-10:12:53,516 nipype.workflow INFO:
# 	 [Job 46] Completed (feat_level12_sst_roi.get_volume).
# 230223-10:12:53,519 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 57 jobs ready. Free memory (GB): 159.00/160.00, Free processors: 3/8.
#                      Currently running:
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
# 230223-10:12:53,580 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_LV2T/get_volume".
# 230223-10:12:53,580 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_KP6T/get_volume".
# 230223-10:12:53,581 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_PF5T/get_volume".
# 230223-10:12:53,586 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 230223-10:12:53,587 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 230223-10:12:53,587 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 230223-10:12:55,516 nipype.workflow INFO:
# 	 [MultiProc] Running 8 tasks, and 54 jobs ready. Free memory (GB): 158.40/160.00, Free processors: 0/8.
#                      Currently running:
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
# 230223-10:12:57,755 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 92.258951s.
# 230223-10:12:59,519 nipype.workflow INFO:
# 	 [Job 48] Completed (feat_level12_sst_roi.get_volume).
# 230223-10:12:59,522 nipype.workflow INFO:
# 	 [MultiProc] Running 7 tasks, and 54 jobs ready. Free memory (GB): 158.60/160.00, Free processors: 1/8.
#                      Currently running:
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
# 230223-10:12:59,588 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_ZK4T/get_volume".
# 230223-10:12:59,595 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 230223-10:13:01,366 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 97.873082s.
# 230223-10:13:01,521 nipype.workflow INFO:
# 	 [Job 40] Completed (feat_level12_sst_roi.get_volume).
# 230223-10:13:01,524 nipype.workflow INFO:
# 	 [MultiProc] Running 7 tasks, and 53 jobs ready. Free memory (GB): 158.60/160.00, Free processors: 1/8.
#                      Currently running:
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
# 230223-10:13:01,594 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_UM2T/get_volume".
# 230223-10:13:01,599 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 230223-10:13:03,524 nipype.workflow INFO:
# 	 [MultiProc] Running 8 tasks, and 52 jobs ready. Free memory (GB): 158.40/160.00, Free processors: 0/8.
#                      Currently running:
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
# 230223-10:14:00,981 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 85.425839s.
# 230223-10:14:01,582 nipype.workflow INFO:
# 	 [Job 50] Completed (feat_level12_sst_roi.get_volume).
# 230223-10:14:01,586 nipype.workflow INFO:
# 	 [MultiProc] Running 7 tasks, and 52 jobs ready. Free memory (GB): 158.60/160.00, Free processors: 1/8.
#                      Currently running:
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
# 230223-10:14:01,644 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/get_volume".
# 230223-10:14:01,649 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 230223-10:14:03,339 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 69.750844s.
# 230223-10:14:03,585 nipype.workflow INFO:
# 	 [Job 56] Completed (feat_level12_sst_roi.get_volume).
# 230223-10:14:03,587 nipype.workflow INFO:
# 	 [MultiProc] Running 7 tasks, and 51 jobs ready. Free memory (GB): 158.60/160.00, Free processors: 1/8.
#                      Currently running:
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
# 230223-10:14:03,646 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_KCAT/session_info_getter/mapflow/_session_info_getter0".
# 230223-10:14:03,650 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter0" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:14:04,0 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 70.410609s.
# 230223-10:14:04,183 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 64.585941s.
# 230223-10:14:05,546 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter0", elapsed time 1.894064s.
# 230223-10:14:05,587 nipype.workflow INFO:
# 	 [Job 58] Completed (feat_level12_sst_roi.get_volume).
# 230223-10:14:05,588 nipype.workflow INFO:
# 	 [Job 62] Completed (feat_level12_sst_roi.get_volume).
# 230223-10:14:05,589 nipype.workflow INFO:
# 	 [Job 272] Completed (_session_info_getter0).
# 230223-10:14:05,591 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 50 jobs ready. Free memory (GB): 159.00/160.00, Free processors: 3/8.
#                      Currently running:
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
# 230223-10:14:05,646 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_KCAT/session_info_getter/mapflow/_session_info_getter1".
# 230223-10:14:05,647 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_KCAT/session_info_getter/mapflow/_session_info_getter2".
# 230223-10:14:05,647 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_MRCT/session_info_getter/mapflow/_session_info_getter0".
# 230223-10:14:05,651 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter0" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:14:05,650 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter1" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:14:05,652 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter2" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:14:06,28 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter0", elapsed time 0.375109s.
# 230223-10:14:06,53 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter1", elapsed time 0.398439s.
# 230223-10:14:06,129 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter2", elapsed time 0.474317s.
# 230223-10:14:07,255 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 77.6808s.
# 230223-10:14:07,589 nipype.workflow INFO:
# 	 [Job 54] Completed (feat_level12_sst_roi.get_volume).
# 230223-10:14:07,590 nipype.workflow INFO:
# 	 [Job 273] Completed (_session_info_getter1).
# 230223-10:14:07,591 nipype.workflow INFO:
# 	 [Job 274] Completed (_session_info_getter2).
# 230223-10:14:07,592 nipype.workflow INFO:
# 	 [Job 275] Completed (_session_info_getter0).
# 230223-10:14:07,594 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 48 jobs ready. Free memory (GB): 159.20/160.00, Free processors: 4/8.
#                      Currently running:
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
# 230223-10:14:07,651 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_MRCT/session_info_getter/mapflow/_session_info_getter1".
# 230223-10:14:07,652 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_MRCT/session_info_getter/mapflow/_session_info_getter2".
# 230223-10:14:07,652 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_RSIT/session_info_getter/mapflow/_session_info_getter0".
# 230223-10:14:07,655 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_KCAT/session_info_getter/mapflow/_session_info_getter0".
# 230223-10:14:07,656 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter2" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:14:07,659 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter0" - collecting precomputed outputs
# 230223-10:14:07,658 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter0" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:14:07,660 nipype.workflow INFO:
# 	 [Node] "_session_info_getter0" found cached.
# 230223-10:14:07,659 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter1" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:14:07,662 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_KCAT/session_info_getter/mapflow/_session_info_getter1".
# 230223-10:14:07,663 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter1" - collecting precomputed outputs
# 230223-10:14:07,664 nipype.workflow INFO:
# 	 [Node] "_session_info_getter1" found cached.
# 230223-10:14:07,665 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_KCAT/session_info_getter/mapflow/_session_info_getter2".
# 230223-10:14:07,667 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter2" - collecting precomputed outputs
# 230223-10:14:07,667 nipype.workflow INFO:
# 	 [Node] "_session_info_getter2" found cached.
# 230223-10:14:07,982 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter1", elapsed time 0.319327s.
# 230223-10:14:08,36 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter2", elapsed time 0.377792s.
# 230223-10:14:08,164 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter0", elapsed time 0.503555s.
# 230223-10:14:09,591 nipype.workflow INFO:
# 	 [Job 35] Completed (feat_level12_sst_roi.session_info_getter).
# 230223-10:14:09,592 nipype.workflow INFO:
# 	 [Job 276] Completed (_session_info_getter1).
# 230223-10:14:09,593 nipype.workflow INFO:
# 	 [Job 277] Completed (_session_info_getter2).
# 230223-10:14:09,594 nipype.workflow INFO:
# 	 [Job 278] Completed (_session_info_getter0).
# 230223-10:14:09,596 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 46 jobs ready. Free memory (GB): 159.20/160.00, Free processors: 4/8.
#                      Currently running:
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
#                        * feat_level12_sst_roi.get_volume
# 230223-10:14:09,661 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.specifymodel1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_KCAT/specifymodel1".
# 230223-10:14:09,662 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_RSIT/session_info_getter/mapflow/_session_info_getter1".
# 230223-10:14:09,664 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_RSIT/session_info_getter/mapflow/_session_info_getter2".
# 230223-10:14:09,664 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_MRCT/session_info_getter/mapflow/_session_info_getter0".
# 230223-10:14:09,667 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter1" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:14:09,667 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter2" <nipype.interfaces.utility.wrappers.Function>
# 230223-10:14:09,670 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter0" - collecting precomputed outputs
# 230223-10:14:09,673 nipype.workflow INFO:
# 	 [Node] "_session_info_getter0" found cached.
# 230223-10:14:09,675 nipype.workflow INFO:
# ...
# 	 [Node] Setting-up "_smoothestimate2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/smoothestimate/mapflow/_smoothestimate2".
# 230223-12:35:05,917 nipype.workflow INFO:
# 	 [Node] Cached "_smoothestimate2" - collecting precomputed outputs
# 230223-12:35:05,918 nipype.workflow INFO:
# 	 [Node] "_smoothestimate2" found cached.
# 230223-12:35:05,919 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate3" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/smoothestimate/mapflow/_smoothestimate3".
# 230223-12:35:05,935 nipype.workflow INFO:
# 	 [Node] Cached "_smoothestimate3" - collecting precomputed outputs
# 230223-12:35:05,935 nipype.workflow INFO:
# 	 [Node] "_smoothestimate3" found cached.
# 230223-12:35:05,936 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate4" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/smoothestimate/mapflow/_smoothestimate4".
# 230223-12:35:05,938 nipype.workflow INFO:
# 	 [Node] Cached "_smoothestimate4" - collecting precomputed outputs
# 230223-12:35:05,939 nipype.workflow INFO:
# 	 [Node] "_smoothestimate4" found cached.
# 230223-12:35:05,940 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate5" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/smoothestimate/mapflow/_smoothestimate5".
# 230223-12:35:05,941 nipype.workflow INFO:
# 	 [Node] Cached "_smoothestimate5" - collecting precomputed outputs
# 230223-12:35:05,942 nipype.workflow INFO:
# 	 [Node] "_smoothestimate5" found cached.
# 230223-12:35:07,837 nipype.workflow INFO:
# 	 [Job 236] Completed (feat_level12_sst_roi.smoothestimate).
# 230223-12:35:07,840 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 160.00/160.00, Free processors: 8/8.
# 230223-12:35:09,840 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 12 jobs ready. Free memory (GB): 160.00/160.00, Free processors: 8/8.
# 230223-12:35:09,902 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/_threshold_2.3/grf_cluster/mapflow/_grf_cluster0".
# 230223-12:35:09,903 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/_threshold_2.3/grf_cluster/mapflow/_grf_cluster1".
# 230223-12:35:09,903 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/_threshold_2.3/grf_cluster/mapflow/_grf_cluster2".
# 230223-12:35:09,903 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster3" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/_threshold_2.3/grf_cluster/mapflow/_grf_cluster3".
# 230223-12:35:09,904 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster4" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/_threshold_2.3/grf_cluster/mapflow/_grf_cluster4".
# 230223-12:35:09,906 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster0" <nipype.interfaces.fsl.model.Cluster>
# 230223-12:35:09,906 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster1" <nipype.interfaces.fsl.model.Cluster>
# 230223-12:35:09,907 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster2" <nipype.interfaces.fsl.model.Cluster>
# 230223-12:35:09,907 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster3" <nipype.interfaces.fsl.model.Cluster>
# 230223-12:35:09,907 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster4" <nipype.interfaces.fsl.model.Cluster>
# 230223-12:35:09,908 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster5" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/_threshold_2.3/grf_cluster/mapflow/_grf_cluster5".
# 230223-12:35:09,908 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/_threshold_3.1/grf_cluster/mapflow/_grf_cluster1".
# 230223-12:35:09,908 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/_threshold_3.1/grf_cluster/mapflow/_grf_cluster0".
# 230223-12:35:09,932 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster0" <nipype.interfaces.fsl.model.Cluster>
# 230223-12:35:09,932 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster5" <nipype.interfaces.fsl.model.Cluster>
# 230223-12:35:09,932 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster1" <nipype.interfaces.fsl.model.Cluster>
# 230223-12:35:10,517 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster0", elapsed time 0.609471s.
# 230223-12:35:10,535 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster1", elapsed time 0.626935s.
# 230223-12:35:10,538 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster4", elapsed time 0.607436s.
# 230223-12:35:10,556 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster5", elapsed time 0.622075s.
# 230223-12:35:10,561 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster1", elapsed time 0.626621s.
# 230223-12:35:10,561 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster0", elapsed time 0.627235s.
# 230223-12:35:10,564 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster3", elapsed time 0.633264s.
# 230223-12:35:10,570 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster2", elapsed time 0.639917s.
# 230223-12:35:11,841 nipype.workflow INFO:
# 	 [Job 1025] Completed (_grf_cluster0).
# 230223-12:35:11,842 nipype.workflow INFO:
# 	 [Job 1026] Completed (_grf_cluster1).
# 230223-12:35:11,843 nipype.workflow INFO:
# 	 [Job 1027] Completed (_grf_cluster2).
# 230223-12:35:11,844 nipype.workflow INFO:
# 	 [Job 1028] Completed (_grf_cluster3).
# 230223-12:35:11,845 nipype.workflow INFO:
# 	 [Job 1029] Completed (_grf_cluster4).
# 230223-12:35:11,845 nipype.workflow INFO:
# 	 [Job 1030] Completed (_grf_cluster5).
# 230223-12:35:11,846 nipype.workflow INFO:
# 	 [Job 1031] Completed (_grf_cluster0).
# 230223-12:35:11,847 nipype.workflow INFO:
# 	 [Job 1032] Completed (_grf_cluster1).
# 230223-12:35:11,849 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 160.00/160.00, Free processors: 8/8.
# 230223-12:35:11,916 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/_threshold_3.1/grf_cluster/mapflow/_grf_cluster2".
# 230223-12:35:11,916 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster3" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/_threshold_3.1/grf_cluster/mapflow/_grf_cluster3".
# 230223-12:35:11,917 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster4" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/_threshold_3.1/grf_cluster/mapflow/_grf_cluster4".
# 230223-12:35:11,917 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster5" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/_threshold_3.1/grf_cluster/mapflow/_grf_cluster5".
# 230223-12:35:11,920 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/_threshold_2.3/grf_cluster/mapflow/_grf_cluster0".
# 230223-12:35:11,921 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster4" <nipype.interfaces.fsl.model.Cluster>
# 230223-12:35:11,921 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster2" <nipype.interfaces.fsl.model.Cluster>
# 230223-12:35:11,922 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster5" <nipype.interfaces.fsl.model.Cluster>
# 230223-12:35:11,922 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster3" <nipype.interfaces.fsl.model.Cluster>
# 230223-12:35:11,922 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster0" - collecting precomputed outputs
# 230223-12:35:11,923 nipype.workflow INFO:
# 	 [Node] "_grf_cluster0" found cached.
# 230223-12:35:11,925 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/_threshold_2.3/grf_cluster/mapflow/_grf_cluster1".
# 230223-12:35:11,926 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster1" - collecting precomputed outputs
# 230223-12:35:11,927 nipype.workflow INFO:
# 	 [Node] "_grf_cluster1" found cached.
# 230223-12:35:11,928 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/_threshold_2.3/grf_cluster/mapflow/_grf_cluster2".
# 230223-12:35:11,929 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster2" - collecting precomputed outputs
# 230223-12:35:11,930 nipype.workflow INFO:
# 	 [Node] "_grf_cluster2" found cached.
# 230223-12:35:11,931 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster3" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/_threshold_2.3/grf_cluster/mapflow/_grf_cluster3".
# 230223-12:35:11,932 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster3" - collecting precomputed outputs
# 230223-12:35:11,932 nipype.workflow INFO:
# 	 [Node] "_grf_cluster3" found cached.
# 230223-12:35:11,934 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster4" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/_threshold_2.3/grf_cluster/mapflow/_grf_cluster4".
# 230223-12:35:11,935 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster4" - collecting precomputed outputs
# 230223-12:35:11,936 nipype.workflow INFO:
# 	 [Node] "_grf_cluster4" found cached.
# 230223-12:35:11,937 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster5" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/_threshold_2.3/grf_cluster/mapflow/_grf_cluster5".
# 230223-12:35:11,939 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster5" - collecting precomputed outputs
# 230223-12:35:11,939 nipype.workflow INFO:
# 	 [Node] "_grf_cluster5" found cached.
# 230223-12:35:12,525 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster3", elapsed time 0.601102s.
# 230223-12:35:12,530 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster5", elapsed time 0.605968s.
# 230223-12:35:12,532 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster4", elapsed time 0.608974s.
# 230223-12:35:12,533 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster2", elapsed time 0.609745s.
# 230223-12:35:13,843 nipype.workflow INFO:
# 	 [Job 270] Completed (feat_level12_sst_roi.grf_cluster).
# 230223-12:35:13,845 nipype.workflow INFO:
# 	 [Job 1033] Completed (_grf_cluster2).
# 230223-12:35:13,845 nipype.workflow INFO:
# 	 [Job 1034] Completed (_grf_cluster3).
# 230223-12:35:13,846 nipype.workflow INFO:
# 	 [Job 1035] Completed (_grf_cluster4).
# 230223-12:35:13,846 nipype.workflow INFO:
# 	 [Job 1036] Completed (_grf_cluster5).
# 230223-12:35:13,849 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 160.00/160.00, Free processors: 8/8.
# 230223-12:35:13,919 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/_threshold_3.1/grf_cluster/mapflow/_grf_cluster0".
# 230223-12:35:13,920 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster0" - collecting precomputed outputs
# 230223-12:35:13,921 nipype.workflow INFO:
# 	 [Node] "_grf_cluster0" found cached.
# 230223-12:35:13,922 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/_threshold_3.1/grf_cluster/mapflow/_grf_cluster1".
# 230223-12:35:13,925 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster1" - collecting precomputed outputs
# 230223-12:35:13,925 nipype.workflow INFO:
# 	 [Node] "_grf_cluster1" found cached.
# 230223-12:35:13,926 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/_threshold_3.1/grf_cluster/mapflow/_grf_cluster2".
# 230223-12:35:13,928 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster2" - collecting precomputed outputs
# 230223-12:35:13,928 nipype.workflow INFO:
# 	 [Node] "_grf_cluster2" found cached.
# 230223-12:35:13,929 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster3" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/_threshold_3.1/grf_cluster/mapflow/_grf_cluster3".
# 230223-12:35:13,930 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster3" - collecting precomputed outputs
# 230223-12:35:13,931 nipype.workflow INFO:
# 	 [Node] "_grf_cluster3" found cached.
# 230223-12:35:13,932 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster4" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/_threshold_3.1/grf_cluster/mapflow/_grf_cluster4".
# 230223-12:35:13,934 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster4" - collecting precomputed outputs
# 230223-12:35:13,934 nipype.workflow INFO:
# 	 [Node] "_grf_cluster4" found cached.
# 230223-12:35:13,935 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster5" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/Leipzig_7T_GdH/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_SC1T/_threshold_3.1/grf_cluster/mapflow/_grf_cluster5".
# 230223-12:35:13,936 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster5" - collecting precomputed outputs
# 230223-12:35:13,937 nipype.workflow INFO:
# 	 [Node] "_grf_cluster5" found cached.
# 230223-12:35:15,845 nipype.workflow INFO:
# 	 [Job 271] Completed (feat_level12_sst_roi.grf_cluster).
# 230223-12:35:15,848 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 160.00/160.00, Free processors: 8/8.

# %%
from nipype.utils.filemanip import loadpkl
res = loadpkl('/home/scotti/projects/3t_7t_sst_comparison/processing/crashdumps/crash-20230202-194255-scotti-_modelestimate0-569bdeac-24e9-4591-a258-3f0682a4dc27.pklz')
res
# Out:
# {'node': _modelestimate0,
#  'traceback': ['Traceback (most recent call last):\n',
#   '  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/nipype/pipeline/plugins/multiproc.py", line 67, in run_node\n    result["result"] = node.run(updatehash=updatehash)\n',
#   '  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 521, in run\n    result = self._run_interface(execute=True)\n',
#   '  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 639, in _run_interface\n    return self._run_command(execute)\n',
#   '  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 750, in _run_command\n    raise NodeExecutionError(\n',
#   'nipype.pipeline.engine.nodes.NodeExecutionError: Exception raised while executing Node _modelestimate0.\n\nTraceback (most recent call last):\n  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/nipype/interfaces/base/core.py", line 454, in aggregate_outputs\n    setattr(outputs, key, val)\n  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/nipype/interfaces/base/traits_extension.py", line 330, in validate\n    value = super(File, self).validate(objekt, name, value, return_pathlike=True)\n  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/nipype/interfaces/base/traits_extension.py", line 135, in validate\n    self.error(objekt, name, str(value))\n  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/traits/base_trait_handler.py", line 74, in error\n    raise TraitError(\ntraits.trait_errors.TraitError: The \'thresholdac\' trait of a FILMGLSOutputSpec507 instance must be a pathlike object or string representing an existing file, but a value of \'/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_12/modelestimate/mapflow/_modelestimate0/results/threshac1.nii.gz\' <class \'str\'> was specified.\n\nDuring handling of the above exception, another exception occurred:\n\nTraceback (most recent call last):\n  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/nipype/interfaces/base/core.py", line 401, in run\n    outputs = self.aggregate_outputs(runtime)\n  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/nipype/interfaces/base/core.py", line 461, in aggregate_outputs\n    raise FileNotFoundError(msg)\nFileNotFoundError: No such file or directory \'/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_12/modelestimate/mapflow/_modelestimate0/results/threshac1.nii.gz\' for output \'thresholdac\' of a FILMGLS interface\n\n']}

# %%
from nipype.utils.filemanip import loadpkl
res = loadpkl('/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_10/modelestimate/mapflow/_modelestimate1/_inputs.pklz')
res
# Out:
# {'threshold': 1000.0,
#  'tcon_file': '/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_10/modelgen/mapflow/_modelgen1/run1.con',
#  'in_file': '/home/scotti/projects/3t_7t_sst_comparison/derivatives/fsl_feat_roi_func/aron_3T/sub-10/func/sub-10_task-stopsignal_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz',
#  'design_file': '/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_10/modelgen/mapflow/_modelgen1/run1.mat',
#  'smooth_autocorr': False,
#  'mask_size': 0,
#  'autocorr_noestimate': True,
#  'results_dir': 'results',
#  'output_type': 'NIFTI_GZ',
#  'environ': {'FSLOUTPUTTYPE': 'NIFTI_GZ'}}

# %%
from nipype.utils.filemanip import loadpkl
res = loadpkl('/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_3p125_space_T1w_subject_id_01/modelestimate/mapflow/_modelestimate1/_inputs.pklz')
res
# Out:
# {'threshold': 1000.0,
#  'tcon_file': '/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_3p125_space_T1w_subject_id_01/modelgen/mapflow/_modelgen1/run1.con',
#  'in_file': '/home/scotti/projects/3t_7t_sst_comparison/derivatives/susan_smoothed_hp_func/aron_3T/sub-01/func/sub-01_task-stopsignal_run-2_space-T1w_desc-preproc_bold_smoothed_fwhm-3p125_tempfilt.nii.gz',
#  'design_file': '/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_3p125_space_T1w_subject_id_01/modelgen/mapflow/_modelgen1/run1.mat',
#  'smooth_autocorr': True,
#  'mask_size': 5,
#  'results_dir': 'results',
#  'output_type': 'NIFTI_GZ',
#  'environ': {'FSLOUTPUTTYPE': 'NIFTI_GZ'}}

# %%
workflow = pe.Workflow(name='feat_level12_sst_roi')
workflow.base_dir = os.path.join(base_dir, 'processing', 'nipype_workflow_folders', this_dataset)
workflow.config = {"execution": {"crashdump_dir":os.path.join(base_dir, 'processing', 'crashdumps')}}

# identity
identity = pe.Node(util.IdentityInterface(fields=['subject_id', 'space', 'model_n']), name='identity')
identity.iterables = [('subject_id', subject_ids),
                      ('space', spaces),
                      ('model_n', model_n)]

# selector
# if running only one run, copy the mask from run 1 to run 2, 'mask' variable below needs a list, it will crash if only one is found
#(terrible way to get around this.. fix at some point.. lazy..)
templates = {'roi_funcs': os.path.join(base_dir, 'derivatives', 'fsl_feat_roi_func', this_dataset,
                                            'sub-{subject_id}', 'func',  
                                            f'sub-{{subject_id}}_task-{task}_run-*_space-{{space}}*_desc-preproc_bold.nii.gz'),
             'mask': os.path.join(base_dir, 'derivatives', 'fmriprep_feat_hack', this_dataset, 
                                  'sub-{subject_id}', 'func', 
                                  f'sub-{{subject_id}}_task-{task}_run-*_space-{{space}}_desc-brain_mask.nii.gz')}

selector = pe.Node(nio.SelectFiles(templates), name='selector')

workflow.connect(identity, 'subject_id', selector, 'subject_id')
workflow.connect(identity, 'space', selector, 'space')

# get run info per sub
run_info_getter = pe.Node(util.Function(function=get_runs_per_sub,
                                        input_names=['subject_id'],
                                        output_names=['runs']), name='run_info_getter')
workflow.connect(identity, 'subject_id', run_info_getter, 'subject_id')

# session info getter
session_info_getter = pe.MapNode(util.Function(function=get_session_info,
                                     input_names=['subject_id', 'run', 'task', 'this_dataset', 'space', 'shift', 'model_n'],
                                     output_names=['session_info', 'confounds']),
                                 iterfield=['run'],
                                 name='session_info_getter')
session_info_getter.inputs.task=task
session_info_getter.inputs.this_dataset=this_dataset
session_info_getter.inputs.space='MNI152NLin2009cAsym'
session_info_getter.inputs.shift = -t_r/2

workflow.connect(identity, 'subject_id', session_info_getter, 'subject_id')
workflow.connect(run_info_getter, 'runs', session_info_getter, 'run')
workflow.connect(identity, 'model_n', session_info_getter, 'model_n')


# model setup
specifymodel = pe.Node(model.SpecifyModel(), name='specifymodel1')
specifymodel.inputs.input_units = 'secs'
specifymodel.inputs.time_repetition = t_r
specifymodel.inputs.high_pass_filter_cutoff = hpcutoff

workflow.connect(session_info_getter, 'session_info', specifymodel, 'subject_info')
## old flow (with cosines): immediately connect to specifymodel
workflow.connect(selector, 'roi_funcs', specifymodel, 'functional_runs')

# Level 1 design
level1design = pe.Node(interface=fsl.Level1Design(), name="level1design")
level1design.inputs.interscan_interval = t_r
level1design.inputs.bases = {'dgamma': {'derivs': True}}
level1design.inputs.contrasts = contrasts
level1design.inputs.model_serial_correlations = True

workflow.connect(specifymodel, 'session_info', level1design, 'session_info')
# workflow.connect(session_info_getter, 'contrasts', level1design, 'contrasts')

# FEAT model
modelgen = pe.MapNode(interface=fsl.FEATModel(), iterfield=['ev_files', 'fsf_file', 'args'], name='modelgen')

workflow.connect(level1design, 'ev_files', modelgen, 'ev_files')
workflow.connect(level1design, 'fsf_files', modelgen, 'fsf_file')
workflow.connect(session_info_getter, 'confounds', modelgen, 'args')   # add confounds here


# FILM GLS
iterfield = ['design_file', 'in_file', 'tcon_file']
modelestimate = pe.MapNode(interface=fsl.FILMGLS(#smooth_autocorr=False, # prewhitening yes or no?
                                                 autocorr_noestimate=True,
                                                 mask_size = 0,
                                                 threshold = 1000),  # what to scale all inputs up to?
                                                 name='modelestimate',
                                                 iterfield=iterfield,
                                                 mem_gb=10)#,
                                                 #full_data = True)

# ## old flow (with cosines): immediately connect to modelestimate
workflow.connect(selector, 'roi_funcs', modelestimate, 'in_file')
# # new flow: connect high-passed data
# workflow.connect(highpass, 'out_file', modelestimate, 'in_file')


workflow.connect(modelgen, 'design_file', modelestimate, 'design_file')
workflow.connect(modelgen, 'con_file', modelestimate, 'tcon_file')


#### Fixed effects
# merge copes, varcopes
copemerge = pe.MapNode(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="copemerge")

varcopemerge = pe.MapNode(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="varcopemerge")

maskemerge = pe.MapNode(interface=fsl.Merge(dimension='t'),
                       iterfield=['in_files'],
                       name="maskemerge")

def sort_copes(files):
    numelements = len(files[0])
    outfiles = []
    for i in range(numelements):
        outfiles.insert(i,[])
        for j, elements in enumerate(files):
            outfiles[i].append(elements[i])
    return outfiles

workflow.connect(modelestimate, ('copes',sort_copes), copemerge, 'in_files')
workflow.connect(modelestimate, ('varcopes',sort_copes), varcopemerge, 'in_files')


level2model = pe.Node(interface=fsl.L2Model(), name='l2model')
def num_copes(files):
    return len(files)
workflow.connect(modelestimate, ('copes',num_copes), level2model, 'num_copes')


pickfirst = lambda x: x[0]
flameo = pe.MapNode(
    interface=fsl.FLAMEO(run_mode='fe'),
    name="flameo",
    iterfield=['cope_file', 'var_cope_file'])

workflow.connect([
    (selector, flameo, [(('mask', pickfirst), 'mask_file')]),
    (copemerge, flameo, [('merged_file', 'cope_file')]),
    (varcopemerge, flameo, [('merged_file', 'var_cope_file')]),
    (level2model, flameo, [('design_mat', 'design_file'),
                           ('design_con', 't_con_file'), 
                           ('design_grp', 'cov_split_file')]),
])

# ## Warp to MNI-space
# def warp_files(copes, varcopes, zstats, tdofs, mat, template_brain):
#     # stolen from https://dpaniukov.github.io/2016/07/14/three-level-analysis-with-fsl-and-ants-2.html
#     import nipype.interfaces.ants as ants

#     out_copes = []
#     out_varcopes = []
#     out_zstats = []
#     out_tdofs = []
    
#     warp = ants.ApplyTransforms()
#     warp.inputs.input_image_type = 0
#     warp.inputs.interpolation = 'Linear'
#     warp.inputs.invert_transform_flags = [False] #,False]
#     warp.inputs.reference_image = template_brain
#     warp.inputs.transforms = mat

#     if not isinstance(copes, list):
#         copes = [copes]
#         varcopes = [varcopes]
#         zstats = [zstats]
#         tdofs = [tdofs]
    
#     for cope in copes:
#         warp.inputs.input_image = cope
#         res=warp.run()
#         out_copes.append(str(res.outputs.output_image))

#     for varcope in varcopes:
#         warp.inputs.input_image = varcope
#         res=warp.run()
#         out_varcopes.append(str(res.outputs.output_image))
        
#     for zstat in zstats:
#         warp.inputs.input_image = zstat
#         res=warp.run()
#         out_zstats.append(str(res.outputs.output_image))
    
#     for tdof in tdofs:
#         warp.inputs.input_image = tdof
#         res=warp.run()
#         out_tdofs.append(str(res.outputs.output_image))

#     return out_copes, out_varcopes, out_zstats, out_tdofs

# warpfunc = pe.MapNode(util.Function(input_names=['copes', 'varcopes', 'zstats', 'tdofs', 'mat','template_brain'],
#                                output_names=['out_copes', 'out_varcopes', 'out_zstats', 'out_tdofs'],
#                                function=warp_files),
#                                iterfield=['copes', 'varcopes', 'zstats', 'tdofs'],
#                   name='warpfunc')

# warpfunc.inputs.template_brain = template_brain
# workflow.connect(flameo, 'copes', warpfunc, 'copes')
# workflow.connect(flameo, 'var_copes', warpfunc, 'varcopes')
# workflow.connect(flameo, 'zstats', warpfunc, 'zstats')
# workflow.connect(flameo, 'tdof', warpfunc, 'tdofs')
# workflow.connect(selector, 'composite', warpfunc, 'mat')

#### post-FE analyis
# Smoothness estimation
smoothestimate = pe.MapNode(fsl.SmoothEstimate(), iterfield=['zstat_file'], name='smoothestimate')

workflow.connect(selector, ('mask', pickfirst), smoothestimate, 'mask_file')
workflow.connect(flameo, 'zstats', smoothestimate, 'zstat_file')

#
get_volume = pe.Node(fsl.ImageStats(op_string = '-V'), name='get_volume')
workflow.connect(selector, ('mask', pickfirst), get_volume, 'in_file')

# Cluster threshold
grf_cluster = pe.MapNode(fsl.Cluster(), iterfield=['dlh', 'in_file'], name='grf_cluster')
grf_cluster.iterables = [("threshold", [2.3, 3.1])] 
workflow.connect(smoothestimate, 'dlh', grf_cluster, 'dlh')
workflow.connect(flameo, 'zstats', grf_cluster, 'in_file')

def convert_volume(input):
    return int(input[1])

workflow.connect(get_volume, ('out_stat', convert_volume), grf_cluster, 'volume')
grf_cluster.inputs.out_threshold_file = True


## datasink
ds = pe.Node(nio.DataSink(), name='datasink')
ds.inputs.base_directory = os.path.join(base_dir, 'derivatives', 'glm_feat_sst_roi')

#_model_n_0_smoothing_fwhm_1p5_space_T1w_subject_id_002
substitutions = [(f'mni/level2_{stat_type}s/_model_n_{model_n_}_space_MNI152NLin2009cAsym_subject_id_{sub}/_flameo{contrast_n}/{stat_type}1.nii.gz',
                  f'{this_dataset}/sub-{sub}/func/model-{model_n_}/sub-{sub}_task-{task}_space-MNI152NLin2009cAsym_model-{model_n_}_contrast-{contrast_n}_desc-{stat_type}.nii.gz')
                  for sub in subject_ids
                  for contrast_n in range(len(contrasts))
                  for model_n_ in model_n
                  for stat_type in ['cope', 'zstat', 'varcope', 'tdof_t']
                  ]


# substitutions = [(f'mni/level2_{stat_type}s/_model_n_{model_n_}_space_MNI152NLin2009cAsym_subject_id_{sub}/_warpfunc{contrast_n}/{stat_type}1_trans.nii.gz',
#                    f'{this_dataset}/sub-{sub}/func/model-{model_n_}/sub-{sub}_task-{task}_space-MNI152NLin2009cAsym_model-{model_n_}_contrast-{contrast_n}_desc-{stat_type}.nii.gz')
#                   for sub in subject_ids
#                   for contrast_n in range(len(contrasts))
#                   for model_n_ in model_n
#                   for stat_type in ['cope', 'zstat', 'varcope', 'tdof_t']
#                   ]

ds.inputs.substitutions = substitutions


## cluster thresholds: leave for now, this is more of a third-level model thing anyway
# workflow.connect(grf_cluster, 'threshold_file', ds, 'grf_thresholded_zstats_file')
# workflow.connect(grf_cluster, 'locnalmax_txt_file', ds, 'grf_localmax_txt_file')

## T1w-space
workflow.connect(flameo, 'zstats', ds, 'subject_level_model.mni.level2_zstats')
workflow.connect(flameo, 'copes', ds, 'subject_level_model.mni.level2_copes')
workflow.connect(flameo, 'var_copes', ds, 'subject_level_model.mni.level2_varcopes')
workflow.connect(flameo, 'tdof', ds, 'subject_level_model.mni.level2_tdof_ts')

# ## MNI-space
# workflow.connect(warpfunc, 'out_zstats', ds, 'subject_level_model.mni.level2_zstats')
# workflow.connect(warpfunc, 'out_copes', ds, 'subject_level_model.mni.level2_copes')
# workflow.connect(warpfunc, 'out_varcopes', ds, 'subject_level_model.mni.level2_varcopes')
# workflow.connect(warpfunc, 'out_tdofs', ds, 'subject_level_model.mni.level2_tdof_ts')
# workflow.connect(flameo, 'tdof', ds, 'level2_tdof')

# %% [markdown]
# ## when we were not using confounds

# %%
def get_session_info(subject_id, run, task='stop', this_dataset='Leipzig_7T_SM', space='T1w', shift=-1.38/2, model_n=0,
                    root_dir='/home/scotti/projects/3t_7t_sst_comparison', include_physio=True):
    # other space: MNI152NLin2009cAsym
    import pandas as pd
    import numpy as np
    import os
    from nipype.interfaces.base import Bunch
            
    ### files ###
    sub = subject_id
    event_fn = f'{root_dir}/derivatives/event_files/{this_dataset}/sub-{sub}/func/sub-{sub}_task-{task}_run-{run}_events.tsv'
#     confounds_fn = f'{root_dir}/derivatives/fmriprep/{this_dataset}/fmriprep/fmriprep/sub-{sub}/func/sub-{sub}_task-{task}_run-{run}_desc-confounds_timeseries.tsv'

    events = pd.read_csv(event_fn, sep='\t', index_col=None)
    events['duration'] = 0.001  # stick functions
    if model_n == 0:
        events = events.loc[events.trial_type.isin(['ss', 'fs', 'go'])]
    elif model_n == 1:
        events = events.loc[events.trial_type.isin(['response_left', 'response_right'])]
    events = events[['onset', 'trial_type', 'duration']]

    # slice time correction, nb: shift should be a negative number for STC
    events['onset'] += shift  

#     ### confounds ###
#     confounds = pd.read_csv(confounds_fn, sep='\t')
# #        cosine_cols = [x for x in confounds.columns if 'cos' in x]
#     include_confounds = ['trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z', 'dvars', 'framewise_displacement'] #+ cosine_cols
#     confounds = confounds[include_confounds].fillna(method='bfill')

#     # get retroicor
#     if include_physio:
#         ## take first 20 aCompCor components
# #         print("No retroicor found, including 20 a_comp_cor components")
#         a_comp_cor = pd.read_csv(confounds_fn, sep='\t')[['a_comp_cor_' + str(x).zfill(2) for x in range(20)]]
#         confounds = pd.concat([confounds, a_comp_cor], axis=1)

#     # save the confounds that we actually include in the GLM to csv, no header or index
#     confounds_fn = f'{root_dir}/derivatives/confounds/{this_dataset}/sub-{sub}/func/sub-{sub}_task-{task}_run-{run}_desc-confounds_timeseries.txt'
#     os.makedirs(os.path.dirname(confounds_fn), exist_ok=True)
#     confounds.to_csv(confounds_fn, sep='\t', header=False, index=False)

    ### Make bunch ###
    if model_n == 0:
        conditions=['fs',
                    'ss',
                    'go']

    elif model_n ==1:
        conditions = [
                     'response_left',
                     'response_right'
                     ]

    onsets = [events.loc[events.trial_type==trial_type,'onset'].tolist() for trial_type in conditions]
    durations = [events.loc[events.trial_type==trial_type,'duration'].tolist() for trial_type in conditions]
    amplitudes = [[1] * events.loc[events.trial_type==trial_type,'onset'].shape[0] for trial_type in conditions]
#             amplitudes = [events.loc[events.trial_type==trial_type,'modulation'].tolist() for trial_type in conditions]

    info = Bunch(conditions=conditions,
                 onsets=onsets,
                 durations=durations,
                 amplitudes=amplitudes)
#         print(info)
    
    # always return info and the confounds_fn
    return info #, confounds_fn #, contrasts[0]

if model_n == [0]:
    contrasts = [('fs', 'T', ['fs'], [1.0]),
                 ('ss', 'T', ['ss'], [1.0]),
                 ('go', 'T', ['go'], [1.0]),
                 ('fs-go', 'T', ['fs', 'go'], [1, -1]),
                 ('fs-ss', 'T', ['fs', 'ss'], [1, -1]),
                 ('ss-go', 'T', ['ss', 'go'], [1, -1])
                 ]
    
elif model_n == [1]:
    contrasts = [('response_left', 'T', ['response_left'], [1.0]),
                 ('response_right', 'T', ['response_right'], [1.0]),
                 ('left-right', 'T', ['response_left','response_right'], [1,-1])
                 ]

# %%
def get_runs_per_sub(subject_id):
    # here we can add the runs per subject if some subject miss a run or two
    if not subject_id in ['11','12']:
        runs = [1,2,3]
    else:
        runs = [1,2]
    
    return runs

# %%
workflow = pe.Workflow(name='feat_level12_sst_roi')
workflow.base_dir = os.path.join(base_dir, 'processing', 'nipype_workflow_folders', this_dataset)
workflow.config = {"execution": {"crashdump_dir":os.path.join(base_dir, 'processing', 'crashdumps')}}

# identity
identity = pe.Node(util.IdentityInterface(fields=['subject_id', 'space', 'model_n']), name='identity')
identity.iterables = [('subject_id', subject_ids),
                      ('space', spaces),
                      ('model_n', model_n)]

# selector
# if running only one run, copy the mask from run 1 to run 2, 'mask' variable below needs a list, it will crash if only one is found
#(terrible way to get around this.. fix at some point.. lazy..)
templates = {'roi_funcs': os.path.join(base_dir, 'derivatives', 'fsl_feat_roi_func', this_dataset,
                                            'sub-{subject_id}', 'func',  
                                            f'sub-{{subject_id}}_task-{task}_run-*_space-{{space}}*_desc-preproc_bold.nii.gz'),
             'mask': os.path.join(base_dir, 'derivatives', 'fmriprep_feat_hack', this_dataset, 
                                  'sub-{subject_id}', 'func', 
                                  f'sub-{{subject_id}}_task-{task}_run-*_space-{{space}}_desc-brain_mask.nii.gz')}

selector = pe.Node(nio.SelectFiles(templates), name='selector')

workflow.connect(identity, 'subject_id', selector, 'subject_id')
workflow.connect(identity, 'space', selector, 'space')

# get run info per sub
run_info_getter = pe.Node(util.Function(function=get_runs_per_sub,
                                        input_names=['subject_id'],
                                        output_names=['runs']), name='run_info_getter')
workflow.connect(identity, 'subject_id', run_info_getter, 'subject_id')

# session info getter
session_info_getter = pe.MapNode(util.Function(function=get_session_info,
                                     input_names=['subject_id', 'run', 'task', 'this_dataset', 'space', 'shift', 'model_n'],
                                     output_names=['session_info']),
                                 iterfield=['run'],
                                 name='session_info_getter')
session_info_getter.inputs.task=task
session_info_getter.inputs.this_dataset=this_dataset
session_info_getter.inputs.space='MNI152NLin2009cAsym'
session_info_getter.inputs.shift = -t_r/2

workflow.connect(identity, 'subject_id', session_info_getter, 'subject_id')
workflow.connect(run_info_getter, 'runs', session_info_getter, 'run')
workflow.connect(identity, 'model_n', session_info_getter, 'model_n')


# model setup
specifymodel = pe.Node(model.SpecifyModel(), name='specifymodel1')
specifymodel.inputs.input_units = 'secs'
specifymodel.inputs.time_repetition = t_r
specifymodel.inputs.high_pass_filter_cutoff = hpcutoff

workflow.connect(session_info_getter, 'session_info', specifymodel, 'subject_info')
## old flow (with cosines): immediately connect to specifymodel
workflow.connect(selector, 'roi_funcs', specifymodel, 'functional_runs')

# Level 1 design
level1design = pe.Node(interface=fsl.Level1Design(), name="level1design")
level1design.inputs.interscan_interval = t_r
level1design.inputs.bases = {'dgamma': {'derivs': True}}
level1design.inputs.contrasts = contrasts
level1design.inputs.model_serial_correlations = True

workflow.connect(specifymodel, 'session_info', level1design, 'session_info')
# workflow.connect(session_info_getter, 'contrasts', level1design, 'contrasts')

# FEAT model
modelgen = pe.MapNode(interface=fsl.FEATModel(), iterfield=['ev_files', 'fsf_file'], name='modelgen') #, 'args'

workflow.connect(level1design, 'ev_files', modelgen, 'ev_files')
workflow.connect(level1design, 'fsf_files', modelgen, 'fsf_file')
# workflow.connect(session_info_getter, 'confounds', modelgen, 'args')   # add confounds here


# FILM GLS
iterfield = ['design_file', 'in_file', 'tcon_file']
modelestimate = pe.MapNode(interface=fsl.FILMGLS(smooth_autocorr=False,
#                                                  autocorr_noestimate=True,
                                                 mask_size = 0,
                                                 threshold = 10.),  # 
                                                 name='modelestimate',
                                                 iterfield=iterfield,
                                                 mem_gb=10,
                                                 full_data = True)

# ## old flow (with cosines): immediately connect to modelestimate
workflow.connect(selector, 'roi_funcs', modelestimate, 'in_file')
# # new flow: connect high-passed data
# workflow.connect(highpass, 'out_file', modelestimate, 'in_file')


workflow.connect(modelgen, 'design_file', modelestimate, 'design_file')
workflow.connect(modelgen, 'con_file', modelestimate, 'tcon_file')


#### Fixed effects
# merge copes, varcopes
copemerge = pe.MapNode(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="copemerge")

varcopemerge = pe.MapNode(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="varcopemerge")

maskemerge = pe.MapNode(interface=fsl.Merge(dimension='t'),
                       iterfield=['in_files'],
                       name="maskemerge")

def sort_copes(files):
    numelements = len(files[0])
    outfiles = []
    for i in range(numelements):
        outfiles.insert(i,[])
        for j, elements in enumerate(files):
            outfiles[i].append(elements[i])
    return outfiles

workflow.connect(modelestimate, ('copes',sort_copes), copemerge, 'in_files')
workflow.connect(modelestimate, ('varcopes',sort_copes), varcopemerge, 'in_files')


level2model = pe.Node(interface=fsl.L2Model(), name='l2model')
def num_copes(files):
    return len(files)
workflow.connect(modelestimate, ('copes',num_copes), level2model, 'num_copes')


pickfirst = lambda x: x[0]
flameo = pe.MapNode(
    interface=fsl.FLAMEO(run_mode='fe'),
    name="flameo",
    iterfield=['cope_file', 'var_cope_file'])

workflow.connect([
    (selector, flameo, [(('mask', pickfirst), 'mask_file')]),
    (copemerge, flameo, [('merged_file', 'cope_file')]),
    (varcopemerge, flameo, [('merged_file', 'var_cope_file')]),
    (level2model, flameo, [('design_mat', 'design_file'),
                           ('design_con', 't_con_file'), 
                           ('design_grp', 'cov_split_file')]),
])

# ## Warp to MNI-space
# def warp_files(copes, varcopes, zstats, tdofs, mat, template_brain):
#     # stolen from https://dpaniukov.github.io/2016/07/14/three-level-analysis-with-fsl-and-ants-2.html
#     import nipype.interfaces.ants as ants

#     out_copes = []
#     out_varcopes = []
#     out_zstats = []
#     out_tdofs = []
    
#     warp = ants.ApplyTransforms()
#     warp.inputs.input_image_type = 0
#     warp.inputs.interpolation = 'Linear'
#     warp.inputs.invert_transform_flags = [False] #,False]
#     warp.inputs.reference_image = template_brain
#     warp.inputs.transforms = mat

#     if not isinstance(copes, list):
#         copes = [copes]
#         varcopes = [varcopes]
#         zstats = [zstats]
#         tdofs = [tdofs]
    
#     for cope in copes:
#         warp.inputs.input_image = cope
#         res=warp.run()
#         out_copes.append(str(res.outputs.output_image))

#     for varcope in varcopes:
#         warp.inputs.input_image = varcope
#         res=warp.run()
#         out_varcopes.append(str(res.outputs.output_image))
        
#     for zstat in zstats:
#         warp.inputs.input_image = zstat
#         res=warp.run()
#         out_zstats.append(str(res.outputs.output_image))
    
#     for tdof in tdofs:
#         warp.inputs.input_image = tdof
#         res=warp.run()
#         out_tdofs.append(str(res.outputs.output_image))

#     return out_copes, out_varcopes, out_zstats, out_tdofs

# warpfunc = pe.MapNode(util.Function(input_names=['copes', 'varcopes', 'zstats', 'tdofs', 'mat','template_brain'],
#                                output_names=['out_copes', 'out_varcopes', 'out_zstats', 'out_tdofs'],
#                                function=warp_files),
#                                iterfield=['copes', 'varcopes', 'zstats', 'tdofs'],
#                   name='warpfunc')

# warpfunc.inputs.template_brain = template_brain
# workflow.connect(flameo, 'copes', warpfunc, 'copes')
# workflow.connect(flameo, 'var_copes', warpfunc, 'varcopes')
# workflow.connect(flameo, 'zstats', warpfunc, 'zstats')
# workflow.connect(flameo, 'tdof', warpfunc, 'tdofs')
# workflow.connect(selector, 'composite', warpfunc, 'mat')

#### post-FE analyis
# Smoothness estimation
smoothestimate = pe.MapNode(fsl.SmoothEstimate(), iterfield=['zstat_file'], name='smoothestimate')

workflow.connect(selector, ('mask', pickfirst), smoothestimate, 'mask_file')
workflow.connect(flameo, 'zstats', smoothestimate, 'zstat_file')

#
get_volume = pe.Node(fsl.ImageStats(op_string = '-V'), name='get_volume')
workflow.connect(selector, ('mask', pickfirst), get_volume, 'in_file')

# Cluster threshold
grf_cluster = pe.MapNode(fsl.Cluster(), iterfield=['dlh', 'in_file'], name='grf_cluster')
grf_cluster.iterables = [("threshold", [2.3, 3.1])] 
workflow.connect(smoothestimate, 'dlh', grf_cluster, 'dlh')
workflow.connect(flameo, 'zstats', grf_cluster, 'in_file')

def convert_volume(input):
    return int(input[1])

workflow.connect(get_volume, ('out_stat', convert_volume), grf_cluster, 'volume')
grf_cluster.inputs.out_threshold_file = True


## datasink
ds = pe.Node(nio.DataSink(), name='datasink')
ds.inputs.base_directory = os.path.join(base_dir, 'derivatives', 'glm_feat_sst_roi')

#_model_n_0_smoothing_fwhm_1p5_space_T1w_subject_id_002
substitutions = [(f'mni/level2_{stat_type}s/_model_n_{model_n_}_space_MNI152NLin2009cAsym_subject_id_{sub}/_flameo{contrast_n}/{stat_type}1.nii.gz',
                  f'{this_dataset}/sub-{sub}/func/model-{model_n_}/sub-{sub}_task-{task}_space-MNI152NLin2009cAsym_model-{model_n_}_contrast-{contrast_n}_desc-{stat_type}.nii.gz')
                  for sub in subject_ids
                  for contrast_n in range(len(contrasts))
                  for model_n_ in model_n
                  for stat_type in ['cope', 'zstat', 'varcope', 'tdof_t']
                  ]


# substitutions = [(f'mni/level2_{stat_type}s/_model_n_{model_n_}_space_MNI152NLin2009cAsym_subject_id_{sub}/_warpfunc{contrast_n}/{stat_type}1_trans.nii.gz',
#                    f'{this_dataset}/sub-{sub}/func/model-{model_n_}/sub-{sub}_task-{task}_space-MNI152NLin2009cAsym_model-{model_n_}_contrast-{contrast_n}_desc-{stat_type}.nii.gz')
#                   for sub in subject_ids
#                   for contrast_n in range(len(contrasts))
#                   for model_n_ in model_n
#                   for stat_type in ['cope', 'zstat', 'varcope', 'tdof_t']
#                   ]

ds.inputs.substitutions = substitutions


## cluster thresholds: leave for now, this is more of a third-level model thing anyway
# workflow.connect(grf_cluster, 'threshold_file', ds, 'grf_thresholded_zstats_file')
# workflow.connect(grf_cluster, 'locnalmax_txt_file', ds, 'grf_localmax_txt_file')

## T1w-space
workflow.connect(flameo, 'zstats', ds, 'subject_level_model.mni.level2_zstats')
workflow.connect(flameo, 'copes', ds, 'subject_level_model.mni.level2_copes')
workflow.connect(flameo, 'var_copes', ds, 'subject_level_model.mni.level2_varcopes')
workflow.connect(flameo, 'tdof', ds, 'subject_level_model.mni.level2_tdof_ts')

# ## MNI-space
# workflow.connect(warpfunc, 'out_zstats', ds, 'subject_level_model.mni.level2_zstats')
# workflow.connect(warpfunc, 'out_copes', ds, 'subject_level_model.mni.level2_copes')
# workflow.connect(warpfunc, 'out_varcopes', ds, 'subject_level_model.mni.level2_varcopes')
# workflow.connect(warpfunc, 'out_tdofs', ds, 'subject_level_model.mni.level2_tdof_ts')
# workflow.connect(flameo, 'tdof', ds, 'level2_tdof')

# %%
workflow.run(plugin='MultiProc', plugin_args={'n_procs':20, 'memory_gb': 200})
# Out:
# 230130-11:41:31,243 nipype.workflow INFO:
# 	 Workflow feat_level12_sst_roi settings: ['check', 'execution', 'logging', 'monitoring']
# 230130-11:41:31,577 nipype.workflow INFO:
# 	 Running in parallel.
# 230130-11:41:32,465 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 28 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 230130-11:41:32,557 nipype.workflow INFO:
# 	 [Job 1] Cached (feat_level12_sst_roi.run_info_getter).
# 230130-11:41:32,557 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_15/selector".
# 230130-11:41:32,562 nipype.workflow INFO:
# 	 [Job 3] Cached (feat_level12_sst_roi.run_info_getter).
# 230130-11:41:32,563 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_02/selector".
# 230130-11:41:32,565 nipype.workflow INFO:
# 	 [Job 5] Cached (feat_level12_sst_roi.run_info_getter).
# 230130-11:41:32,566 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_14/selector".
# 230130-11:41:32,568 nipype.workflow INFO:
# 	 [Job 7] Cached (feat_level12_sst_roi.run_info_getter).
# 230130-11:41:32,569 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_13/selector".
# 230130-11:41:32,570 nipype.workflow INFO:
# 	 [Job 9] Cached (feat_level12_sst_roi.run_info_getter).
# 230130-11:41:32,572 nipype.workflow INFO:
# 	 [Job 11] Cached (feat_level12_sst_roi.run_info_getter).
# 230130-11:41:32,570 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_10/selector".
# 230130-11:41:32,572 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_12/selector".
# 230130-11:41:32,574 nipype.workflow INFO:
# 	 [Job 13] Cached (feat_level12_sst_roi.run_info_getter).
# 230130-11:41:32,574 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_05/selector".
# 230130-11:41:32,576 nipype.workflow INFO:
# 	 [Job 15] Cached (feat_level12_sst_roi.run_info_getter).
# 230130-11:41:32,576 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_11/selector".
# 230130-11:41:32,578 nipype.workflow INFO:
# 	 [Job 17] Cached (feat_level12_sst_roi.run_info_getter).
# 230130-11:41:32,578 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_06/selector".
# 230130-11:41:32,580 nipype.workflow INFO:
# 	 [Job 19] Cached (feat_level12_sst_roi.run_info_getter).
# 230130-11:41:32,580 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_04/selector".
# 230130-11:41:32,594 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230130-11:41:32,599 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001981s.
# 230130-11:41:32,616 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230130-11:41:32,616 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230130-11:41:32,616 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230130-11:41:32,616 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230130-11:41:32,617 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230130-11:41:32,616 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230130-11:41:32,617 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230130-11:41:32,620 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001742s.
# 230130-11:41:32,621 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001719s.
# 230130-11:41:32,621 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001745s.
# 230130-11:41:32,621 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.002017s.
# 230130-11:41:32,622 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.002191s.
# 230130-11:41:32,622 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.002503s.
# 230130-11:41:32,622 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.002513s.
# 230130-11:41:32,623 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230130-11:41:32,623 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230130-11:41:32,626 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001004s.
# 230130-11:41:32,626 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001056s.
# 230130-11:41:34,468 nipype.workflow INFO:
# 	 [Job 0] Completed (feat_level12_sst_roi.selector).
# 230130-11:41:34,470 nipype.workflow INFO:
# 	 [Job 2] Completed (feat_level12_sst_roi.selector).
# 230130-11:41:34,472 nipype.workflow INFO:
# 	 [Job 4] Completed (feat_level12_sst_roi.selector).
# 230130-11:41:34,474 nipype.workflow INFO:
# 	 [Job 6] Completed (feat_level12_sst_roi.selector).
# 230130-11:41:34,475 nipype.workflow INFO:
# 	 [Job 8] Completed (feat_level12_sst_roi.selector).
# 230130-11:41:34,476 nipype.workflow INFO:
# 	 [Job 10] Completed (feat_level12_sst_roi.selector).
# 230130-11:41:34,476 nipype.workflow INFO:
# 	 [Job 12] Completed (feat_level12_sst_roi.selector).
# 230130-11:41:34,477 nipype.workflow INFO:
# 	 [Job 14] Completed (feat_level12_sst_roi.selector).
# 230130-11:41:34,478 nipype.workflow INFO:
# 	 [Job 16] Completed (feat_level12_sst_roi.selector).
# 230130-11:41:34,478 nipype.workflow INFO:
# 	 [Job 18] Completed (feat_level12_sst_roi.selector).
# 230130-11:41:34,479 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 28 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 230130-11:41:34,530 nipype.workflow INFO:
# 	 [Job 21] Cached (feat_level12_sst_roi.run_info_getter).
# 230130-11:41:34,532 nipype.workflow INFO:
# 	 [Job 23] Cached (feat_level12_sst_roi.run_info_getter).
# 230130-11:41:34,531 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_01/selector".
# 230130-11:41:34,534 nipype.workflow INFO:
# 	 [Job 25] Cached (feat_level12_sst_roi.run_info_getter).
# 230130-11:41:34,533 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/selector".
# 230130-11:41:34,536 nipype.workflow INFO:
# 	 [Job 27] Cached (feat_level12_sst_roi.run_info_getter).
# 230130-11:41:34,534 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_07/selector".
# 230130-11:41:34,536 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230130-11:41:34,537 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_09/selector".
# 230130-11:41:34,538 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230130-11:41:34,540 nipype.workflow INFO:
# 	 [Job 28] Cached (feat_level12_sst_roi.get_volume).
# 230130-11:41:34,540 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230130-11:41:34,540 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001436s.
# 230130-11:41:34,541 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 230130-11:41:34,543 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001418s.
# 230130-11:41:34,544 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001176s.
# 230130-11:41:34,544 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.002843s.
# 230130-11:41:34,551 nipype.workflow INFO:
# 	 [Job 30] Cached (feat_level12_sst_roi.get_volume).
# 230130-11:41:34,559 nipype.workflow INFO:
# 	 [Job 32] Cached (feat_level12_sst_roi.get_volume).
# 230130-11:41:34,568 nipype.workflow INFO:
# 	 [Job 34] Cached (feat_level12_sst_roi.get_volume).
# 230130-11:41:34,578 nipype.workflow INFO:
# 	 [Job 36] Cached (feat_level12_sst_roi.get_volume).
# 230130-11:41:34,587 nipype.workflow INFO:
# 	 [Job 38] Cached (feat_level12_sst_roi.get_volume).
# 230130-11:41:34,595 nipype.workflow INFO:
# 	 [Job 40] Cached (feat_level12_sst_roi.get_volume).
# 230130-11:41:34,605 nipype.workflow INFO:
# 	 [Job 42] Cached (feat_level12_sst_roi.get_volume).
# 230130-11:41:34,616 nipype.workflow INFO:
# 	 [Job 44] Cached (feat_level12_sst_roi.get_volume).
# 230130-11:41:34,624 nipype.workflow INFO:
# 	 [Job 46] Cached (feat_level12_sst_roi.get_volume).
# 230130-11:41:36,469 nipype.workflow INFO:
# 	 [Job 20] Completed (feat_level12_sst_roi.selector).
# 230130-11:41:36,471 nipype.workflow INFO:
# 	 [Job 22] Completed (feat_level12_sst_roi.selector).
# 230130-11:41:36,473 nipype.workflow INFO:
# 	 [Job 24] Completed (feat_level12_sst_roi.selector).
# 230130-11:41:36,475 nipype.workflow INFO:
# 	 [Job 26] Completed (feat_level12_sst_roi.selector).
# 230130-11:41:36,478 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 36 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 230130-11:41:36,515 nipype.workflow INFO:
# 	 [Job 48] Cached (feat_level12_sst_roi.get_volume).
# 230130-11:41:36,527 nipype.workflow INFO:
# 	 [Job 50] Cached (feat_level12_sst_roi.get_volume).
# 230130-11:41:36,538 nipype.workflow INFO:
# 	 [Job 52] Cached (feat_level12_sst_roi.get_volume).
# 230130-11:41:36,547 nipype.workflow INFO:
# 	 [Job 54] Cached (feat_level12_sst_roi.get_volume).
# 230130-11:41:36,556 nipype.workflow INFO:
# 	 [Job 224] Cached (_session_info_getter0).
# 230130-11:41:36,558 nipype.workflow INFO:
# 	 [Job 225] Cached (_session_info_getter1).
# 230130-11:41:36,559 nipype.workflow INFO:
# 	 [Job 226] Cached (_session_info_getter2).
# 230130-11:41:36,560 nipype.workflow INFO:
# 	 [Job 227] Cached (_session_info_getter0).
# 230130-11:41:36,561 nipype.workflow INFO:
# 	 [Job 228] Cached (_session_info_getter1).
# 230130-11:41:36,562 nipype.workflow INFO:
# 	 [Job 229] Cached (_session_info_getter2).
# 230130-11:41:36,563 nipype.workflow INFO:
# 	 [Job 230] Cached (_session_info_getter0).
# 230130-11:41:36,565 nipype.workflow INFO:
# 	 [Job 231] Cached (_session_info_getter1).
# 230130-11:41:36,566 nipype.workflow INFO:
# 	 [Job 232] Cached (_session_info_getter2).
# 230130-11:41:36,567 nipype.workflow INFO:
# 	 [Job 233] Cached (_session_info_getter0).
# 230130-11:41:36,567 nipype.workflow INFO:
# 	 [Job 234] Cached (_session_info_getter1).
# 230130-11:41:36,568 nipype.workflow INFO:
# 	 [Job 235] Cached (_session_info_getter2).
# 230130-11:41:36,569 nipype.workflow INFO:
# 	 [Job 236] Cached (_session_info_getter0).
# 230130-11:41:36,570 nipype.workflow INFO:
# 	 [Job 237] Cached (_session_info_getter1).
# 230130-11:41:36,570 nipype.workflow INFO:
# 	 [Job 238] Cached (_session_info_getter2).
# 230130-11:41:36,571 nipype.workflow INFO:
# 	 [Job 239] Cached (_session_info_getter0).
# 230130-11:41:38,472 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 29 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 230130-11:41:38,508 nipype.workflow INFO:
# 	 [Job 29] Cached (feat_level12_sst_roi.session_info_getter).
# 230130-11:41:38,511 nipype.workflow INFO:
# 	 [Job 31] Cached (feat_level12_sst_roi.session_info_getter).
# 230130-11:41:38,513 nipype.workflow INFO:
# 	 [Job 33] Cached (feat_level12_sst_roi.session_info_getter).
# 230130-11:41:38,515 nipype.workflow INFO:
# 	 [Job 35] Cached (feat_level12_sst_roi.session_info_getter).
# 230130-11:41:38,517 nipype.workflow INFO:
# 	 [Job 37] Cached (feat_level12_sst_roi.session_info_getter).
# 230130-11:41:38,518 nipype.workflow INFO:
# 	 [Job 240] Cached (_session_info_getter1).
# 230130-11:41:38,519 nipype.workflow INFO:
# 	 [Job 241] Cached (_session_info_getter0).
# 230130-11:41:38,520 nipype.workflow INFO:
# 	 [Job 242] Cached (_session_info_getter1).
# 230130-11:41:38,521 nipype.workflow INFO:
# 	 [Job 243] Cached (_session_info_getter2).
# 230130-11:41:38,522 nipype.workflow INFO:
# 	 [Job 244] Cached (_session_info_getter0).
# 230130-11:41:38,523 nipype.workflow INFO:
# 	 [Job 245] Cached (_session_info_getter1).
# 230130-11:41:38,524 nipype.workflow INFO:
# 	 [Job 246] Cached (_session_info_getter0).
# 230130-11:41:38,525 nipype.workflow INFO:
# 	 [Job 247] Cached (_session_info_getter1).
# 230130-11:41:38,526 nipype.workflow INFO:
# 	 [Job 248] Cached (_session_info_getter2).
# 230130-11:41:38,527 nipype.workflow INFO:
# 	 [Job 249] Cached (_session_info_getter0).
# 230130-11:41:38,527 nipype.workflow INFO:
# 	 [Job 250] Cached (_session_info_getter1).
# 230130-11:41:38,528 nipype.workflow INFO:
# 	 [Job 251] Cached (_session_info_getter2).
# 230130-11:41:38,529 nipype.workflow INFO:
# 	 [Job 252] Cached (_session_info_getter0).
# 230130-11:41:38,530 nipype.workflow INFO:
# 	 [Job 253] Cached (_session_info_getter1).
# 230130-11:41:38,531 nipype.workflow INFO:
# 	 [Job 254] Cached (_session_info_getter2).
# 230130-11:41:40,475 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 20 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 230130-11:41:40,509 nipype.workflow INFO:
# 	 [Job 39] Cached (feat_level12_sst_roi.session_info_getter).
# 230130-11:41:40,512 nipype.workflow INFO:
# 	 [Job 41] Cached (feat_level12_sst_roi.session_info_getter).
# 230130-11:41:40,514 nipype.workflow INFO:
# 	 [Job 43] Cached (feat_level12_sst_roi.session_info_getter).
# 230130-11:41:40,516 nipype.workflow INFO:
# 	 [Job 45] Cached (feat_level12_sst_roi.session_info_getter).
# 230130-11:41:40,518 nipype.workflow INFO:
# 	 [Job 47] Cached (feat_level12_sst_roi.session_info_getter).
# 230130-11:41:40,519 nipype.workflow INFO:
# 	 [Job 49] Cached (feat_level12_sst_roi.session_info_getter).
# 230130-11:41:40,527 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:40,530 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.specifymodel1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_15/specifymodel1".
# 230130-11:41:40,533 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:40,534 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:40,537 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.specifymodel1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_02/specifymodel1".
# 230130-11:41:40,539 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:40,542 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:40,544 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.specifymodel1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_14/specifymodel1".
# 230130-11:41:40,546 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:40,548 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:40,550 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.specifymodel1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_13/specifymodel1".
# 230130-11:41:40,552 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:40,554 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:40,556 nipype.workflow INFO:
# 	 [Job 255] Cached (_session_info_getter0).
# 230130-11:41:40,557 nipype.workflow INFO:
# 	 [Job 256] Cached (_session_info_getter1).
# 230130-11:41:40,557 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.specifymodel1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_10/specifymodel1".
# 230130-11:41:40,558 nipype.workflow INFO:
# 	 [Job 257] Cached (_session_info_getter2).
# 230130-11:41:40,559 nipype.workflow INFO:
# 	 [Job 258] Cached (_session_info_getter0).
# 230130-11:41:40,558 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:40,560 nipype.workflow INFO:
# 	 [Job 259] Cached (_session_info_getter1).
# 230130-11:41:40,561 nipype.workflow INFO:
# 	 [Job 260] Cached (_session_info_getter2).
# 230130-11:41:40,562 nipype.workflow INFO:
# 	 [Job 261] Cached (_session_info_getter0).
# 230130-11:41:40,563 nipype.workflow INFO:
# 	 [Job 262] Cached (_session_info_getter1).
# 230130-11:41:40,564 nipype.workflow INFO:
# 	 [Job 263] Cached (_session_info_getter2).
# 230130-11:41:40,570 nipype.workflow INFO:
# 	 [Node] Executing "specifymodel1" <nipype.algorithms.modelgen.SpecifyModel>
# 230130-11:41:40,573 nipype.workflow INFO:
# 	 [Node] Executing "specifymodel1" <nipype.algorithms.modelgen.SpecifyModel>
# 230130-11:41:40,575 nipype.workflow INFO:
# 	 [Node] Finished "specifymodel1", elapsed time 0.002815s.
# 230130-11:41:40,578 nipype.workflow INFO:
# 	 [Node] Finished "specifymodel1", elapsed time 0.002989s.
# 230130-11:41:40,578 nipype.workflow INFO:
# 	 [Node] Executing "specifymodel1" <nipype.algorithms.modelgen.SpecifyModel>
# 230130-11:41:40,585 nipype.workflow INFO:
# 	 [Node] Executing "specifymodel1" <nipype.algorithms.modelgen.SpecifyModel>
# 230130-11:41:40,585 nipype.workflow INFO:
# 	 [Node] Finished "specifymodel1", elapsed time 0.005633s.
# 230130-11:41:40,589 nipype.workflow INFO:
# 	 [Node] Executing "specifymodel1" <nipype.algorithms.modelgen.SpecifyModel>
# 230130-11:41:40,590 nipype.workflow INFO:
# 	 [Node] Finished "specifymodel1", elapsed time 0.003112s.
# 230130-11:41:40,593 nipype.workflow INFO:
# 	 [Node] Finished "specifymodel1", elapsed time 0.002767s.
# 230130-11:41:42,476 nipype.workflow INFO:
# 	 [Job 56] Completed (feat_level12_sst_roi.specifymodel1).
# 230130-11:41:42,478 nipype.workflow INFO:
# 	 [Job 57] Completed (feat_level12_sst_roi.specifymodel1).
# 230130-11:41:42,480 nipype.workflow INFO:
# 	 [Job 58] Completed (feat_level12_sst_roi.specifymodel1).
# 230130-11:41:42,482 nipype.workflow INFO:
# 	 [Job 59] Completed (feat_level12_sst_roi.specifymodel1).
# 230130-11:41:42,484 nipype.workflow INFO:
# 	 [Job 60] Completed (feat_level12_sst_roi.specifymodel1).
# 230130-11:41:42,485 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 14 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 230130-11:41:42,521 nipype.workflow INFO:
# 	 [Job 51] Cached (feat_level12_sst_roi.session_info_getter).
# 230130-11:41:42,524 nipype.workflow INFO:
# 	 [Job 53] Cached (feat_level12_sst_roi.session_info_getter).
# 230130-11:41:42,526 nipype.workflow INFO:
# 	 [Job 55] Cached (feat_level12_sst_roi.session_info_getter).
# 230130-11:41:42,532 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:42,535 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.specifymodel1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_12/specifymodel1".
# 230130-11:41:42,539 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:42,538 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:42,542 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.specifymodel1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_05/specifymodel1".
# 230130-11:41:42,543 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:42,547 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:42,550 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.specifymodel1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_11/specifymodel1".
# 230130-11:41:42,551 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:42,554 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:42,557 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.specifymodel1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_06/specifymodel1".
# 230130-11:41:42,558 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:42,561 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:42,563 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.specifymodel1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_04/specifymodel1".
# 230130-11:41:42,565 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:42,567 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:42,570 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.specifymodel1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_01/specifymodel1".
# 230130-11:41:42,571 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:42,576 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:42,580 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.level1design" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_15/level1design".
# 230130-11:41:42,581 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:42,587 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:42,591 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.level1design" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_02/level1design".
# 230130-11:41:42,592 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:42,594 nipype.workflow INFO:
# 	 [Node] Executing "specifymodel1" <nipype.algorithms.modelgen.SpecifyModel>
# 230130-11:41:42,597 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:42,598 nipype.workflow INFO:
# 	 [Node] Finished "specifymodel1", elapsed time 0.002914s.
# 230130-11:41:42,599 nipype.workflow INFO:
# 	 [Node] Executing "specifymodel1" <nipype.algorithms.modelgen.SpecifyModel>
# 230130-11:41:42,602 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.level1design" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_14/level1design".
# 230130-11:41:42,602 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:42,604 nipype.workflow INFO:
# 	 [Node] Finished "specifymodel1", elapsed time 0.003653s.
# 230130-11:41:42,608 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:42,606 nipype.workflow INFO:
# 	 [Node] Executing "specifymodel1" <nipype.algorithms.modelgen.SpecifyModel>
# 230130-11:41:42,606 nipype.workflow INFO:
# 	 [Node] Executing "specifymodel1" <nipype.algorithms.modelgen.SpecifyModel>
# 230130-11:41:42,608 nipype.workflow INFO:
# 	 [Node] Executing "specifymodel1" <nipype.algorithms.modelgen.SpecifyModel>
# 230130-11:41:42,608 nipype.workflow INFO:
# 	 [Node] Executing "specifymodel1" <nipype.algorithms.modelgen.SpecifyModel>
# 230130-11:41:42,610 nipype.workflow INFO:
# 	 [Node] Finished "specifymodel1", elapsed time 0.003052s.
# 230130-11:41:42,611 nipype.workflow INFO:
# 	 [Node] Finished "specifymodel1", elapsed time 0.002633s.
# 230130-11:41:42,612 nipype.workflow INFO:
# 	 [Node] Finished "specifymodel1", elapsed time 0.002032s.
# 230130-11:41:42,612 nipype.workflow INFO:
# 	 [Node] Finished "specifymodel1", elapsed time 0.002835s.
# 230130-11:41:42,612 nipype.workflow INFO:
# 	 [Node] Executing "level1design" <nipype.interfaces.fsl.model.Level1Design>
# 230130-11:41:42,614 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.level1design" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_13/level1design".
# 230130-11:41:42,615 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:42,625 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:42,630 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.level1design" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_10/level1design".
# 230130-11:41:42,631 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:42,643 nipype.workflow INFO:
# 	 [Node] Executing "level1design" <nipype.interfaces.fsl.model.Level1Design>
# 230130-11:41:42,645 nipype.workflow INFO:
# 	 [Node] Executing "level1design" <nipype.interfaces.fsl.model.Level1Design>
# 230130-11:41:42,647 nipype.workflow INFO:
# 	 [Node] Executing "level1design" <nipype.interfaces.fsl.model.Level1Design>
# 230130-11:41:42,648 nipype.workflow INFO:
# 	 [Node] Executing "level1design" <nipype.interfaces.fsl.model.Level1Design>
# 230130-11:41:42,652 nipype.workflow INFO:
# 	 [Node] Finished "level1design", elapsed time 0.038064s.
# 230130-11:41:42,681 nipype.workflow INFO:
# 	 [Node] Finished "level1design", elapsed time 0.036802s.
# 230130-11:41:42,682 nipype.workflow INFO:
# 	 [Node] Finished "level1design", elapsed time 0.034234s.
# 230130-11:41:42,682 nipype.workflow INFO:
# 	 [Node] Finished "level1design", elapsed time 0.035965s.
# 230130-11:41:42,684 nipype.workflow INFO:
# 	 [Node] Finished "level1design", elapsed time 0.034883s.
# 230130-11:41:44,478 nipype.workflow INFO:
# 	 [Job 61] Completed (feat_level12_sst_roi.specifymodel1).
# 230130-11:41:44,480 nipype.workflow INFO:
# 	 [Job 62] Completed (feat_level12_sst_roi.specifymodel1).
# 230130-11:41:44,482 nipype.workflow INFO:
# 	 [Job 63] Completed (feat_level12_sst_roi.specifymodel1).
# 230130-11:41:44,484 nipype.workflow INFO:
# 	 [Job 64] Completed (feat_level12_sst_roi.specifymodel1).
# 230130-11:41:44,486 nipype.workflow INFO:
# 	 [Job 65] Completed (feat_level12_sst_roi.specifymodel1).
# 230130-11:41:44,487 nipype.workflow INFO:
# 	 [Job 66] Completed (feat_level12_sst_roi.specifymodel1).
# 230130-11:41:44,488 nipype.workflow INFO:
# 	 [Job 70] Completed (feat_level12_sst_roi.level1design).
# 230130-11:41:44,489 nipype.workflow INFO:
# 	 [Job 71] Completed (feat_level12_sst_roi.level1design).
# 230130-11:41:44,490 nipype.workflow INFO:
# 	 [Job 72] Completed (feat_level12_sst_roi.level1design).
# 230130-11:41:44,490 nipype.workflow INFO:
# 	 [Job 73] Completed (feat_level12_sst_roi.level1design).
# 230130-11:41:44,491 nipype.workflow INFO:
# 	 [Job 74] Completed (feat_level12_sst_roi.level1design).
# 230130-11:41:44,493 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 14 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 230130-11:41:44,535 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:44,539 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.specifymodel1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/specifymodel1".
# 230130-11:41:44,540 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:44,543 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:44,546 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.specifymodel1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_07/specifymodel1".
# 230130-11:41:44,547 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:44,550 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:44,552 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.specifymodel1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_09/specifymodel1".
# 230130-11:41:44,553 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.specifymodel1".
# 230130-11:41:44,555 nipype.workflow INFO:
# 	 [Node] Executing "specifymodel1" <nipype.algorithms.modelgen.SpecifyModel>
# 230130-11:41:44,557 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:44,559 nipype.workflow INFO:
# 	 [Node] Finished "specifymodel1", elapsed time 0.002833s.
# 230130-11:41:44,560 nipype.workflow INFO:
# 	 [Node] Executing "specifymodel1" <nipype.algorithms.modelgen.SpecifyModel>
# 230130-11:41:44,562 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.level1design" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_12/level1design".
# 230130-11:41:44,563 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:44,564 nipype.workflow INFO:
# 	 [Node] Finished "specifymodel1", elapsed time 0.002743s.
# 230130-11:41:44,569 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:44,571 nipype.workflow INFO:
# 	 [Node] Executing "level1design" <nipype.interfaces.fsl.model.Level1Design>
# 230130-11:41:44,575 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.level1design" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_05/level1design".
# 230130-11:41:44,576 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:44,581 nipype.workflow INFO:
# 	 [Node] Finished "level1design", elapsed time 0.008648s.
# 230130-11:41:44,582 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:44,585 nipype.workflow INFO:
# 	 [Node] Executing "level1design" <nipype.interfaces.fsl.model.Level1Design>
# 230130-11:41:44,587 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.level1design" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_11/level1design".
# 230130-11:41:44,588 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:44,595 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:44,598 nipype.workflow INFO:
# 	 [Node] Executing "level1design" <nipype.interfaces.fsl.model.Level1Design>
# 230130-11:41:44,600 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.level1design" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_06/level1design".
# 230130-11:41:44,601 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:44,602 nipype.workflow INFO:
# 	 [Node] Finished "level1design", elapsed time 0.015679s.
# 230130-11:41:44,608 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:44,613 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.level1design" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_04/level1design".
# 230130-11:41:44,614 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:44,620 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:44,627 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.level1design" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_01/level1design".
# 230130-11:41:44,627 nipype.workflow INFO:
# 	 [Node] Finished "level1design", elapsed time 0.027969s.
# 230130-11:41:44,627 nipype.workflow INFO:
# 	 [Node] Executing "specifymodel1" <nipype.algorithms.modelgen.SpecifyModel>
# 230130-11:41:44,628 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:44,632 nipype.workflow INFO:
# 	 [Node] Executing "level1design" <nipype.interfaces.fsl.model.Level1Design>
# 230130-11:41:44,632 nipype.workflow INFO:
# 	 [Node] Finished "specifymodel1", elapsed time 0.002955s.
# 230130-11:41:44,644 nipype.workflow INFO:
# 	 [Node] Executing "level1design" <nipype.interfaces.fsl.model.Level1Design>
# 230130-11:41:44,644 nipype.workflow INFO:
# 	 [Node] Executing "level1design" <nipype.interfaces.fsl.model.Level1Design>
# 230130-11:41:44,648 nipype.workflow INFO:
# 	 [Node] Finished "level1design", elapsed time 0.014833s.
# 230130-11:41:44,659 nipype.workflow INFO:
# 	 [Node] Finished "level1design", elapsed time 0.014128s.
# 230130-11:41:44,660 nipype.workflow INFO:
# 	 [Node] Finished "level1design", elapsed time 0.0147s.
# 230130-11:41:46,479 nipype.workflow INFO:
# 	 [Job 67] Completed (feat_level12_sst_roi.specifymodel1).
# 230130-11:41:46,481 nipype.workflow INFO:
# 	 [Job 68] Completed (feat_level12_sst_roi.specifymodel1).
# 230130-11:41:46,484 nipype.workflow INFO:
# 	 [Job 69] Completed (feat_level12_sst_roi.specifymodel1).
# 230130-11:41:46,485 nipype.workflow INFO:
# 	 [Job 75] Completed (feat_level12_sst_roi.level1design).
# 230130-11:41:46,487 nipype.workflow INFO:
# 	 [Job 76] Completed (feat_level12_sst_roi.level1design).
# 230130-11:41:46,488 nipype.workflow INFO:
# 	 [Job 77] Completed (feat_level12_sst_roi.level1design).
# 230130-11:41:46,489 nipype.workflow INFO:
# 	 [Job 78] Completed (feat_level12_sst_roi.level1design).
# 230130-11:41:46,490 nipype.workflow INFO:
# 	 [Job 79] Completed (feat_level12_sst_roi.level1design).
# 230130-11:41:46,491 nipype.workflow INFO:
# 	 [Job 80] Completed (feat_level12_sst_roi.level1design).
# 230130-11:41:46,493 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 24 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 230130-11:41:46,532 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:46,540 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.level1design" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/level1design".
# 230130-11:41:46,542 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:46,550 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:46,555 nipype.workflow INFO:
# 	 [Node] Executing "level1design" <nipype.interfaces.fsl.model.Level1Design>
# 230130-11:41:46,556 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.level1design" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_07/level1design".
# 230130-11:41:46,557 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:46,563 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:46,566 nipype.workflow INFO:
# 	 [Node] Executing "level1design" <nipype.interfaces.fsl.model.Level1Design>
# 230130-11:41:46,567 nipype.workflow INFO:
# 	 [Node] Finished "level1design", elapsed time 0.011517s.
# 230130-11:41:46,570 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.level1design" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_09/level1design".
# 230130-11:41:46,572 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.level1design".
# 230130-11:41:46,578 nipype.workflow INFO:
# 	 [Node] Finished "level1design", elapsed time 0.010421s.
# 230130-11:41:46,584 nipype.workflow INFO:
# 	 [Node] Executing "level1design" <nipype.interfaces.fsl.model.Level1Design>
# 230130-11:41:46,596 nipype.workflow INFO:
# 	 [Node] Finished "level1design", elapsed time 0.010541s.
# 230130-11:41:46,618 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen0".
# 230130-11:41:46,620 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen1".
# 230130-11:41:46,620 nipype.workflow INFO:
# 	 [Node] Setting-up "_modelgen0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_15/modelgen/mapflow/_modelgen0".
# 230130-11:41:46,622 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen2".
# 230130-11:41:46,622 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen0".
# 230130-11:41:46,622 nipype.workflow INFO:
# 	 [Node] Setting-up "_modelgen1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_15/modelgen/mapflow/_modelgen1".
# 230130-11:41:46,624 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen0".
# 230130-11:41:46,624 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen1".
# 230130-11:41:46,624 nipype.workflow INFO:
# 	 [Node] Setting-up "_modelgen2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_15/modelgen/mapflow/_modelgen2".
# 230130-11:41:46,625 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen2".
# 230130-11:41:46,626 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen1".
# 230130-11:41:46,626 nipype.workflow INFO:
# 	 [Node] Setting-up "_modelgen0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_02/modelgen/mapflow/_modelgen0".
# 230130-11:41:46,628 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen2".
# 230130-11:41:46,627 nipype.workflow INFO:
# 	 [Node] Executing "_modelgen0" <nipype.interfaces.fsl.model.FEATModel>
# 230130-11:41:46,628 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen0".
# 230130-11:41:46,628 nipype.workflow INFO:
# 	 [Node] Setting-up "_modelgen1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_02/modelgen/mapflow/_modelgen1".
# 230130-11:41:46,629 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen1".
# 230130-11:41:46,629 nipype.workflow INFO:
# 	 [Node] Executing "_modelgen2" <nipype.interfaces.fsl.model.FEATModel>
# 230130-11:41:46,629 nipype.workflow INFO:
# 	 [Node] Executing "_modelgen1" <nipype.interfaces.fsl.model.FEATModel>
# 230130-11:41:46,630 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen0".
# 230130-11:41:46,629 nipype.workflow INFO:
# 	 [Node] Setting-up "_modelgen2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_02/modelgen/mapflow/_modelgen2".
# 230130-11:41:46,631 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen2".
# 230130-11:41:46,633 nipype.workflow INFO:
# 	 [Node] Executing "_modelgen0" <nipype.interfaces.fsl.model.FEATModel>
# 230130-11:41:46,633 nipype.workflow INFO:
# 	 [Node] Setting-up "_modelgen0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_14/modelgen/mapflow/_modelgen0".
# 230130-11:41:46,633 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen1".
# 230130-11:41:46,633 nipype.workflow INFO:
# 	 [Node] Executing "_modelgen1" <nipype.interfaces.fsl.model.FEATModel>
# 230130-11:41:46,634 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen0".
# 230130-11:41:46,636 nipype.workflow INFO:
# 	 [Node] Executing "_modelgen2" <nipype.interfaces.fsl.model.FEATModel>
# 230130-11:41:46,636 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen2".
# 230130-11:41:46,636 nipype.workflow INFO:
# 	 [Node] Setting-up "_modelgen1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_14/modelgen/mapflow/_modelgen1".
# 230130-11:41:46,637 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen1".
# 230130-11:41:46,638 nipype.workflow INFO:
# 	 [Node] Executing "_modelgen0" <nipype.interfaces.fsl.model.FEATModel>
# 230130-11:41:46,639 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen0".
# 230130-11:41:46,639 nipype.workflow INFO:
# 	 [Node] Setting-up "_modelgen2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_14/modelgen/mapflow/_modelgen2".
# 230130-11:41:46,639 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen2".
# 230130-11:41:46,641 nipype.workflow INFO:
# 	 [Node] Executing "_modelgen1" <nipype.interfaces.fsl.model.FEATModel>
# 230130-11:41:46,642 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen1".
# 230130-11:41:46,642 nipype.workflow INFO:
# 	 [Node] Setting-up "_modelgen0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_13/modelgen/mapflow/_modelgen0".
# 230130-11:41:46,643 nipype.workflow INFO:
# 	 [Node] Executing "_modelgen2" <nipype.interfaces.fsl.model.FEATModel>
# 230130-11:41:46,642 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen0".
# 230130-11:41:46,644 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen2".
# 230130-11:41:46,644 nipype.workflow INFO:
# 	 [Node] Setting-up "_modelgen1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_13/modelgen/mapflow/_modelgen1".
# 230130-11:41:46,645 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen1".
# 230130-11:41:46,646 nipype.workflow INFO:
# 	 [Node] Executing "_modelgen0" <nipype.interfaces.fsl.model.FEATModel>
# 230130-11:41:46,646 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen0".
# 230130-11:41:46,647 nipype.workflow INFO:
# 	 [Node] Setting-up "_modelgen2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_13/modelgen/mapflow/_modelgen2".
# 230130-11:41:46,647 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen2".
# 230130-11:41:46,648 nipype.workflow INFO:
# 	 [Node] Executing "_modelgen1" <nipype.interfaces.fsl.model.FEATModel>
# 230130-11:41:46,649 nipype.workflow INFO:
# 	 [Node] Setting-up "_modelgen0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_10/modelgen/mapflow/_modelgen0".
# 230130-11:41:46,650 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen1".
# 230130-11:41:46,650 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen0".
# 230130-11:41:46,651 nipype.workflow INFO:
# 	 [Node] Executing "_modelgen2" <nipype.interfaces.fsl.model.FEATModel>
# 230130-11:41:46,653 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen2".
# 230130-11:41:46,653 nipype.workflow INFO:
# 	 [Node] Setting-up "_modelgen1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_10/modelgen/mapflow/_modelgen1".
# 230130-11:41:46,653 nipype.workflow INFO:
# 	 [Node] Executing "_modelgen0" <nipype.interfaces.fsl.model.FEATModel>
# 230130-11:41:46,654 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen1".
# 230130-11:41:46,655 nipype.workflow INFO:
# 	 [Node] Setting-up "_modelgen2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_10/modelgen/mapflow/_modelgen2".
# 230130-11:41:46,656 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_modelgen2".
# 230130-11:41:46,656 nipype.workflow INFO:
# 	 [Node] Executing "_modelgen1" <nipype.interfaces.fsl.model.FEATModel>
# ...
# 230130-11:54:53,302 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_grf_cluster0".
# 230130-11:54:53,304 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_grf_cluster1".
# 230130-11:54:53,305 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_grf_cluster2".
# 230130-11:54:53,304 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/_threshold_2.3/grf_cluster/mapflow/_grf_cluster0".
# 230130-11:54:53,307 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_grf_cluster3".
# 230130-11:54:53,305 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/_threshold_2.3/grf_cluster/mapflow/_grf_cluster1".
# 230130-11:54:53,306 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_grf_cluster1".
# 230130-11:54:53,309 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_grf_cluster4".
# 230130-11:54:53,306 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_grf_cluster0".
# 230130-11:54:53,307 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/_threshold_2.3/grf_cluster/mapflow/_grf_cluster2".
# 230130-11:54:53,308 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_grf_cluster2".
# 230130-11:54:53,312 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_grf_cluster5".
# 230130-11:54:53,309 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster3" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/_threshold_2.3/grf_cluster/mapflow/_grf_cluster3".
# 230130-11:54:53,310 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_grf_cluster3".
# 230130-11:54:53,315 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_grf_cluster0".
# 230130-11:54:53,309 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster1" <nipype.interfaces.fsl.model.Cluster>
# 230130-11:54:53,311 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster0" <nipype.interfaces.fsl.model.Cluster>
# 230130-11:54:53,312 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster2" <nipype.interfaces.fsl.model.Cluster>
# 230130-11:54:53,312 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster4" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/_threshold_2.3/grf_cluster/mapflow/_grf_cluster4".
# 230130-11:54:53,317 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_grf_cluster1".
# 230130-11:54:53,313 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster3" <nipype.interfaces.fsl.model.Cluster>
# 230130-11:54:53,314 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_grf_cluster4".
# 230130-11:54:53,314 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster5" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/_threshold_2.3/grf_cluster/mapflow/_grf_cluster5".
# 230130-11:54:53,316 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_grf_cluster5".
# 230130-11:54:53,319 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_grf_cluster2".
# 230130-11:54:53,317 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/_threshold_3.1/grf_cluster/mapflow/_grf_cluster0".
# 230130-11:54:53,318 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster4" <nipype.interfaces.fsl.model.Cluster>
# 230130-11:54:53,321 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_grf_cluster3".
# 230130-11:54:53,318 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_grf_cluster0".
# 230130-11:54:53,319 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/_threshold_3.1/grf_cluster/mapflow/_grf_cluster1".
# 230130-11:54:53,320 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_grf_cluster1".
# 230130-11:54:53,320 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster5" <nipype.interfaces.fsl.model.Cluster>
# 230130-11:54:53,321 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/_threshold_3.1/grf_cluster/mapflow/_grf_cluster2".
# 230130-11:54:53,322 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster1" <nipype.interfaces.fsl.model.Cluster>
# 230130-11:54:53,324 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_grf_cluster4".
# 230130-11:54:53,322 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_grf_cluster2".
# 230130-11:54:53,322 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster0" <nipype.interfaces.fsl.model.Cluster>
# 230130-11:54:53,323 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster3" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/_threshold_3.1/grf_cluster/mapflow/_grf_cluster3".
# 230130-11:54:53,324 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_grf_cluster3".
# 230130-11:54:53,325 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_grf_cluster5".
# 230130-11:54:53,325 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster2" <nipype.interfaces.fsl.model.Cluster>
# 230130-11:54:53,325 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster4" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/_threshold_3.1/grf_cluster/mapflow/_grf_cluster4".
# 230130-11:54:53,326 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster3" <nipype.interfaces.fsl.model.Cluster>
# 230130-11:54:53,326 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_grf_cluster4".
# 230130-11:54:53,328 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster5" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/_threshold_3.1/grf_cluster/mapflow/_grf_cluster5".
# 230130-11:54:53,329 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_grf_cluster5".
# 230130-11:54:53,329 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster4" <nipype.interfaces.fsl.model.Cluster>
# 230130-11:54:53,331 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster5" <nipype.interfaces.fsl.model.Cluster>
# 230130-11:54:53,896 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster2", elapsed time 0.5825s.
# 230130-11:54:53,929 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster4", elapsed time 0.598837s.
# 230130-11:54:53,929 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster0", elapsed time 0.615708s.
# 230130-11:54:53,931 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster0", elapsed time 0.606672s.
# 230130-11:54:53,938 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster5", elapsed time 0.61582s.
# 230130-11:54:53,941 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster3", elapsed time 0.613799s.
# 230130-11:54:53,949 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster1", elapsed time 0.625002s.
# 230130-11:54:53,950 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster3", elapsed time 0.635066s.
# 230130-11:54:53,956 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster4", elapsed time 0.636402s.
# 230130-11:54:53,961 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster1", elapsed time 0.648601s.
# 230130-11:54:53,961 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster5", elapsed time 0.627962s.
# 230130-11:54:53,962 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster2", elapsed time 0.635223s.
# 230130-11:54:55,251 nipype.workflow INFO:
# 	 [Job 836] Completed (_grf_cluster0).
# 230130-11:54:55,252 nipype.workflow INFO:
# 	 [Job 837] Completed (_grf_cluster1).
# 230130-11:54:55,253 nipype.workflow INFO:
# 	 [Job 838] Completed (_grf_cluster2).
# 230130-11:54:55,254 nipype.workflow INFO:
# 	 [Job 839] Completed (_grf_cluster3).
# 230130-11:54:55,255 nipype.workflow INFO:
# 	 [Job 840] Completed (_grf_cluster4).
# 230130-11:54:55,256 nipype.workflow INFO:
# 	 [Job 841] Completed (_grf_cluster5).
# 230130-11:54:55,257 nipype.workflow INFO:
# 	 [Job 842] Completed (_grf_cluster0).
# 230130-11:54:55,258 nipype.workflow INFO:
# 	 [Job 843] Completed (_grf_cluster1).
# 230130-11:54:55,258 nipype.workflow INFO:
# 	 [Job 844] Completed (_grf_cluster2).
# 230130-11:54:55,259 nipype.workflow INFO:
# 	 [Job 845] Completed (_grf_cluster3).
# 230130-11:54:55,260 nipype.workflow INFO:
# 	 [Job 846] Completed (_grf_cluster4).
# 230130-11:54:55,260 nipype.workflow INFO:
# 	 [Job 847] Completed (_grf_cluster5).
# 230130-11:54:55,262 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 230130-11:54:55,322 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.grf_cluster".
# 230130-11:54:55,326 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.grf_cluster".
# 230130-11:54:55,326 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.grf_cluster".
# 230130-11:54:55,329 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "feat_level12_sst_roi.grf_cluster".
# 230130-11:54:55,330 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/_threshold_2.3/grf_cluster/mapflow/_grf_cluster0".
# 230130-11:54:55,332 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster0" - collecting precomputed outputs
# 230130-11:54:55,332 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/_threshold_3.1/grf_cluster/mapflow/_grf_cluster0".
# 230130-11:54:55,333 nipype.workflow INFO:
# 	 [Node] "_grf_cluster0" found cached.
# 230130-11:54:55,334 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster0" - collecting precomputed outputs
# 230130-11:54:55,334 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/_threshold_2.3/grf_cluster/mapflow/_grf_cluster1".
# 230130-11:54:55,335 nipype.workflow INFO:
# 	 [Node] "_grf_cluster0" found cached.
# 230130-11:54:55,335 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster1" - collecting precomputed outputs
# 230130-11:54:55,336 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/_threshold_3.1/grf_cluster/mapflow/_grf_cluster1".
# 230130-11:54:55,336 nipype.workflow INFO:
# 	 [Node] "_grf_cluster1" found cached.
# 230130-11:54:55,337 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/_threshold_2.3/grf_cluster/mapflow/_grf_cluster2".
# 230130-11:54:55,337 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster1" - collecting precomputed outputs
# 230130-11:54:55,338 nipype.workflow INFO:
# 	 [Node] "_grf_cluster1" found cached.
# 230130-11:54:55,338 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster2" - collecting precomputed outputs
# 230130-11:54:55,339 nipype.workflow INFO:
# 	 [Node] "_grf_cluster2" found cached.
# 230130-11:54:55,339 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/_threshold_3.1/grf_cluster/mapflow/_grf_cluster2".
# 230130-11:54:55,340 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster3" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/_threshold_2.3/grf_cluster/mapflow/_grf_cluster3".
# 230130-11:54:55,340 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster2" - collecting precomputed outputs
# 230130-11:54:55,341 nipype.workflow INFO:
# 	 [Node] "_grf_cluster2" found cached.
# 230130-11:54:55,341 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster3" - collecting precomputed outputs
# 230130-11:54:55,342 nipype.workflow INFO:
# 	 [Node] "_grf_cluster3" found cached.
# 230130-11:54:55,342 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster3" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/_threshold_3.1/grf_cluster/mapflow/_grf_cluster3".
# 230130-11:54:55,343 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster4" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/_threshold_2.3/grf_cluster/mapflow/_grf_cluster4".
# 230130-11:54:55,343 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster3" - collecting precomputed outputs
# 230130-11:54:55,344 nipype.workflow INFO:
# 	 [Node] "_grf_cluster3" found cached.
# 230130-11:54:55,344 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster4" - collecting precomputed outputs
# 230130-11:54:55,345 nipype.workflow INFO:
# 	 [Node] "_grf_cluster4" found cached.
# 230130-11:54:55,345 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster4" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/_threshold_3.1/grf_cluster/mapflow/_grf_cluster4".
# 230130-11:54:55,346 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster5" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/_threshold_2.3/grf_cluster/mapflow/_grf_cluster5".
# 230130-11:54:55,346 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster4" - collecting precomputed outputs
# 230130-11:54:55,347 nipype.workflow INFO:
# 	 [Node] "_grf_cluster4" found cached.
# 230130-11:54:55,348 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster5" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_MNI152NLin2009cAsym_subject_id_03/_threshold_3.1/grf_cluster/mapflow/_grf_cluster5".
# 230130-11:54:55,348 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster5" - collecting precomputed outputs
# 230130-11:54:55,349 nipype.workflow INFO:
# 	 [Node] "_grf_cluster5" found cached.
# 230130-11:54:55,349 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster5" - collecting precomputed outputs
# 230130-11:54:55,349 nipype.workflow INFO:
# 	 [Node] "_grf_cluster5" found cached.
# 230130-11:54:57,253 nipype.workflow INFO:
# 	 [Job 218] Completed (feat_level12_sst_roi.grf_cluster).
# 230130-11:54:57,255 nipype.workflow INFO:
# 	 [Job 219] Completed (feat_level12_sst_roi.grf_cluster).
# 230130-11:54:57,260 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.

# %% [markdown]
# ## pipeline setup

# %%
# Which dataset are we looking at?
# this_dataset = 'Leipzig_7T_SM'
# this_dataset = 'Leipzig_7T_GdH'
# this_dataset = 'NTNU_7T_SJSI'
this_dataset = 'aron_3T'

# %%
# general set-up
base_dir = '/home/scotti/projects/3t_7t_sst_comparison'
work_dir = os.path.join(base_dir, 'processing', 'nipype_workflow_folders')
roi_hp_dir = os.path.join(base_dir, 'derivatives', 'fsl_feat_roi_func', this_dataset)

hpcutoff = 10000.   # in seconds
model_n = [0]
spaces = ['T1w']   # shouldn't touch this but just in case we _do_ want to go back to MNI....

if this_dataset == 'Leipzig_7T_SM':
    t_r = 3.0
    numsubs = 18
    subject_ids = [x.split('/')[-2].split('-')[-1] for x in glob.glob(os.path.join(roi_hp_dir, 'sub-*/'))]
    task = 'stop'
elif this_dataset == 'Leipzig_7T_GdH':
    t_r = 2.0
    numsubs = 20
    subject_ids = [x.split('/')[-1].split('-')[-1] for x in glob.glob(os.path.join(roi_hp_dir, 'sub-*T'))]
    task = 'stop'
elif this_dataset == 'aron_3T':
    t_r = 2.0
    subject_ids = [x.split('/')[-2].split('-')[-1] for x in glob.glob(os.path.join(roi_hp_dir, 'sub-*/'))]
    numsubs = len(subject_ids)
    task = 'stopsignal'
    
# make sure all files required are found correctly    
rois_ = glob.glob(os.path.join(base_dir, 'derivatives', 'fsl_feat_roi_func', this_dataset,
                                        'sub-*', 'func',  f'sub-*_task-{task}_run-*_space-*_desc-preproc_bold.nii.gz'))
masks_ = glob.glob(os.path.join(base_dir, 'derivatives', 'fmriprep_feat_hack', this_dataset, 
                              'sub-*', 'func', f'sub-*_task-{task}_run-*_space-*_desc-brain_mask.nii.gz'))
comp_ = glob.glob(os.path.join(base_dir, 'derivatives', 'fmriprep_feat_hack', this_dataset, 
                                    'sub-*', 'anat', 'sub-*_from-T1w_to-MNI152NLin2009cAsym_mode-image_xfm.h5'))
xfm_ = glob.glob(os.path.join(base_dir, 'derivatives', 'fmriprep_feat_hack', this_dataset,
                              'sub-*', 'func',  f'sub-*_task-{task}_run-*_from-scanner_to-T1w_mode-image_xfm.txt'))
events_ = glob.glob(os.path.join(base_dir, f'derivatives/event_files/{this_dataset}/sub-*/func/sub-*run-*_events.tsv'))
    
template_brain = os.path.join(base_dir,'sourcedata/templates/mni_icbm152_t1_tal_nlin_asym_09c_brain.nii')

# %%
print(f"""
this dataset : {this_dataset}
tr : {t_r}
number of subjects : {numsubs}
subject ids : {subject_ids}
roi_hp_dir : {roi_hp_dir}
model ns : {model_n}
no. rois : {len(rois_)}
no. masks : {len(masks_)}
no. comps : {len(comp_)}
no. xfms : {len(xfm_)}
no.events : {len(events_)}

""")
# Out:
# this dataset : aron_3T
# tr : 2.0
# number of subjects : 14
# subject ids : ['15', '02', '14', '13', '10', '12', '05', '11', '06', '04', '01', '03', '07', '09']
# roi_hp_dir : /home/scotti/projects/3t_7t_sst_comparison/derivatives/fsl_feat_roi_func/aron_3T
# model ns : [0]
# no. rois : 40
# no. masks : 40
# no. comps : 14
# no. xfms : 40
# no.events : 40

# %% [markdown]
# # first & second level models

# %%
def get_session_info(subject_id, run, task='stop', this_dataset='Leipzig_7T_SM', space='T1w', shift=-1.38/2, model_n=0,
                    root_dir='/home/scotti/projects/3t_7t_sst_comparison', include_physio=True):
    # other space: MNI152NLin2009cAsym
    import pandas as pd
    import numpy as np
    import os
    from nipype.interfaces.base import Bunch
            
    ### files ###
    sub = subject_id
    event_fn = f'{root_dir}/derivatives/event_files/{this_dataset}/sub-{sub}/func/sub-{sub}_task-{task}_run-{run}_events.tsv'
    confounds_fn = f'{root_dir}/derivatives/fmriprep/{this_dataset}/fmriprep/fmriprep/sub-{sub}/func/sub-{sub}_task-{task}_run-{run}_desc-confounds_timeseries.tsv'

    events = pd.read_csv(event_fn, sep='\t', index_col=None)
    events['duration'] = 0.001  # stick functions
    if model_n == 0:
        events = events.loc[events.trial_type.isin(['ss', 'fs', 'go'])]
    elif model_n == 1:
        events = events.loc[events.trial_type.isin(['response_left', 'response_right'])]
    events = events[['onset', 'trial_type', 'duration']]

    # slice time correction, nb: shift should be a negative number for STC
    events['onset'] += shift  

    ### confounds ###
    confounds = pd.read_csv(confounds_fn, sep='\t')
#        cosine_cols = [x for x in confounds.columns if 'cos' in x]
    include_confounds = ['trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z', 'dvars', 'framewise_displacement'] #+ cosine_cols
    confounds = confounds[include_confounds].fillna(method='bfill')

    # get retroicor
    if include_physio:
        ## take first 20 aCompCor components
#         print("No retroicor found, including 20 a_comp_cor components")
        a_comp_cor = pd.read_csv(confounds_fn, sep='\t')[['a_comp_cor_' + str(x).zfill(2) for x in range(20)]]
        confounds = pd.concat([confounds, a_comp_cor], axis=1)

    # save the confounds that we actually include in the GLM to csv, no header or index
    confounds_fn = f'{root_dir}/derivatives/confounds/{this_dataset}/sub-{sub}/func/sub-{sub}_task-{task}_run-{run}_desc-confounds_timeseries.txt'
    os.makedirs(os.path.dirname(confounds_fn), exist_ok=True)
    confounds.to_csv(confounds_fn, sep='\t', header=False, index=False)

    ### Make bunch ###
    if model_n == 0:
        conditions=['fs',
                    'ss',
                    'go']

    elif model_n ==1:
        conditions = [
                     'response_left',
                     'response_right'
                     ]

    onsets = [events.loc[events.trial_type==trial_type,'onset'].tolist() for trial_type in conditions]
    durations = [events.loc[events.trial_type==trial_type,'duration'].tolist() for trial_type in conditions]
    amplitudes = [[1] * events.loc[events.trial_type==trial_type,'onset'].shape[0] for trial_type in conditions]
#             amplitudes = [events.loc[events.trial_type==trial_type,'modulation'].tolist() for trial_type in conditions]

    info = Bunch(conditions=conditions,
                 onsets=onsets,
                 durations=durations,
                 amplitudes=amplitudes)
#         print(info)
    
    # always return info and the confounds_fn
    return info, confounds_fn #, contrasts[0]

if model_n == [0]:
    contrasts = [('fs', 'T', ['fs'], [1.0]),
                 ('ss', 'T', ['ss'], [1.0]),
                 ('go', 'T', ['go'], [1.0]),
                 ('fs-go', 'T', ['fs', 'go'], [1, -1]),
                 ('fs-ss', 'T', ['fs', 'ss'], [1, -1]),
                 ('ss-go', 'T', ['ss', 'go'], [1, -1])
                 ]
    
elif model_n == [1]:
    contrasts = [('response_left', 'T', ['response_left'], [1.0]),
                 ('response_right', 'T', ['response_right'], [1.0]),
                 ('left-right', 'T', ['response_left','response_right'], [1,-1])
                 ]

# %%
def get_runs_per_sub(subject_id):
    # here we can add the runs per subject if some subject miss a run or two
    if not subject_id in ['11','12']:
        runs = [1,2,3]
    else:
        runs = [1,2]
    
    return runs

# %%
workflow = pe.Workflow(name='feat_level12_sst_roi')
workflow.base_dir = os.path.join(base_dir, 'processing', 'nipype_workflow_folders', this_dataset)
workflow.config = {"execution": {"crashdump_dir":os.path.join(base_dir, 'processing', 'crashdumps')}}

# identity
identity = pe.Node(util.IdentityInterface(fields=['subject_id', 'space', 'model_n']), name='identity')
identity.iterables = [('subject_id', subject_ids),
                      ('space', spaces),
                      ('model_n', model_n)]

# selector
# if running only one run, copy the mask from run 1 to run 2, 'mask' variable below needs a list, it will crash if only one is found
#(terrible way to get around this.. fix at some point.. lazy..)
templates = {'roi_funcs': os.path.join(base_dir, 'derivatives', 'fsl_feat_roi_func', this_dataset,
                                            'sub-{subject_id}', 'func',  
                                            f'sub-{{subject_id}}_task-{task}_run-*_space-{{space}}*_desc-preproc_bold.nii.gz'),
             'mask': os.path.join(base_dir, 'derivatives', 'fmriprep_feat_hack', this_dataset, 
                                  'sub-{subject_id}', 'func', 
                                  f'sub-{{subject_id}}_task-{task}_run-*_space-{{space}}_desc-brain_mask.nii.gz'),
             'composite':  os.path.join(base_dir, 'derivatives', 'fmriprep_feat_hack', this_dataset, 
                                        'sub-{subject_id}', 'anat', 
                                        'sub-{subject_id}_from-T1w_to-MNI152NLin2009cAsym_mode-image_xfm.h5'),
             'xfm': os.path.join(base_dir, 'derivatives', 'fmriprep_feat_hack', this_dataset, 
                                  'sub-{subject_id}', 'func', 
                                  f'sub-{{subject_id}}_task-{task}_run-*_from-scanner_to-T1w_mode-image_xfm.txt'),}
selector = pe.Node(nio.SelectFiles(templates), name='selector')

workflow.connect(identity, 'subject_id', selector, 'subject_id')
workflow.connect(identity, 'space', selector, 'space')

# get run info per sub
run_info_getter = pe.Node(util.Function(function=get_runs_per_sub,
                                        input_names=['subject_id'],
                                        output_names=['runs']), name='run_info_getter')
workflow.connect(identity, 'subject_id', run_info_getter, 'subject_id')

# session info getter
session_info_getter = pe.MapNode(util.Function(function=get_session_info,
                                     input_names=['subject_id', 'run', 'task', 'this_dataset', 'space', 'shift', 'model_n'],
                                     output_names=['session_info', 'confounds']),
                                 iterfield=['run'],
                                 name='session_info_getter')
session_info_getter.inputs.task=task
session_info_getter.inputs.this_dataset=this_dataset
session_info_getter.inputs.space='T1w'
session_info_getter.inputs.shift = -t_r/2

workflow.connect(identity, 'subject_id', session_info_getter, 'subject_id')
workflow.connect(run_info_getter, 'runs', session_info_getter, 'run')
workflow.connect(identity, 'model_n', session_info_getter, 'model_n')


# model setup
specifymodel = pe.Node(model.SpecifyModel(), name='specifymodel1')
specifymodel.inputs.input_units = 'secs'
specifymodel.inputs.time_repetition = t_r
specifymodel.inputs.high_pass_filter_cutoff = hpcutoff

workflow.connect(session_info_getter, 'session_info', specifymodel, 'subject_info')
## old flow (with cosines): immediately connect to specifymodel
workflow.connect(selector, 'roi_funcs', specifymodel, 'functional_runs')

# Level 1 design
level1design = pe.Node(interface=fsl.Level1Design(), name="level1design")
level1design.inputs.interscan_interval = t_r
level1design.inputs.bases = {'dgamma': {'derivs': True}}
level1design.inputs.contrasts = contrasts
level1design.inputs.model_serial_correlations = True

workflow.connect(specifymodel, 'session_info', level1design, 'session_info')
# workflow.connect(session_info_getter, 'contrasts', level1design, 'contrasts')

# FEAT model
modelgen = pe.MapNode(interface=fsl.FEATModel(), iterfield=['ev_files', 'fsf_file', 'args'], name='modelgen')

workflow.connect(level1design, 'ev_files', modelgen, 'ev_files')
workflow.connect(level1design, 'fsf_files', modelgen, 'fsf_file')
workflow.connect(session_info_getter, 'confounds', modelgen, 'args')   # add confounds here


# FILM GLS
iterfield = ['design_file', 'in_file', 'tcon_file']
modelestimate = pe.MapNode(interface=fsl.FILMGLS(smooth_autocorr=False,
                                                 autocorr_noestimate=True,
                                                 mask_size = 0,
                                                 threshold = 10.0),  # 
                                                 name='modelestimate',
                                                 iterfield=iterfield,
                                                 mem_gb=10)

# ## old flow (with cosines): immediately connect to modelestimate
workflow.connect(selector, 'roi_funcs', modelestimate, 'in_file')
# # new flow: connect high-passed data
# workflow.connect(highpass, 'out_file', modelestimate, 'in_file')


workflow.connect(modelgen, 'design_file', modelestimate, 'design_file')
workflow.connect(modelgen, 'con_file', modelestimate, 'tcon_file')


#### Fixed effects
# merge copes, varcopes
copemerge = pe.MapNode(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="copemerge")

varcopemerge = pe.MapNode(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="varcopemerge")

maskemerge = pe.MapNode(interface=fsl.Merge(dimension='t'),
                       iterfield=['in_files'],
                       name="maskemerge")

def sort_copes(files):
    numelements = len(files[0])
    outfiles = []
    for i in range(numelements):
        outfiles.insert(i,[])
        for j, elements in enumerate(files):
            outfiles[i].append(elements[i])
    return outfiles

workflow.connect(modelestimate, ('copes',sort_copes), copemerge, 'in_files')
workflow.connect(modelestimate, ('varcopes',sort_copes), varcopemerge, 'in_files')


level2model = pe.Node(interface=fsl.L2Model(), name='l2model')
def num_copes(files):
    return len(files)
workflow.connect(modelestimate, ('copes',num_copes), level2model, 'num_copes')


pickfirst = lambda x: x[0]
flameo = pe.MapNode(
    interface=fsl.FLAMEO(run_mode='fe'),
    name="flameo",
    iterfield=['cope_file', 'var_cope_file'])

workflow.connect([
    (selector, flameo, [(('mask', pickfirst), 'mask_file')]),
    (copemerge, flameo, [('merged_file', 'cope_file')]),
    (varcopemerge, flameo, [('merged_file', 'var_cope_file')]),
    (level2model, flameo, [('design_mat', 'design_file'),
                           ('design_con', 't_con_file'), 
                           ('design_grp', 'cov_split_file')]),
])

## Warp to MNI-space
def warp_files(copes, varcopes, zstats, tdofs, mat, template_brain):
    # stolen from https://dpaniukov.github.io/2016/07/14/three-level-analysis-with-fsl-and-ants-2.html
    import nipype.interfaces.ants as ants

    out_copes = []
    out_varcopes = []
    out_zstats = []
    out_tdofs = []
    
    warp = ants.ApplyTransforms()
    warp.inputs.input_image_type = 0
    warp.inputs.interpolation = 'Linear'
    warp.inputs.invert_transform_flags = [False] #,False]
    warp.inputs.reference_image = template_brain
    warp.inputs.transforms = mat

    if not isinstance(copes, list):
        copes = [copes]
        varcopes = [varcopes]
        zstats = [zstats]
        tdofs = [tdofs]
    
    for cope in copes:
        warp.inputs.input_image = cope
        res=warp.run()
        out_copes.append(str(res.outputs.output_image))

    for varcope in varcopes:
        warp.inputs.input_image = varcope
        res=warp.run()
        out_varcopes.append(str(res.outputs.output_image))
        
    for zstat in zstats:
        warp.inputs.input_image = zstat
        res=warp.run()
        out_zstats.append(str(res.outputs.output_image))
    
    for tdof in tdofs:
        warp.inputs.input_image = tdof
        res=warp.run()
        out_tdofs.append(str(res.outputs.output_image))

    return out_copes, out_varcopes, out_zstats, out_tdofs

warpfunc = pe.MapNode(util.Function(input_names=['copes', 'varcopes', 'zstats', 'tdofs', 'mat','template_brain'],
                               output_names=['out_copes', 'out_varcopes', 'out_zstats', 'out_tdofs'],
                               function=warp_files),
                               iterfield=['copes', 'varcopes', 'zstats', 'tdofs'],
                  name='warpfunc')

warpfunc.inputs.template_brain = template_brain
workflow.connect(flameo, 'copes', warpfunc, 'copes')
workflow.connect(flameo, 'var_copes', warpfunc, 'varcopes')
workflow.connect(flameo, 'zstats', warpfunc, 'zstats')
workflow.connect(flameo, 'tdof', warpfunc, 'tdofs')
workflow.connect(selector, 'composite', warpfunc, 'mat')

#### post-FE analyis
# Smoothness estimation
smoothestimate = pe.MapNode(fsl.SmoothEstimate(), iterfield=['zstat_file'], name='smoothestimate')

workflow.connect(selector, ('mask', pickfirst), smoothestimate, 'mask_file')
workflow.connect(flameo, 'zstats', smoothestimate, 'zstat_file')

#
get_volume = pe.Node(fsl.ImageStats(op_string = '-V'), name='get_volume')
workflow.connect(selector, ('mask', pickfirst), get_volume, 'in_file')

# Cluster threshold
grf_cluster = pe.MapNode(fsl.Cluster(), iterfield=['dlh', 'in_file'], name='grf_cluster')
grf_cluster.iterables = [("threshold", [2.3, 3.1])] 
workflow.connect(smoothestimate, 'dlh', grf_cluster, 'dlh')
workflow.connect(flameo, 'zstats', grf_cluster, 'in_file')

def convert_volume(input):
    return int(input[1])

workflow.connect(get_volume, ('out_stat', convert_volume), grf_cluster, 'volume')
grf_cluster.inputs.out_threshold_file = True


## datasink
ds = pe.Node(nio.DataSink(), name='datasink')
ds.inputs.base_directory = os.path.join(base_dir, 'derivatives', 'glm_feat_sst_roi')

#_model_n_0_smoothing_fwhm_1p5_space_T1w_subject_id_002
substitutions = [(f't1w/level2_{stat_type}s/_model_n_{model_n_}_space_T1w_subject_id_{sub}/_flameo{contrast_n}/{stat_type}1.nii.gz',
                  f'{this_dataset}/sub-{sub}/func/model-{model_n_}/sub-{sub}_task-{task}_space-T1w_model-{model_n_}_contrast-{contrast_n}_desc-{stat_type}.nii.gz')
                  for sub in subject_ids
                  for contrast_n in range(len(contrasts))
                  for model_n_ in model_n
                  for stat_type in ['cope', 'zstat', 'varcope', 'tdof_t']
                  ]


substitutions += [(f'mni/level2_{stat_type}s/_model_n_{model_n_}_space_T1w_subject_id_{sub}/_warpfunc{contrast_n}/{stat_type}1_trans.nii.gz',
                   f'{this_dataset}/sub-{sub}/func/model-{model_n_}/sub-{sub}_task-{task}_space-MNI152NLin2009cAsym_model-{model_n_}_contrast-{contrast_n}_desc-{stat_type}.nii.gz')
                  for sub in subject_ids
                  for contrast_n in range(len(contrasts))
                  for model_n_ in model_n
                  for stat_type in ['cope', 'zstat', 'varcope', 'tdof_t']
                  ]

ds.inputs.substitutions = substitutions


## cluster thresholds: leave for now, this is more of a third-level model thing anyway
# workflow.connect(grf_cluster, 'threshold_file', ds, 'grf_thresholded_zstats_file')
# workflow.connect(grf_cluster, 'locnalmax_txt_file', ds, 'grf_localmax_txt_file')

## T1w-space
workflow.connect(flameo, 'zstats', ds, 'subject_level_model.t1w.level2_zstats')
workflow.connect(flameo, 'copes', ds, 'subject_level_model.t1w.level2_copes')
workflow.connect(flameo, 'var_copes', ds, 'subject_level_model.t1w.level2_varcopes')
workflow.connect(flameo, 'tdof', ds, 'subject_level_model.t1w.level2_tdof_ts')

## MNI-space
workflow.connect(warpfunc, 'out_zstats', ds, 'subject_level_model.mni.level2_zstats')
workflow.connect(warpfunc, 'out_copes', ds, 'subject_level_model.mni.level2_copes')
workflow.connect(warpfunc, 'out_varcopes', ds, 'subject_level_model.mni.level2_varcopes')
workflow.connect(warpfunc, 'out_tdofs', ds, 'subject_level_model.mni.level2_tdof_ts')
# workflow.connect(flameo, 'tdof', ds, 'level2_tdof')

# %%
workflow.run(plugin='MultiProc', plugin_args={'n_procs':20, 'memory_gb': 200})
# Out:
# 221202-14:45:43,766 nipype.workflow INFO:
# 	 Workflow feat_level12_sst_roi settings: ['check', 'execution', 'logging', 'monitoring']
# 221202-14:45:43,915 nipype.workflow INFO:
# 	 Running in parallel.
# 221202-14:45:43,918 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 28 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 221202-14:45:44,11 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_15/selector".
# 221202-14:45:44,12 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_15/run_info_getter".
# 221202-14:45:44,12 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_02/selector".
# 221202-14:45:44,12 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_02/run_info_getter".
# 221202-14:45:44,13 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_13/run_info_getter".
# 221202-14:45:44,12 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_14/run_info_getter".
# 221202-14:45:44,12 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_14/selector".
# 221202-14:45:44,13 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_05/selector".
# 221202-14:45:44,12 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_13/selector".
# 221202-14:45:44,13 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_12/selector".
# 221202-14:45:44,13 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_10/selector".
# 221202-14:45:44,13 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_05/run_info_getter".
# 221202-14:45:44,13 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_12/run_info_getter".
# 221202-14:45:44,13 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_10/run_info_getter".
# 221202-14:45:44,13 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_11/selector".
# 221202-14:45:44,14 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_04/run_info_getter".
# 221202-14:45:44,14 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_06/selector".
# 221202-14:45:44,14 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_11/run_info_getter".
# 221202-14:45:44,14 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_06/run_info_getter".
# 221202-14:45:44,14 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_04/selector".
# 221202-14:45:44,16 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:44,16 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221202-14:45:44,18 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:44,19 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:44,19 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221202-14:45:44,19 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221202-14:45:44,19 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:44,21 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221202-14:45:44,21 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000506s.
# 221202-14:45:44,21 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000476s.
# 221202-14:45:44,21 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221202-14:45:44,21 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221202-14:45:44,21 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:44,22 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000769s.
# 221202-14:45:44,22 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:44,22 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221202-14:45:44,22 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000431s.
# 221202-14:45:44,22 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:44,22 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001829s.
# 221202-14:45:44,23 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221202-14:45:44,23 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001612s.
# 221202-14:45:44,23 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221202-14:45:44,23 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:44,23 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221202-14:45:44,23 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:44,23 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:44,23 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001822s.
# 221202-14:45:44,25 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000482s.
# 221202-14:45:44,25 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000591s.
# 221202-14:45:44,26 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000541s.
# 221202-14:45:44,26 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001792s.
# 221202-14:45:44,26 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000581s.
# 221202-14:45:44,27 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.002104s.
# 221202-14:45:44,27 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.002187s.
# 221202-14:45:44,27 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001412s.
# 221202-14:45:44,27 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000515s.
# 221202-14:45:44,27 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000644s.
# 221202-14:45:44,27 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.002008s.
# 221202-14:45:44,28 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.00151s.
# 221202-14:45:44,28 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.002187s.
# 221202-14:45:45,921 nipype.workflow INFO:
# 	 [Job 0] Completed (feat_level12_sst_roi.selector).
# 221202-14:45:45,923 nipype.workflow INFO:
# 	 [Job 1] Completed (feat_level12_sst_roi.run_info_getter).
# 221202-14:45:45,924 nipype.workflow INFO:
# 	 [Job 2] Completed (feat_level12_sst_roi.selector).
# 221202-14:45:45,926 nipype.workflow INFO:
# 	 [Job 3] Completed (feat_level12_sst_roi.run_info_getter).
# 221202-14:45:45,927 nipype.workflow INFO:
# 	 [Job 4] Completed (feat_level12_sst_roi.selector).
# 221202-14:45:45,928 nipype.workflow INFO:
# 	 [Job 5] Completed (feat_level12_sst_roi.run_info_getter).
# 221202-14:45:45,929 nipype.workflow INFO:
# 	 [Job 6] Completed (feat_level12_sst_roi.selector).
# 221202-14:45:45,930 nipype.workflow INFO:
# 	 [Job 7] Completed (feat_level12_sst_roi.run_info_getter).
# 221202-14:45:45,931 nipype.workflow INFO:
# 	 [Job 8] Completed (feat_level12_sst_roi.selector).
# 221202-14:45:45,932 nipype.workflow INFO:
# 	 [Job 9] Completed (feat_level12_sst_roi.run_info_getter).
# 221202-14:45:45,933 nipype.workflow INFO:
# 	 [Job 10] Completed (feat_level12_sst_roi.selector).
# 221202-14:45:45,934 nipype.workflow INFO:
# 	 [Job 11] Completed (feat_level12_sst_roi.run_info_getter).
# 221202-14:45:45,935 nipype.workflow INFO:
# 	 [Job 12] Completed (feat_level12_sst_roi.selector).
# 221202-14:45:45,936 nipype.workflow INFO:
# 	 [Job 13] Completed (feat_level12_sst_roi.run_info_getter).
# 221202-14:45:45,937 nipype.workflow INFO:
# 	 [Job 14] Completed (feat_level12_sst_roi.selector).
# 221202-14:45:45,937 nipype.workflow INFO:
# 	 [Job 15] Completed (feat_level12_sst_roi.run_info_getter).
# 221202-14:45:45,938 nipype.workflow INFO:
# 	 [Job 16] Completed (feat_level12_sst_roi.selector).
# 221202-14:45:45,941 nipype.workflow INFO:
# 	 [Job 17] Completed (feat_level12_sst_roi.run_info_getter).
# 221202-14:45:45,942 nipype.workflow INFO:
# 	 [Job 18] Completed (feat_level12_sst_roi.selector).
# 221202-14:45:45,943 nipype.workflow INFO:
# 	 [Job 19] Completed (feat_level12_sst_roi.run_info_getter).
# 221202-14:45:45,945 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 18 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 221202-14:45:46,7 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_01/selector".
# 221202-14:45:46,8 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_03/selector".
# 221202-14:45:46,7 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_01/run_info_getter".
# 221202-14:45:46,8 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_03/run_info_getter".
# 221202-14:45:46,9 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_07/selector".
# 221202-14:45:46,11 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221202-14:45:46,12 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:46,12 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:46,12 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_07/run_info_getter".
# 221202-14:45:46,12 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221202-14:45:46,12 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_09/run_info_getter".
# 221202-14:45:46,12 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_roi.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_09/selector".
# 221202-14:45:46,13 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221202-14:45:46,14 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.00042s.
# 221202-14:45:46,15 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:46,15 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000618s.
# 221202-14:45:46,15 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 221202-14:45:46,15 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:46,16 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.00239s.
# 221202-14:45:46,16 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001778s.
# 221202-14:45:46,16 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000289s.
# 221202-14:45:46,17 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.002067s.
# 221202-14:45:46,17 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.00035s.
# 221202-14:45:46,18 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.00156s.
# 221202-14:45:47,923 nipype.workflow INFO:
# 	 [Job 20] Completed (feat_level12_sst_roi.selector).
# 221202-14:45:47,925 nipype.workflow INFO:
# 	 [Job 21] Completed (feat_level12_sst_roi.run_info_getter).
# 221202-14:45:47,927 nipype.workflow INFO:
# 	 [Job 22] Completed (feat_level12_sst_roi.selector).
# 221202-14:45:47,929 nipype.workflow INFO:
# 	 [Job 23] Completed (feat_level12_sst_roi.run_info_getter).
# 221202-14:45:47,930 nipype.workflow INFO:
# 	 [Job 24] Completed (feat_level12_sst_roi.selector).
# 221202-14:45:47,931 nipype.workflow INFO:
# 	 [Job 25] Completed (feat_level12_sst_roi.run_info_getter).
# 221202-14:45:47,932 nipype.workflow INFO:
# 	 [Job 26] Completed (feat_level12_sst_roi.selector).
# 221202-14:45:47,933 nipype.workflow INFO:
# 	 [Job 27] Completed (feat_level12_sst_roi.run_info_getter).
# 221202-14:45:47,934 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 32 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 221202-14:45:48,36 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_15/session_info_getter/mapflow/_session_info_getter0".
# 221202-14:45:48,36 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_15/session_info_getter/mapflow/_session_info_getter1".
# 221202-14:45:48,37 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_15/session_info_getter/mapflow/_session_info_getter2".
# 221202-14:45:48,37 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_02/session_info_getter/mapflow/_session_info_getter0".
# 221202-14:45:48,38 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_02/session_info_getter/mapflow/_session_info_getter1".
# 221202-14:45:48,40 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_02/session_info_getter/mapflow/_session_info_getter2".
# 221202-14:45:48,40 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_14/session_info_getter/mapflow/_session_info_getter0".
# 221202-14:45:48,40 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_14/session_info_getter/mapflow/_session_info_getter1".
# 221202-14:45:48,41 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_14/session_info_getter/mapflow/_session_info_getter2".
# 221202-14:45:48,41 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_13/session_info_getter/mapflow/_session_info_getter0".
# 221202-14:45:48,42 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter0" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:48,43 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter0" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:48,43 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter1" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:48,43 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter2" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:48,43 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter1" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:48,44 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter2" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:48,43 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_13/session_info_getter/mapflow/_session_info_getter1".
# 221202-14:45:48,45 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter1" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:48,45 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter0" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:48,45 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter0" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:48,46 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_13/session_info_getter/mapflow/_session_info_getter2".
# 221202-14:45:48,47 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_10/session_info_getter/mapflow/_session_info_getter0".
# 221202-14:45:48,48 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_10/session_info_getter/mapflow/_session_info_getter1".
# 221202-14:45:48,48 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter2" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:48,49 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_10/session_info_getter/mapflow/_session_info_getter2".
# 221202-14:45:48,49 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter1" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:48,50 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_12/session_info_getter/mapflow/_session_info_getter0".
# 221202-14:45:48,51 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_12/session_info_getter/mapflow/_session_info_getter1".
# 221202-14:45:48,51 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_05/session_info_getter/mapflow/_session_info_getter0".
# 221202-14:45:48,52 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter0" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:48,53 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter1" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:48,53 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_05/session_info_getter/mapflow/_session_info_getter1".
# 221202-14:45:48,53 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter2" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:48,54 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_05/session_info_getter/mapflow/_session_info_getter2".
# 221202-14:45:48,54 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter2" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:48,55 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter1" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:48,56 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter0" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:48,57 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter0" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:48,57 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter1" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:48,59 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter2" <nipype.interfaces.utility.wrappers.Function>
# No retroicor found, including 20 a_comp_cor componentsNo retroicor found, including 20 a_comp_cor components
#
# No retroicor found, including 20 a_comp_cor componentsNo retroicor found, including 20 a_comp_cor componentsNo retroicor found, including 20 a_comp_cor components
#
# No retroicor found, including 20 a_comp_cor componentsNo retroicor found, including 20 a_comp_cor components
# No retroicor found, including 20 a_comp_cor components
#
#
# No retroicor found, including 20 a_comp_cor componentsNo retroicor found, including 20 a_comp_cor componentsNo retroicor found, including 20 a_comp_cor components
# No retroicor found, including 20 a_comp_cor components
#
#
# No retroicor found, including 20 a_comp_cor componentsNo retroicor found, including 20 a_comp_cor componentsNo retroicor found, including 20 a_comp_cor components
#
#
# No retroicor found, including 20 a_comp_cor componentsNo retroicor found, including 20 a_comp_cor components
#
# 221202-14:45:49,434 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter0", elapsed time 1.390018s.
# 221202-14:45:49,435 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter0", elapsed time 1.388666s.
# 221202-14:45:49,435 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter0", elapsed time 1.382249s.
# 221202-14:45:49,436 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter1", elapsed time 1.390078s.
# 221202-14:45:49,436 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter1", elapsed time 1.391636s.
# No retroicor found, including 20 a_comp_cor components
# 221202-14:45:49,439 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter1", elapsed time 1.389175s.
# 221202-14:45:49,439 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter2", elapsed time 1.379066s.
# 221202-14:45:49,441 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter1", elapsed time 1.383439s.
# 221202-14:45:49,442 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter1", elapsed time 1.397418s.
# 221202-14:45:49,443 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter2", elapsed time 1.387245s.
# 221202-14:45:49,444 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter0", elapsed time 1.385939s.
# 221202-14:45:49,444 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter2", elapsed time 1.399073s.
# 221202-14:45:49,445 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter0", elapsed time 1.401027s.
# No retroicor found, including 20 a_comp_cor components
# 221202-14:45:49,447 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter1", elapsed time 1.392713s.
# 221202-14:45:49,447 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter2", elapsed time 1.392296s.
# 221202-14:45:49,449 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter0", elapsed time 1.401905s.
# 221202-14:45:49,451 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter0", elapsed time 1.393157s.
# 221202-14:45:49,457 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter2", elapsed time 1.4081139999999999s.
# 221202-14:45:49,461 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter2", elapsed time 1.416167s.
# No retroicor found, including 20 a_comp_cor components
# 221202-14:45:49,615 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter1", elapsed time 1.557266s.
# 221202-14:45:49,924 nipype.workflow INFO:
# 	 [Job 182] Completed (_session_info_getter0).
# 221202-14:45:49,925 nipype.workflow INFO:
# 	 [Job 183] Completed (_session_info_getter1).
# 221202-14:45:49,926 nipype.workflow INFO:
# 	 [Job 184] Completed (_session_info_getter2).
# 221202-14:45:49,927 nipype.workflow INFO:
# 	 [Job 185] Completed (_session_info_getter0).
# 221202-14:45:49,929 nipype.workflow INFO:
# 	 [Job 186] Completed (_session_info_getter1).
# 221202-14:45:49,930 nipype.workflow INFO:
# 	 [Job 187] Completed (_session_info_getter2).
# 221202-14:45:49,931 nipype.workflow INFO:
# 	 [Job 188] Completed (_session_info_getter0).
# 221202-14:45:49,932 nipype.workflow INFO:
# 	 [Job 189] Completed (_session_info_getter1).
# 221202-14:45:49,933 nipype.workflow INFO:
# 	 [Job 190] Completed (_session_info_getter2).
# 221202-14:45:49,934 nipype.workflow INFO:
# 	 [Job 191] Completed (_session_info_getter0).
# 221202-14:45:49,934 nipype.workflow INFO:
# 	 [Job 192] Completed (_session_info_getter1).
# 221202-14:45:49,935 nipype.workflow INFO:
# 	 [Job 193] Completed (_session_info_getter2).
# 221202-14:45:49,936 nipype.workflow INFO:
# 	 [Job 194] Completed (_session_info_getter0).
# 221202-14:45:49,936 nipype.workflow INFO:
# 	 [Job 195] Completed (_session_info_getter1).
# 221202-14:45:49,937 nipype.workflow INFO:
# 	 [Job 196] Completed (_session_info_getter2).
# 221202-14:45:49,937 nipype.workflow INFO:
# 	 [Job 197] Completed (_session_info_getter0).
# 221202-14:45:49,938 nipype.workflow INFO:
# 	 [Job 198] Completed (_session_info_getter1).
# 221202-14:45:49,939 nipype.workflow INFO:
# 	 [Job 199] Completed (_session_info_getter0).
# 221202-14:45:49,939 nipype.workflow INFO:
# 	 [Job 200] Completed (_session_info_getter1).
# 221202-14:45:49,940 nipype.workflow INFO:
# 	 [Job 201] Completed (_session_info_getter2).
# 221202-14:45:49,941 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 27 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 221202-14:45:49,990 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_11/session_info_getter/mapflow/_session_info_getter0".
# 221202-14:45:49,992 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_06/session_info_getter/mapflow/_session_info_getter2".
# 221202-14:45:49,990 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_11/session_info_getter/mapflow/_session_info_getter1".
# 221202-14:45:49,990 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_06/session_info_getter/mapflow/_session_info_getter0".
# 221202-14:45:49,991 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_06/session_info_getter/mapflow/_session_info_getter1".
# 221202-14:45:49,992 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_15/session_info_getter/mapflow/_session_info_getter0".
# 221202-14:45:49,993 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_04/session_info_getter/mapflow/_session_info_getter0".
# 221202-14:45:49,993 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter0" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:49,993 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_14/session_info_getter/mapflow/_session_info_getter0".
# 221202-14:45:49,993 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_13/session_info_getter/mapflow/_session_info_getter0".
# 221202-14:45:49,994 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_04/session_info_getter/mapflow/_session_info_getter1".
# 221202-14:45:49,994 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_02/session_info_getter/mapflow/_session_info_getter0".
# 221202-14:45:49,994 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_04/session_info_getter/mapflow/_session_info_getter2".
# 221202-14:45:49,994 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_10/session_info_getter/mapflow/_session_info_getter0".
# 221202-14:45:49,995 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter1" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:49,995 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_01/session_info_getter/mapflow/_session_info_getter0".
# 221202-14:45:49,995 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_05/session_info_getter/mapflow/_session_info_getter0".
# 221202-14:45:49,995 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter0" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:49,996 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter0" - collecting precomputed outputs
# 221202-14:45:49,996 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter1" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:49,996 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_01/session_info_getter/mapflow/_session_info_getter1".
# 221202-14:45:49,996 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter0" - collecting precomputed outputs
# 221202-14:45:49,996 nipype.workflow INFO:
# 	 [Node] "_session_info_getter0" found cached.
# 221202-14:45:49,996 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter0" - collecting precomputed outputs
# 221202-14:45:49,997 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter0" - collecting precomputed outputs
# 221202-14:45:49,996 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_12/session_info_getter/mapflow/_session_info_getter0".
# 221202-14:45:49,997 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter0" - collecting precomputed outputs
# 221202-14:45:49,997 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter0" - collecting precomputed outputs
# 221202-14:45:49,997 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter2" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:49,997 nipype.workflow INFO:
# 	 [Node] "_session_info_getter0" found cached.
# 221202-14:45:49,997 nipype.workflow INFO:
# 	 [Node] "_session_info_getter0" found cached.
# 221202-14:45:49,998 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_01/session_info_getter/mapflow/_session_info_getter2".
# 221202-14:45:49,998 nipype.workflow INFO:
# 	 [Node] "_session_info_getter0" found cached.
# 221202-14:45:49,998 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_03/session_info_getter/mapflow/_session_info_getter0".
# 221202-14:45:49,998 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_14/session_info_getter/mapflow/_session_info_getter1".
# 221202-14:45:49,998 nipype.workflow INFO:
# 	 [Node] "_session_info_getter0" found cached.
# 221202-14:45:49,999 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter0" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:49,999 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter1" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:49,999 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter2" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:49,999 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_13/session_info_getter/mapflow/_session_info_getter1".
# 221202-14:45:50,0 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_10/session_info_getter/mapflow/_session_info_getter1".
# 221202-14:45:50,0 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_02/session_info_getter/mapflow/_session_info_getter1".
# 221202-14:45:50,0 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter0" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:49,998 nipype.workflow INFO:
# 	 [Node] "_session_info_getter0" found cached.
# 221202-14:45:50,0 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_15/session_info_getter/mapflow/_session_info_getter1".
# 221202-14:45:50,0 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter1" - collecting precomputed outputs
# 221202-14:45:50,0 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_03/session_info_getter/mapflow/_session_info_getter1".
# 221202-14:45:50,0 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter1" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:50,1 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter1" - collecting precomputed outputs
# 221202-14:45:50,1 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter1" - collecting precomputed outputs
# 221202-14:45:50,1 nipype.workflow INFO:
# 	 [Node] "_session_info_getter1" found cached.
# 221202-14:45:50,1 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter1" - collecting precomputed outputs
# 221202-14:45:50,1 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter1" - collecting precomputed outputs
# 221202-14:45:50,1 nipype.workflow INFO:
# 	 [Node] "_session_info_getter1" found cached.
# 221202-14:45:50,1 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_05/session_info_getter/mapflow/_session_info_getter1".
# 221202-14:45:50,2 nipype.workflow INFO:
# 	 [Node] "_session_info_getter1" found cached.
# 221202-14:45:50,2 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter2" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:50,2 nipype.workflow INFO:
# 	 [Node] "_session_info_getter1" found cached.
# 221202-14:45:50,2 nipype.workflow INFO:
# 	 [Node] "_session_info_getter1" found cached.
# 221202-14:45:50,2 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_14/session_info_getter/mapflow/_session_info_getter2".
# 221202-14:45:50,3 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_13/session_info_getter/mapflow/_session_info_getter2".
# 221202-14:45:50,3 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_15/session_info_getter/mapflow/_session_info_getter2".
# 221202-14:45:50,3 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter1" - collecting precomputed outputs
# 221202-14:45:50,3 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_02/session_info_getter/mapflow/_session_info_getter2".
# 221202-14:45:50,3 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter0" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:50,3 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_10/session_info_getter/mapflow/_session_info_getter2".
# 221202-14:45:50,3 nipype.workflow INFO:
# 	 [Node] "_session_info_getter1" found cached.
# 221202-14:45:50,3 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter1" <nipype.interfaces.utility.wrappers.Function>
# 221202-14:45:50,4 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter2" - collecting precomputed outputs
# 221202-14:45:50,4 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter2" - collecting precomputed outputs
# 221202-14:45:50,4 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter2" - collecting precomputed outputs
# 221202-14:45:50,4 nipype.workflow INFO:
# 	 [Node] "_session_info_getter2" found cached.
# 221202-14:45:50,4 nipype.workflow INFO:
# 	 [Node] "_session_info_getter2" found cached.
# 221202-14:45:50,5 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_05/session_info_getter/mapflow/_session_info_getter2".
# 221202-14:45:50,5 nipype.workflow INFO:
# 	 [Node] "_session_info_getter2" found cached.
# 221202-14:45:50,5 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter2" - collecting precomputed outputs
# 221202-14:45:50,5 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter0" - collecting precomputed outputs
# 221202-14:45:50,5 nipype.workflow INFO:
# 	 [Node] "_session_info_getter2" found cached.
# 221202-14:45:50,6 nipype.workflow INFO:
# 	 [Node] "_session_info_getter0" found cached.
# 221202-14:45:50,6 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter2" - collecting precomputed outputs
# 221202-14:45:50,6 nipype.workflow INFO:
# 	 [Node] "_session_info_getter2" found cached.
# 221202-14:45:50,7 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_12/session_info_getter/mapflow/_session_info_getter1".
# 221202-14:45:50,8 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter1" - collecting precomputed outputs
# 221202-14:45:50,9 nipype.workflow INFO:
# 	 [Node] "_session_info_getter1" found cached.
# No retroicor found, including 20 a_comp_cor components
# 221202-14:45:50,16 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter2" - collecting precomputed outputs
# 221202-14:45:50,17 nipype.workflow INFO:
# 	 [Node] "_session_info_getter2" found cached.
# No retroicor found, including 20 a_comp_cor components
# No retroicor found, including 20 a_comp_cor components
# No retroicor found, including 20 a_comp_cor components
# No retroicor found, including 20 a_comp_cor components
# No retroicor found, including 20 a_comp_cor components
# No retroicor found, including 20 a_comp_cor components
# No retroicor found, including 20 a_comp_cor components
# No retroicor found, including 20 a_comp_cor components
# No retroicor found, including 20 a_comp_cor componentsNo retroicor found, including 20 a_comp_cor componentsNo retroicor found, including 20 a_comp_cor components
#
#
# No retroicor found, including 20 a_comp_cor components
# 221202-14:45:50,34 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter1", elapsed time 0.03394s.
# 221202-14:45:50,34 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter0", elapsed time 0.039371s.
# 221202-14:45:50,39 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter1", elapsed time 0.034045s.
# 221202-14:45:50,39 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter0", elapsed time 0.041905s.
# 221202-14:45:50,40 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter2", elapsed time 0.039008s.
# 221202-14:45:50,40 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter1", elapsed time 0.042161s.
# 221202-14:45:50,42 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter2", elapsed time 0.042996s.
# 221202-14:45:50,45 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter1", elapsed time 0.048641s.
# 221202-14:45:50,46 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter0", elapsed time 0.045712s.
# 221202-14:45:50,48 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter0", elapsed time 0.047015s.
# 221202-14:45:50,49 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter2", elapsed time 0.045977s.
# 221202-14:45:50,50 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter1", elapsed time 0.048645s.
# 221202-14:45:50,51 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter0", elapsed time 0.046333s.
# 221202-14:45:51,927 nipype.workflow INFO:
# 	 [Job 28] Completed (feat_level12_sst_roi.session_info_getter).
# 221202-14:45:51,929 nipype.workflow INFO:
# 	 [Job 29] Completed (feat_level12_sst_roi.session_info_getter).
# 221202-14:45:51,931 nipype.workflow INFO:
# 	 [Job 30] Completed (feat_level12_sst_roi.session_info_getter).
# 221202-14:45:51,932 nipype.workflow INFO:
# 	 [Job 31] Completed (feat_level12_sst_roi.session_info_getter).
# 221202-14:45:51,933 nipype.workflow INFO:
# 	 [Job 32] Completed (feat_level12_sst_roi.session_info_getter).
# 221202-14:45:51,934 nipype.workflow INFO:
# 	 [Job 33] Completed (feat_level12_sst_roi.session_info_getter).
# 221202-14:45:51,935 nipype.workflow INFO:
# 	 [Job 34] Completed (feat_level12_sst_roi.session_info_getter).
# ...
# 221202-14:47:20,115 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/t1w/level2_varcopes/_model_n_0_space_T1w_subject_id_09/_flameo0/varcope1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-T1w_model-0_contrast-0_desc-varcope.nii.gz
# 221202-14:47:20,116 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/t1w/level2_varcopes/_model_n_0_space_T1w_subject_id_09/_flameo1/varcope1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-T1w_model-0_contrast-1_desc-varcope.nii.gz
# 221202-14:47:20,117 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/t1w/level2_varcopes/_model_n_0_space_T1w_subject_id_09/_flameo2/varcope1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-T1w_model-0_contrast-2_desc-varcope.nii.gz
# 221202-14:47:20,118 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/t1w/level2_varcopes/_model_n_0_space_T1w_subject_id_09/_flameo3/varcope1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-T1w_model-0_contrast-3_desc-varcope.nii.gz
# 221202-14:47:20,119 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/t1w/level2_varcopes/_model_n_0_space_T1w_subject_id_09/_flameo4/varcope1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-T1w_model-0_contrast-4_desc-varcope.nii.gz
# 221202-14:47:20,119 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/t1w/level2_varcopes/_model_n_0_space_T1w_subject_id_09/_flameo5/varcope1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-T1w_model-0_contrast-5_desc-varcope.nii.gz
# 221202-14:47:20,120 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/t1w/level2_tdof_ts/_model_n_0_space_T1w_subject_id_09/_flameo0/tdof_t1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-T1w_model-0_contrast-0_desc-tdof_t.nii.gz
# 221202-14:47:20,121 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/t1w/level2_tdof_ts/_model_n_0_space_T1w_subject_id_09/_flameo1/tdof_t1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-T1w_model-0_contrast-1_desc-tdof_t.nii.gz
# 221202-14:47:20,122 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/t1w/level2_tdof_ts/_model_n_0_space_T1w_subject_id_09/_flameo2/tdof_t1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-T1w_model-0_contrast-2_desc-tdof_t.nii.gz
# 221202-14:47:20,123 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/t1w/level2_tdof_ts/_model_n_0_space_T1w_subject_id_09/_flameo3/tdof_t1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-T1w_model-0_contrast-3_desc-tdof_t.nii.gz
# 221202-14:47:20,123 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/t1w/level2_tdof_ts/_model_n_0_space_T1w_subject_id_09/_flameo4/tdof_t1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-T1w_model-0_contrast-4_desc-tdof_t.nii.gz
# 221202-14:47:20,124 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/t1w/level2_tdof_ts/_model_n_0_space_T1w_subject_id_09/_flameo5/tdof_t1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-T1w_model-0_contrast-5_desc-tdof_t.nii.gz
# 221202-14:47:20,125 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_zstats/_model_n_0_space_T1w_subject_id_09/_warpfunc0/zstat1_trans.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-MNI152NLin2009cAsym_model-0_contrast-0_desc-zstat.nii.gz
# 221202-14:47:20,125 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_zstats/_model_n_0_space_T1w_subject_id_09/_warpfunc1/zstat1_trans.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-MNI152NLin2009cAsym_model-0_contrast-1_desc-zstat.nii.gz
# 221202-14:47:20,126 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_zstats/_model_n_0_space_T1w_subject_id_09/_warpfunc2/zstat1_trans.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-MNI152NLin2009cAsym_model-0_contrast-2_desc-zstat.nii.gz
# 221202-14:47:20,127 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_zstats/_model_n_0_space_T1w_subject_id_09/_warpfunc3/zstat1_trans.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-MNI152NLin2009cAsym_model-0_contrast-3_desc-zstat.nii.gz
# 221202-14:47:20,128 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_zstats/_model_n_0_space_T1w_subject_id_09/_warpfunc4/zstat1_trans.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-MNI152NLin2009cAsym_model-0_contrast-4_desc-zstat.nii.gz
# 221202-14:47:20,128 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_zstats/_model_n_0_space_T1w_subject_id_09/_warpfunc5/zstat1_trans.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-MNI152NLin2009cAsym_model-0_contrast-5_desc-zstat.nii.gz
# 221202-14:47:20,129 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_copes/_model_n_0_space_T1w_subject_id_09/_warpfunc0/cope1_trans.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-MNI152NLin2009cAsym_model-0_contrast-0_desc-cope.nii.gz
# 221202-14:47:20,130 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_copes/_model_n_0_space_T1w_subject_id_09/_warpfunc1/cope1_trans.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-MNI152NLin2009cAsym_model-0_contrast-1_desc-cope.nii.gz
# 221202-14:47:20,130 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_copes/_model_n_0_space_T1w_subject_id_09/_warpfunc2/cope1_trans.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-MNI152NLin2009cAsym_model-0_contrast-2_desc-cope.nii.gz
# 221202-14:47:20,131 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_copes/_model_n_0_space_T1w_subject_id_09/_warpfunc3/cope1_trans.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-MNI152NLin2009cAsym_model-0_contrast-3_desc-cope.nii.gz
# 221202-14:47:20,132 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_copes/_model_n_0_space_T1w_subject_id_09/_warpfunc4/cope1_trans.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-MNI152NLin2009cAsym_model-0_contrast-4_desc-cope.nii.gz
# 221202-14:47:20,133 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_copes/_model_n_0_space_T1w_subject_id_09/_warpfunc5/cope1_trans.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-MNI152NLin2009cAsym_model-0_contrast-5_desc-cope.nii.gz
# 221202-14:47:20,133 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_varcopes/_model_n_0_space_T1w_subject_id_09/_warpfunc0/varcope1_trans.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-MNI152NLin2009cAsym_model-0_contrast-0_desc-varcope.nii.gz
# 221202-14:47:20,134 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_varcopes/_model_n_0_space_T1w_subject_id_09/_warpfunc1/varcope1_trans.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-MNI152NLin2009cAsym_model-0_contrast-1_desc-varcope.nii.gz
# 221202-14:47:20,135 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_varcopes/_model_n_0_space_T1w_subject_id_09/_warpfunc2/varcope1_trans.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-MNI152NLin2009cAsym_model-0_contrast-2_desc-varcope.nii.gz
# 221202-14:47:20,135 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_varcopes/_model_n_0_space_T1w_subject_id_09/_warpfunc3/varcope1_trans.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-MNI152NLin2009cAsym_model-0_contrast-3_desc-varcope.nii.gz
# 221202-14:47:20,136 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_varcopes/_model_n_0_space_T1w_subject_id_09/_warpfunc4/varcope1_trans.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-MNI152NLin2009cAsym_model-0_contrast-4_desc-varcope.nii.gz
# 221202-14:47:20,137 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_varcopes/_model_n_0_space_T1w_subject_id_09/_warpfunc5/varcope1_trans.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-MNI152NLin2009cAsym_model-0_contrast-5_desc-varcope.nii.gz
# 221202-14:47:20,138 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_tdof_ts/_model_n_0_space_T1w_subject_id_09/_warpfunc0/tdof_t1_trans.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-MNI152NLin2009cAsym_model-0_contrast-0_desc-tdof_t.nii.gz
# 221202-14:47:20,138 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_tdof_ts/_model_n_0_space_T1w_subject_id_09/_warpfunc1/tdof_t1_trans.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-MNI152NLin2009cAsym_model-0_contrast-1_desc-tdof_t.nii.gz
# 221202-14:47:20,139 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_tdof_ts/_model_n_0_space_T1w_subject_id_09/_warpfunc2/tdof_t1_trans.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-MNI152NLin2009cAsym_model-0_contrast-2_desc-tdof_t.nii.gz
# 221202-14:47:20,140 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_tdof_ts/_model_n_0_space_T1w_subject_id_09/_warpfunc3/tdof_t1_trans.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-MNI152NLin2009cAsym_model-0_contrast-3_desc-tdof_t.nii.gz
# 221202-14:47:20,141 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_tdof_ts/_model_n_0_space_T1w_subject_id_09/_warpfunc4/tdof_t1_trans.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-MNI152NLin2009cAsym_model-0_contrast-4_desc-tdof_t.nii.gz
# 221202-14:47:20,141 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_tdof_ts/_model_n_0_space_T1w_subject_id_09/_warpfunc5/tdof_t1_trans.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/aron_3T/sub-09/func/model-0/sub-09_task-stopsignal_space-MNI152NLin2009cAsym_model-0_contrast-5_desc-tdof_t.nii.gz
# 221202-14:47:20,142 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.038356s.
# 221202-14:47:22,12 nipype.workflow INFO:
# 	 [Job 181] Completed (feat_level12_sst_roi.datasink).
# 221202-14:47:22,16 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.

# %%
from nipype.utils.filemanip import loadpkl
res = loadpkl('/home/scotti/projects/3t_7t_sst_comparison/processing/crashdumps/crash-20221130-134015-scotti-_modelestimate2-c8f14e53-d5b2-4b8e-bd60-f4e47e4384c0.pklz')
res
# Out:
# {'node': _modelestimate2,
#  'traceback': ['Traceback (most recent call last):\n',
#   '  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/nipype/pipeline/plugins/multiproc.py", line 67, in run_node\n    result["result"] = node.run(updatehash=updatehash)\n',
#   '  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 521, in run\n    result = self._run_interface(execute=True)\n',
#   '  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 639, in _run_interface\n    return self._run_command(execute)\n',
#   '  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 750, in _run_command\n    raise NodeExecutionError(\n',
#   'nipype.pipeline.engine.nodes.NodeExecutionError: Exception raised while executing Node _modelestimate2.\n\nTraceback (most recent call last):\n  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/nipype/interfaces/base/core.py", line 454, in aggregate_outputs\n    setattr(outputs, key, val)\n  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/nipype/interfaces/base/traits_extension.py", line 425, in validate\n    value = super(MultiObject, self).validate(objekt, name, newvalue)\n  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/traits/trait_types.py", line 2699, in validate\n    return TraitListObject(self, object, name, value)\n  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/traits/trait_list_object.py", line 582, in __init__\n    super().__init__(\n  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/traits/trait_list_object.py", line 213, in __init__\n    super().__init__(self.item_validator(item) for item in iterable)\n  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/traits/trait_list_object.py", line 213, in <genexpr>\n    super().__init__(self.item_validator(item) for item in iterable)\n  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/traits/trait_list_object.py", line 865, in _item_validator\n    return trait_validator(object, self.name, value)\n  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/nipype/interfaces/base/traits_extension.py", line 330, in validate\n    value = super(File, self).validate(objekt, name, value, return_pathlike=True)\n  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/nipype/interfaces/base/traits_extension.py", line 135, in validate\n    self.error(objekt, name, str(value))\n  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/traits/base_trait_handler.py", line 74, in error\n    raise TraitError(\ntraits.trait_errors.TraitError: Each element of the \'varcopes\' trait of a FILMGLSOutputSpec507 instance must be a pathlike object or string representing an existing file, but a value of \'/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_02/modelestimate/mapflow/_modelestimate2/results/varcope1.nii.gz\' <class \'str\'> was specified.\n\nDuring handling of the above exception, another exception occurred:\n\nTraceback (most recent call last):\n  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/nipype/interfaces/base/core.py", line 401, in run\n    outputs = self.aggregate_outputs(runtime)\n  File "/home/scotti/miniconda3/envs/py38/lib/python3.8/site-packages/nipype/interfaces/base/core.py", line 461, in aggregate_outputs\n    raise FileNotFoundError(msg)\nFileNotFoundError: No such file or directory \'[\'/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_02/modelestimate/mapflow/_modelestimate2/results/varcope1.nii.gz\', \'/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_02/modelestimate/mapflow/_modelestimate2/results/varcope2.nii.gz\', \'/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_02/modelestimate/mapflow/_modelestimate2/results/varcope3.nii.gz\', \'/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_02/modelestimate/mapflow/_modelestimate2/results/varcope4.nii.gz\', \'/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_roi/_model_n_0_space_T1w_subject_id_02/modelestimate/mapflow/_modelestimate2/results/varcope5.nii.gz\', \'/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folde ...

# %%
from nipype.utils.filemanip import loadpkl
res = loadpkl('/home/scotti/projects/3t_7t_sst_comparison/processing/crashdumps/crash-20220725-201456-scotti-_modelgen2-853c3a8d-a5d2-434c-9c99-ac3b0735bd4a.pklz')
res
# Out:
# {'node': _modelgen2,
#  'traceback': ['Traceback (most recent call last):\n',
#   '  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/pipeline/plugins/multiproc.py", line 67, in run_node\n    result["result"] = node.run(updatehash=updatehash)\n',
#   '  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 521, in run\n    result = self._run_interface(execute=True)\n',
#   '  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 639, in _run_interface\n    return self._run_command(execute)\n',
#   '  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 750, in _run_command\n    raise NodeExecutionError(\n',
#   'nipype.pipeline.engine.nodes.NodeExecutionError: Exception raised while executing Node _modelgen2.\n\nTraceback (most recent call last):\n  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/interfaces/base/core.py", line 401, in run\n    outputs = self.aggregate_outputs(runtime)\n  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/interfaces/base/core.py", line 430, in aggregate_outputs\n    predicted_outputs = self._list_outputs()  # Predictions from _list_outputs\n  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/interfaces/fsl/model.py", line 544, in _list_outputs\n    assert len(design_file) == 1, "No mat file generated by FEAT Model"\nAssertionError: No mat file generated by FEAT Model\n\n']}
# ERROR! Session/line number was not unique in database. History logging moved to new session 260

# %%
from nipype.utils.filemanip import loadpkl
res = loadpkl('/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_3p125_space_T1w_subject_id_01/modelgen/result_modelgen.pklz')
res

# %%
res.outputs
# Out:
# Bunch(con_file=['/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_3p125_space_T1w_subject_id_01/modelgen/mapflow/_modelgen0/run0.con',
#        '/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_3p125_space_T1w_subject_id_01/modelgen/mapflow/_modelgen1/run1.con',
#        '/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_3p125_space_T1w_subject_id_01/modelgen/mapflow/_modelgen2/run2.con'],
#       design_cov=<undefined>,
#       design_file=['/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_3p125_space_T1w_subject_id_01/modelgen/mapflow/_modelgen0/run0.mat',
#        '/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_3p125_space_T1w_subject_id_01/modelgen/mapflow/_modelgen1/run1.mat',
#        '/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_3p125_space_T1w_subject_id_01/modelgen/mapflow/_modelgen2/run2.mat'],
#       design_image=<undefined>,
#       fcon_file=<undefined>)

# %%
check1 == check2
# Out:
# False
